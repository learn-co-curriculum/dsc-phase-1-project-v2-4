# %% [markdown]
# # Movie Data Analysis

# %%
import pandas as pd
import sqlite3
import zipfile
import matplotlib.pyplot as plt

# %%
# upzip im.db.zip file
with zipfile.ZipFile('./zippedData/im.db.zip') as zipObj:
    zipObj.extractall(path='./zippedData/')

# %%
con = sqlite3.connect('zippedData/im.db')
cursor = con.cursor()

# %%
# check table names
schema_df = pd.read_sql("""
                        SELECT *
                        FROM sqlite_master """, con)
schema_df
# Out:
#     type           name       tbl_name  rootpage  \
# 0  table   movie_basics   movie_basics         2
# 1  table      directors      directors         3
# 2  table      known_for      known_for         4
# 3  table     movie_akas     movie_akas         5
# 4  table  movie_ratings  movie_ratings         6
# 5  table        persons        persons         7
# 6  table     principals     principals         8
# 7  table        writers        writers         9
#
#                                                  sql
# 0  CREATE TABLE "movie_basics" (\n"movie_id" TEXT...
# 1  CREATE TABLE "directors" (\n"movie_id" TEXT,\n...
# 2  CREATE TABLE "known_for" (\n"person_id" TEXT,\...
# 3  CREATE TABLE "movie_akas" (\n"movie_id" TEXT,\...
# 4  CREATE TABLE "movie_ratings" (\n"movie_id" TEX...
# 5  CREATE TABLE "persons" (\n"person_id" TEXT,\n ...
# 6  CREATE TABLE "principals" (\n"movie_id" TEXT,\...
# 7  CREATE TABLE "writers" (\n"movie_id" TEXT,\n  ...

# %% [markdown]
# Trying to find if there is any correlations between the budgets and ratings of the movies. There are three data frames I need, movie_raitng and movie_basics from im.db database as well as the budget from tn.movie_budgets.csv.gz.

# %%
df_rating = pd.read_sql("""
                        SELECT *
                        FROM movie_ratings """, con)
df_rating.head()
# Out:
#      movie_id  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21

# %%
df_basics = pd.read_sql("""
                        SELECT 
                            movie_id,
                        FROM movie_basics """, con)
df_basics.head()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1680         try:
# -> 1681             cur.execute(*args, **kwargs)
#    1682             return cur
#
# OperationalError: near "FROM": syntax error
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-8-3f9155e44042> in <module>
# ----> 1 df_basics = pd.read_sql("""
#       2                         SELECT
#       3                             movie_id,
#       4                         FROM movie_basics """, con)
#       5 df_basics.head()
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/io/sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     481
#     482     if isinstance(pandas_sql, SQLiteDatabase):
# --> 483         return pandas_sql.read_query(
#     484             sql,
#     485             index_col=index_col,
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/io/sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1725
#    1726         args = _convert_params(sql, params)
# -> 1727         cursor = self.execute(*args)
#    1728         columns = [col_desc[0] for col_desc in cursor.description]
#    1729
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1691
#    1692             ex = DatabaseError(f"Execution failed on sql '{args[0]}': {exc}")
# -> 1693             raise ex from exc
#    1694
#    1695     @staticmethod
#
# DatabaseError: Execution failed on sql '
#                         SELECT
#                             movie_id,
#                         FROM movie_basics ': near "FROM": syntax error

# %%
# Join two tables together, with both movie_id, movie name and averagerating
movie_titles_rating = pd.read_sql("""
                                    SELECT 
                                        movie_ratings.movie_id, movie_basics.primary_title AS movie, movie_ratings.averagerating 
                                    FROM 
                                        movie_ratings
                                        INNER JOIN movie_basics
                                            ON movie_ratings.movie_id = movie_basics.movie_id
                                    
                                    """, con)
movie_titles_rating.head(50)
# Out:
#       movie_id                                              movie  \
# 0   tt10356526                                   Laiye Je Yaarian
# 1   tt10384606                                         Borderless
# 2    tt1042974                                          Just Inès
# 3    tt1043726                             The Legend of Hercules
# 4    tt1060240                                          Até Onde?
# 5    tt1069246                                         Habana Eva
# 6    tt1094666                                         The Hammer
# 7    tt1130982                                    The Night Clerk
# 8    tt1156528                                      Silent Sonata
# 9    tt1161457                                         Vanquisher
# 10   tt1171222                                      Baggage Claim
# 11   tt1174693                                The Four-Faced Liar
# 12   tt1181840                    Jack and the Cuckoo-Clock Heart
# 13   tt1193623                                     Buried Prayers
# 14   tt1199588                                        Black Widow
# 15   tt1204784  Maverick and Ariel's First Ever Ever Movie Hol...
# 16   tt1210166                                          Moneyball
# 17   tt1212419                                          Hereafter
# 18   tt1220911                      Why I Did (Not) Eat My Father
# 19   tt1229238               Mission: Impossible - Ghost Protocol
# 20   tt1232829                                     21 Jump Street
# 21   tt1235548                                               VIPs
# 22   tt1243974                                              Aloha
# 23   tt1250861            Under the Boardwalk: The Monopoly Story
# 24   tt1258812                                    War of the Gods
# 25   tt1261945                                 Sex and the City 2
# 26   tt1266037                                  Quartier lointain
# 27   tt1270291                                        Hunter Prey
# 28   tt1270761                        Don't Be Afraid of the Dark
# 29   tt1272886                                   Small Apartments
# 30   tt1274297                       Weddings and Other Disasters
# 31   tt1283887                                      Burning Palms
# 32   tt1285219                                 Ghosts Don't Exist
# 33   tt1287879                                   America Stripped
# 34   tt1290476                                Obituary of the Sun
# 35   tt1294141                                      Dancing Ninja
# 36   tt1320239                                     Burke and Hare
# 37   tt1322312                                 Going the Distance
# 38   tt1323962                        Andrey Iskanov's Ingression
# 39   tt1325014                        The People vs. George Lucas
# 40   tt1325019                                    The Custom Mary
# 41   tt1326743  California State of Mind: The Legacy of Pat Brown
# 42   tt1327602                               Two Days in February
# 43   tt1328913                                     Preacher's Kid
# 44   tt1331329                                    The Final Storm
# 45   tt1332570                                      Night Terrors
# 46   tt1343110                                       Speed-Dating
# 47   tt1343740                                            Paradox
# 48   tt1346690   Music Makes a City: A Louisville Orchestra Story
# 49   tt1352393                                      Little Secret
#
#     averagerating
# 0             8.3
# 1             8.9
# 2             6.4
# 3             4.2
# 4             6.5
# 5             6.2
# 6             7.0
# 7             6.4
# 8             7.2
# 9             4.2
# 10            5.1
# 11            5.8
# 12            7.0
# 13            8.0
# 14            5.5
# 15            5.8
# 16            7.6
# 17            6.5
# 18            5.0
# 19            7.4
# 20            7.2
# 21            6.6
# 22            5.4
# 23            6.2
# 24            4.0
# 25            4.4
# 26            7.0
# 27            5.8
# 28            5.6
# 29            6.1
# 30            5.4
# 31            5.4
# 32            3.4
# 33            7.7
# 34            7.2
# 35            4.5
# 36            6.2
# 37            6.3
# 38            5.1
# 39            6.7
# 40            7.2
# 41            8.4
# 42            7.8
# 43            5.2
# 44            3.6
# 45            2.1
# 46            2.5
# 47            4.6
# 48            7.7
# 49            7.7

# %% [markdown]
# Now I have a clean table to check both movie name and it corresponding rating. Next, I'm going to join this table with budget info.

# %%
df_budgets = pd.read_csv('zippedData/tn.movie_budgets.csv.gz')
df_budgets.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
df_budgets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB

# %%
# df_budgets.sort_values(by='production_budget')

# %%
# df_budgets['production_budget'][0][0]

# %%
budget_rating_df = pd.merge(movie_titles_rating,df_budgets, on='movie')
budget_rating_df.head(50)
# Out:
#       movie_id                                       movie  averagerating  id  \
# 0    tt1043726                      The Legend of Hercules            4.2  42
# 1    tt1094666                                  The Hammer            7.0  50
# 2    tt3096900                                  The Hammer            6.5  50
# 3    tt1171222                               Baggage Claim            5.1  38
# 4    tt1210166                                   Moneyball            7.6  15
# 5    tt1212419                                   Hereafter            6.5  61
# 6    tt1232829                              21 Jump Street            7.2  44
# 7    tt1243974                                       Aloha            5.4   3
# 8    tt1261945                          Sex and the City 2            4.4  16
# 9    tt1270761                 Don't Be Afraid of the Dark            5.6  43
# 10   tt1272886                            Small Apartments            6.1  90
# 11   tt1322312                          Going the Distance            6.3  11
# 12   tt6135412                          Going the Distance            3.9  11
# 13   tt1376213  The Adventurer: The Curse of the Midas Box            5.4  29
# 14   tt1403981                                 Remember Me            7.1  51
# 15   tt4843358                                 Remember Me            5.2  51
# 16   tt1460743                          Reign of Assassins            6.9  28
# 17   tt1499658                             Horrible Bosses            6.9  34
# 18   tt1535109                            Captain Phillips            7.8  92
# 19   tt1549572                               Another Earth            7.0  48
# 20   tt1582507              House at the End of the Street            5.6  73
# 21   tt1584131                          The Last Godfather            3.7  41
# 22   tt1608290                                 Zoolander 2            4.7  64
# 23   tt1629757                           Chasing Mavericks            7.2  67
# 24   tt1640484                           Jumping the Broom            5.7  93
# 25   tt1655420                        My Week with Marilyn            7.0  22
# 26   tt1661420                                     Polisse            7.3  24
# 27   tt1663202                                The Revenant            8.0  27
# 28   tt3300078                                The Revenant            6.0  27
# 29   tt1681370                                The Algerian            5.3  46
# 30   tt1714206                         The Spectacular Now            7.1  22
# 31   tt1726589                                L!fe Happens            5.6  34
# 32   tt1758741                              People Like Us            6.4  60
# 33   tt1716777                              People Like Us            7.1  60
# 34   tt1792647               Cirque du Soleil: Worlds Away            6.8  77
# 35   tt0979434                              Lottery Ticket            5.0  90
# 36   tt0985694                                     Machete            6.6  18
# 37  tt10075374                           The Little Prince            8.3  19
# 38   tt5317732                           The Little Prince            7.8  19
# 39   tt1754656                           The Little Prince            7.7  19
# 40   tt6925204                                      Genius            5.4  10
# 41   tt7722258                                      Genius            4.7  10
# 42   tt1703957                                      Genius            6.6  10
# 43   tt8919194                                      Genius            6.2  10
# 44   tt7076838                                        Adam            5.6  59
# 45   tt4113020                                        Adam            7.8  59
# 46   tt6316466                                        Adam            6.8  59
# 47  tt10199664                                        Adam            6.3  59
# 48   tt7166214                                       Bobby            6.8   8
# 49   tt8439948                                       Bobby            8.9   8
#
#     release_date production_budget domestic_gross worldwide_gross
# 0   Jan 10, 2014       $70,000,000    $18,848,538     $58,953,319
# 1   Mar 21, 2008          $850,000       $442,638        $442,638
# 2   Mar 21, 2008          $850,000       $442,638        $442,638
# 3   Sep 27, 2013        $8,500,000    $21,569,509     $22,885,836
# 4   Sep 23, 2011       $50,000,000    $75,605,492    $111,300,835
# 5   Oct 15, 2010       $50,000,000    $32,746,941    $108,660,270
# 6   Mar 16, 2012       $42,000,000   $138,447,667    $202,812,429
# 7   May 29, 2015       $37,000,000    $21,052,030     $25,387,091
# 8   May 27, 2010       $95,000,000    $95,347,692    $294,680,778
# 9   Aug 26, 2011       $25,000,000    $24,046,682     $39,126,427
# 10   Feb 8, 2013        $2,000,000             $0              $0
# 11   Sep 3, 2010       $32,000,000    $17,804,299     $43,603,990
# 12   Sep 3, 2010       $32,000,000    $17,804,299     $43,603,990
# 13  Jan 10, 2014       $25,000,000             $0              $0
# 14  Mar 12, 2010       $16,000,000    $19,068,240     $56,506,120
# 15  Mar 12, 2010       $16,000,000    $19,068,240     $56,506,120
# 16   Nov 1, 2016       $14,000,000             $0     $11,354,230
# 17   Jul 8, 2011       $35,000,000   $117,538,559    $212,417,601
# 18  Oct 11, 2013       $55,000,000   $107,136,417    $220,648,184
# 19  Jul 22, 2011          $175,000     $1,321,194      $2,102,779
# 20  Sep 21, 2012        $6,900,000    $31,611,916     $44,103,982
# 21   Apr 1, 2011       $13,400,000       $164,247        $164,247
# 22  Feb 12, 2016       $50,000,000    $28,848,693     $55,348,693
# 23  Oct 26, 2012       $20,000,000     $6,002,756      $8,300,821
# 24   May 6, 2011        $7,000,000    $37,295,394     $38,158,601
# 25  Nov 23, 2011       $10,000,000    $14,597,405     $34,240,572
# 26  May 18, 2012        $8,900,000       $176,988     $22,744,132
# 27  Dec 25, 2015      $135,000,000   $183,637,894    $532,938,302
# 28  Dec 25, 2015      $135,000,000   $183,637,894    $532,938,302
# 29  Jun 26, 2015        $1,300,000             $0              $0
# 30   Aug 2, 2013        $2,500,000     $6,852,971      $6,916,951
# 31  Apr 13, 2012          $930,000        $30,905         $30,905
# 32  Jun 29, 2012       $16,000,000    $12,431,792     $12,617,472
# 33  Jun 29, 2012       $16,000,000    $12,431,792     $12,617,472
# 34  Dec 21, 2012       $25,000,000    $12,512,862     $28,012,862
# 35  Aug 20, 2010       $17,000,000    $24,719,879     $24,719,879
# 36   Sep 3, 2010       $12,500,000    $26,593,646     $46,370,970
# 37  Feb 12, 2016       $77,500,000     $1,311,213    $102,028,919
# 38  Feb 12, 2016       $77,500,000     $1,311,213    $102,028,919
# 39  Feb 12, 2016       $77,500,000     $1,311,213    $102,028,919
# 40  Jun 10, 2016       $17,000,000     $1,361,045      $7,265,283
# 41  Jun 10, 2016       $17,000,000     $1,361,045      $7,265,283
# 42  Jun 10, 2016       $17,000,000     $1,361,045      $7,265,283
# 43  Jun 10, 2016       $17,000,000     $1,361,045      $7,265,283
# 44  Jul 29, 2009        $3,200,000     $2,283,291      $2,834,485
# 45  Jul 29, 2009        $3,200,000     $2,283,291      $2,834,485
# 46  Jul 29, 2009        $3,200,000     $2,283,291      $2,834,485
# 47  Jul 29, 2009        $3,200,000     $2,283,291      $2,834,485
# 48  Nov 17, 2006       $14,000,000    $11,242,801     $20,597,806
# 49  Nov 17, 2006       $14,000,000    $11,242,801     $20,597,806

# %%
budget_rating_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2875 entries, 0 to 2874
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   movie_id           2875 non-null   object
#  1   movie              2875 non-null   object
#  2   averagerating      2875 non-null   float64
#  3   id                 2875 non-null   int64
#  4   release_date       2875 non-null   object
#  5   production_budget  2875 non-null   object
#  6   domestic_gross     2875 non-null   object
#  7   worldwide_gross    2875 non-null   object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 202.1+ KB

# %%
fig, ax = plt.subplots()
ax.scatter(x=budget_rating_df['budgets'], y=budget_rating_df['averagerating'])
ax.set_xlabel('budgets (USD)')
ax.set_ylabel('averagerating')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'budgets'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-48ba525801c8> in <module>
#       1 fig, ax = plt.subplots()
# ----> 2 ax.scatter(x=budget_rating_df['budgets'], y=budget_rating_df['averagerating'])
#       3 ax.set_xlabel('budgets (USD)')
#       4 ax.set_ylabel('averagerating')
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
# -> 2897                 raise KeyError(key) from err
#    2898
#    2899         if tolerance is not None:
#
# KeyError: 'budgets'

# %% [markdown]
# ## Clean Budgets Table

# %%
df_budgets = pd.read_csv('zippedData/tn.movie_budgets.csv.gz')

# %%
"""All the numbers in this table need to be converted to integers"""

df_budgets['budgets(USD)'] = df_budgets['production_budget'].str.replace('$','').str.replace(',', '').astype(int)
df_budgets['dom_gross(USD)'] = df_budgets['domestic_gross'].str.replace('$','').str.replace(',', '').astype(int)
df_budgets['world_gross(USD)'] = df_budgets['worldwide_gross'].str.replace('$','').str.replace(',', '').astype('int64')

# %%
df_budgets.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross  budgets(USD)  \
# 0      $425,000,000   $760,507,625  $2,776,345,279     425000000
# 1      $410,600,000   $241,063,875  $1,045,663,875     410600000
# 2      $350,000,000    $42,762,350    $149,762,350     350000000
# 3      $330,600,000   $459,005,868  $1,403,013,963     330600000
# 4      $317,000,000   $620,181,382  $1,316,721,747     317000000
#
#    dom_gross(USD)  world_gross(USD)
# 0       760507625        2776345279
# 1       241063875        1045663875
# 2        42762350         149762350
# 3       459005868        1403013963
# 4       620181382        1316721747

# %%
# keep the int columns only
budget_clean = df_budgets.drop(['production_budget','domestic_gross','worldwide_gross'], axis=1)

# %%
budget_clean.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#    budgets(USD)  dom_gross(USD)  world_gross(USD)
# 0     425000000       760507625        2776345279
# 1     410600000       241063875        1045663875
# 2     350000000        42762350         149762350
# 3     330600000       459005868        1403013963
# 4     317000000       620181382        1316721747

# %% [markdown]
# ## Join movie_basics and budget_clean

# %%
# load movie_basics from the database
df_basics = pd.read_sql("""
                        SELECT 
                            movie_id, primary_title AS movie, genres, runtime_minutes
                        FROM 
                            movie_basics """, con)

# %%
df_basics.loc[df_basics['movie']=='Avatar']
# Out:
#         movie_id   movie  genres  runtime_minutes
# 17060  tt1775309  Avatar  Horror             93.0

# %%
#
movie_budget = budget_clean.merge(df_basics, on='movie')

# %%
movie_budget.head(50)
# Out:
#     id  release_date                                             movie  \
# 0    1  Dec 18, 2009                                            Avatar
# 1    2  May 20, 2011       Pirates of the Caribbean: On Stranger Tides
# 2    3   Jun 7, 2019                                      Dark Phoenix
# 3    4   May 1, 2015                           Avengers: Age of Ultron
# 4    7  Apr 27, 2018                            Avengers: Infinity War
# 5    9  Nov 17, 2017                                    Justice League
# 6   10   Nov 6, 2015                                           Spectre
# 7   11  Jul 20, 2012                             The Dark Knight Rises
# 8   12  May 25, 2018                           Solo: A Star Wars Story
# 9   13   Jul 2, 2013                                   The Lone Ranger
# 10  14   Mar 9, 2012                                       John Carter
# 11  15  Nov 24, 2010                                           Tangled
# 12  17   May 6, 2016                        Captain America: Civil War
# 13  18  Mar 25, 2016                Batman v Superman: Dawn of Justice
# 14  19  Dec 14, 2012                 The Hobbit: An Unexpected Journey
# 15  21  Dec 13, 2013               The Hobbit: The Desolation of Smaug
# 16  22  Dec 17, 2014         The Hobbit: The Battle of the Five Armies
# 17  23  Apr 14, 2017                           The Fate of the Furious
# 18  25  May 26, 2017  Pirates of the Caribbean: Dead Men Tell No Tales
# 19  27   May 4, 2012                                      The Avengers
# 20  35  Aug 14, 1998                                      The Avengers
# 21  29  Jun 14, 2013                                      Man of Steel
# 22  31   Jul 3, 2012                            The Amazing Spider-Man
# 23  32  May 18, 2012                                        Battleship
# 24  33  Jun 21, 2017                     Transformers: The Last Knight
# 25  34  Jun 12, 2015                                    Jurassic World
# 26  35  May 25, 2012                                    Men in Black 3
# 27  37  Jun 27, 2014                   Transformers: Age of Extinction
# 28  39  May 14, 2010                                        Robin Hood
# 29  39  May 14, 2010                                        Robin Hood
# 30  39  May 14, 2010                                        Robin Hood
# 31  39  May 14, 2010                                        Robin Hood
# 32  39  May 14, 2010                                        Robin Hood
# 33   9  Nov 21, 2018                                        Robin Hood
# 34   9  Nov 21, 2018                                        Robin Hood
# 35   9  Nov 21, 2018                                        Robin Hood
# 36   9  Nov 21, 2018                                        Robin Hood
# 37   9  Nov 21, 2018                                        Robin Hood
# 38  40  Dec 14, 2005                                         King Kong
# 39  75  Dec 17, 1976                                         King Kong
# 40  97   Apr 7, 1933                                         King Kong
# 41  42  Feb 16, 2018                                     Black Panther
# 42  43  Dec 19, 1997                                           Titanic
# 43  43  Dec 19, 1997                                           Titanic
# 44  44  Jun 15, 2018                                     Incredibles 2
# 45  45  Dec 16, 2016                      Rogue One: A Star Wars Story
# 46  46  Jun 17, 2016                                      Finding Dory
# 47  47  Jun 18, 2010                                       Toy Story 3
# 48  48   May 3, 2013                                        Iron Man 3
# 49  51   Mar 5, 2010                               Alice in Wonderland
#
#     budgets(USD)  dom_gross(USD)  world_gross(USD)   movie_id  \
# 0      425000000       760507625        2776345279  tt1775309
# 1      410600000       241063875        1045663875  tt1298650
# 2      350000000        42762350         149762350  tt6565702
# 3      330600000       459005868        1403013963  tt2395427
# 4      300000000       678815482        2048134200  tt4154756
# 5      300000000       229024295         655945209  tt0974015
# 6      300000000       200074175         879620923  tt2379713
# 7      275000000       448139099        1084439099  tt1345836
# 8      275000000       213767512         393151347  tt3778644
# 9      275000000        89302115         260002115  tt1210819
# 10     275000000        73058679         282778100  tt0401729
# 11     260000000       200821936         586477240  tt0398286
# 12     250000000       408084349        1140069413  tt3498820
# 13     250000000       330360194         867500281  tt2975590
# 14     250000000       303003568        1017003568  tt0903624
# 15     250000000       258366855         960366855  tt1170358
# 16     250000000       255119788         945577621  tt2310332
# 17     250000000       225764765        1234846267  tt4630562
# 18     230000000       172558876         788241137  tt1790809
# 19     225000000       623279547        1517935897  tt0848228
# 20      60000000        23385416          48585416  tt0848228
# 21     225000000       291045518         667999518  tt0770828
# 22     220000000       262030663         757890267  tt0948470
# 23     220000000        65233400         313477717  tt1440129
# 24     217000000       130168683         602893340  tt3371366
# 25     215000000       652270625        1648854864  tt0369610
# 26     215000000       179020854         654213485  tt1409024
# 27     210000000       245439076        1104039076  tt2109248
# 28     210000000       105487148         322459006  tt0955308
# 29     210000000       105487148         322459006  tt2363363
# 30     210000000       105487148         322459006  tt4532826
# 31     210000000       105487148         322459006  tt6858500
# 32     210000000       105487148         322459006  tt8558276
# 33      99000000        30824628          84747441  tt0955308
# 34      99000000        30824628          84747441  tt2363363
# 35      99000000        30824628          84747441  tt4532826
# 36      99000000        30824628          84747441  tt6858500
# 37      99000000        30824628          84747441  tt8558276
# 38     207000000       218080025         550517357  tt7733440
# 39      23000000        52614445          90614445  tt7733440
# 40        672000        10000000          10000650  tt7733440
# 41     200000000       700059566        1348258224  tt1825683
# 42     200000000       659363944        2208208395  tt2495766
# 43     200000000       659363944        2208208395  tt8852130
# 44     200000000       608581744        1242520711  tt3606756
# 45     200000000       532177324        1049102856  tt3748528
# 46     200000000       486295561        1021215193  tt2277860
# 47     200000000       415004880        1068879522  tt0435761
# 48     200000000       408992272        1215392272  tt1300854
# 49     200000000       334191110        1025491110  tt1014759
#
#                         genres  runtime_minutes
# 0                       Horror             93.0
# 1     Action,Adventure,Fantasy            136.0
# 2      Action,Adventure,Sci-Fi            113.0
# 3      Action,Adventure,Sci-Fi            141.0
# 4      Action,Adventure,Sci-Fi            149.0
# 5     Action,Adventure,Fantasy            120.0
# 6    Action,Adventure,Thriller            148.0
# 7              Action,Thriller            164.0
# 8     Action,Adventure,Fantasy            135.0
# 9     Action,Adventure,Western            150.0
# 10     Action,Adventure,Sci-Fi            132.0
# 11  Adventure,Animation,Comedy            100.0
# 12     Action,Adventure,Sci-Fi            147.0
# 13    Action,Adventure,Fantasy            151.0
# 14    Adventure,Family,Fantasy            169.0
# 15           Adventure,Fantasy            161.0
# 16           Adventure,Fantasy            144.0
# 17       Action,Crime,Thriller            136.0
# 18    Action,Adventure,Fantasy            129.0
# 19     Action,Adventure,Sci-Fi            143.0
# 20     Action,Adventure,Sci-Fi            143.0
# 21     Action,Adventure,Sci-Fi            143.0
# 22     Action,Adventure,Sci-Fi            136.0
# 23     Action,Adventure,Sci-Fi            131.0
# 24     Action,Adventure,Sci-Fi            154.0
# 25     Action,Adventure,Sci-Fi            124.0
# 26     Action,Adventure,Comedy            106.0
# 27     Action,Adventure,Sci-Fi            165.0
# 28      Action,Adventure,Drama            140.0
# 29                Action,Drama             92.0
# 30   Action,Adventure,Thriller            116.0
# 31                        None              NaN
# 32    Action,Adventure,History             60.0
# 33      Action,Adventure,Drama            140.0
# 34                Action,Drama             92.0
# 35   Action,Adventure,Thriller            116.0
# 36                        None              NaN
# 37    Action,Adventure,History             60.0
# 38            Action,Adventure              NaN
# 39            Action,Adventure              NaN
# 40            Action,Adventure              NaN
# 41     Action,Adventure,Sci-Fi            134.0
# 42                   Adventure              NaN
# 43                      Family            115.0
# 44  Action,Adventure,Animation            118.0
# 45     Action,Adventure,Sci-Fi            133.0
# 46  Adventure,Animation,Comedy             97.0
# 47  Adventure,Animation,Comedy            103.0
# 48     Action,Adventure,Sci-Fi            130.0
# 49    Adventure,Family,Fantasy            108.0

# %%
movie_budget.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3815 entries, 0 to 3814
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                3815 non-null   int64
#  1   release_date      3815 non-null   object
#  2   movie             3815 non-null   object
#  3   budgets(USD)      3815 non-null   int64
#  4   dom_gross(USD)    3815 non-null   int64
#  5   world_gross(USD)  3815 non-null   int64
#  6   movie_id          3815 non-null   object
#  7   genres            3743 non-null   object
#  8   runtime_minutes   3328 non-null   float64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 298.0+ KB

# %%
# check nan in genres
# movie_budget.loc[movie_budget['genres'].isna()]

# %%
# add a new column "Estimated Profit"
movie_budget['Estimated Profit'] = movie_budget['world_gross(USD)']-movie_budget['budgets(USD)']

# %%
movie_budget.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   7  Apr 27, 2018                       Avengers: Infinity War
#
#    budgets(USD)  dom_gross(USD)  world_gross(USD)   movie_id  \
# 0     425000000       760507625        2776345279  tt1775309
# 1     410600000       241063875        1045663875  tt1298650
# 2     350000000        42762350         149762350  tt6565702
# 3     330600000       459005868        1403013963  tt2395427
# 4     300000000       678815482        2048134200  tt4154756
#
#                      genres  runtime_minutes  Estimated Profit
# 0                    Horror             93.0        2351345279
# 1  Action,Adventure,Fantasy            136.0         635063875
# 2   Action,Adventure,Sci-Fi            113.0        -200237650
# 3   Action,Adventure,Sci-Fi            141.0        1072413963
# 4   Action,Adventure,Sci-Fi            149.0        1748134200

# %%
df_directors = pd.read_sql("""
                        SELECT 
                            *
                        FROM 
                            directors """, con)
df_directors.head()
# Out:
#     movie_id  person_id
# 0  tt0285252  nm0899854
# 1  tt0462036  nm1940585
# 2  tt0835418  nm0151540
# 3  tt0835418  nm0151540
# 4  tt0878654  nm0089502

# %%
df_person = pd.read_sql("""
                        SELECT 
                            *
                        FROM 
                            persons """, con)
df_person.head()
# Out:
#    person_id       primary_name  birth_year  death_year  \
# 0  nm0061671  Mary Ellen Bauder         NaN         NaN
# 1  nm0061865       Joseph Bauer         NaN         NaN
# 2  nm0062070         Bruce Baum         NaN         NaN
# 3  nm0062195       Axel Baumann         NaN         NaN
# 4  nm0062798        Pete Baxter         NaN         NaN
#
#                                  primary_profession
# 0         miscellaneous,production_manager,producer
# 1        composer,music_department,sound_department
# 2                        miscellaneous,actor,writer
# 3  camera_department,cinematographer,art_department
# 4  production_designer,art_department,set_decorator

# %%
director_df = pd.read_sql("""
                            SELECT
                                d.movie_id, p.primary_name AS director_name
                            FROM 
                                directors AS d
                                INNER JOIN persons AS p
                                    ON d.person_id = p.person_id
                                """, con)
director_df.head()
# Out:
#     movie_id      director_name
# 0  tt0285252        Tony Vitale
# 1  tt0462036         Bill Haley
# 2  tt0835418  Jay Chandrasekhar
# 3  tt0835418  Jay Chandrasekhar
# 4  tt0878654        Albert Pyun

# %%
director_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 291171 entries, 0 to 291170
# Data columns (total 2 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   movie_id       291171 non-null  object
#  1   director_name  291171 non-null  object
# dtypes: object(2)
# memory usage: 4.4+ MB

# %%
movie_df = movie_budget.merge(director_df, on='movie_id', how='inner')

# %%
movie_df.drop_duplicates(subset='movie_id',keep='first', inplace=True)

# %%
movie_clean_df = movie_df.drop_duplicates(subset='movie',keep='first')

# %%
movie_clean_df
# Out:
#       id  release_date                                        movie  \
# 0      1  Dec 18, 2009                                       Avatar
# 2      2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 7      3   Jun 7, 2019                                 Dark Phoenix
# 13     4   May 1, 2015                      Avengers: Age of Ultron
# 18     7  Apr 27, 2018                       Avengers: Infinity War
# ...   ..           ...                                          ...
# 8971  68   Jul 6, 2001                                         Cure
# 8973  70   Apr 1, 1996                                         Bang
# 8977  73  Jan 13, 2012                                    Newlyweds
# 8978  78  Dec 31, 2018                                       Red 11
# 8980  81  Sep 29, 2015                         A Plague So Pleasant
#
#       budgets(USD)  dom_gross(USD)  world_gross(USD)   movie_id  \
# 0        425000000       760507625        2776345279  tt1775309
# 2        410600000       241063875        1045663875  tt1298650
# 7        350000000        42762350         149762350  tt6565702
# 13       330600000       459005868        1403013963  tt2395427
# 18       300000000       678815482        2048134200  tt4154756
# ...            ...             ...               ...        ...
# 8971         10000           94596             94596  tt1872026
# 8973         10000             527               527  tt6616538
# 8977          9000            4584              4584  tt1880418
# 8978          7000               0                 0  tt7837402
# 8980          1400               0                 0  tt2107644
#
#                         genres  runtime_minutes  Estimated Profit  \
# 0                       Horror             93.0        2351345279
# 2     Action,Adventure,Fantasy            136.0         635063875
# 7      Action,Adventure,Sci-Fi            113.0        -200237650
# 13     Action,Adventure,Sci-Fi            141.0        1072413963
# 18     Action,Adventure,Sci-Fi            149.0        1748134200
# ...                        ...              ...               ...
# 8971                     Drama             93.0             84596
# 8973                      None              NaN             -9473
# 8977              Comedy,Drama             95.0             -4416
# 8978    Horror,Sci-Fi,Thriller             77.0             -7000
# 8980     Drama,Horror,Thriller             76.0             -1400
#
#           director_name
# 0          Atsushi Wada
# 2          Rob Marshall
# 7         Simon Kinberg
# 13          Joss Whedon
# 18        Anthony Russo
# ...                 ...
# 8971           Bill Yip
# 8973  Zarina Tadjibaeva
# 8977       Edward Burns
# 8978   Robert Rodriguez
# 8980   Benjamin Roberds
#
# [2298 rows x 11 columns]

# %%
movie_clean_df['Estimated Profit'] = movie_clean_df['world_gross(USD)']-movie_clean_df['budgets(USD)']
# Out:
# <ipython-input-38-336117b4f84c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie_clean_df['Estimated Profit'] = movie_clean_df['world_gross(USD)']-movie_clean_df['budgets(USD)']

# %%
movie_clean_df.head()
# Out:
#     id  release_date                                        movie  \
# 0    1  Dec 18, 2009                                       Avatar
# 2    2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 7    3   Jun 7, 2019                                 Dark Phoenix
# 13   4   May 1, 2015                      Avengers: Age of Ultron
# 18   7  Apr 27, 2018                       Avengers: Infinity War
#
#     budgets(USD)  dom_gross(USD)  world_gross(USD)   movie_id  \
# 0      425000000       760507625        2776345279  tt1775309
# 2      410600000       241063875        1045663875  tt1298650
# 7      350000000        42762350         149762350  tt6565702
# 13     330600000       459005868        1403013963  tt2395427
# 18     300000000       678815482        2048134200  tt4154756
#
#                       genres  runtime_minutes  Estimated Profit  director_name
# 0                     Horror             93.0        2351345279   Atsushi Wada
# 2   Action,Adventure,Fantasy            136.0         635063875   Rob Marshall
# 7    Action,Adventure,Sci-Fi            113.0        -200237650  Simon Kinberg
# 13   Action,Adventure,Sci-Fi            141.0        1072413963    Joss Whedon
# 18   Action,Adventure,Sci-Fi            149.0        1748134200  Anthony Russo

# %% [markdown]
# ##Working with Movie Table and Runtime Minutes (Cleaned version with no duplicates)

# %%
#Drop rows that are missing runtime_minutes values
movie_clean_df = movie_clean_df.dropna(subset=["runtime_minutes"])
#Check that the runtime_minutes has no missing values
movie_clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2144 entries, 0 to 8980
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                2144 non-null   int64
#  1   release_date      2144 non-null   object
#  2   movie             2144 non-null   object
#  3   budgets(USD)      2144 non-null   int64
#  4   dom_gross(USD)    2144 non-null   int64
#  5   world_gross(USD)  2144 non-null   int64
#  6   movie_id          2144 non-null   object
#  7   genres            2138 non-null   object
#  8   runtime_minutes   2144 non-null   float64
#  9   Estimated Profit  2144 non-null   int64
#  10  director_name     2144 non-null   object
# dtypes: float64(1), int64(5), object(5)
# memory usage: 201.0+ KB

# %%
#Find mean number of runtime_minutes for all movies in dataset
movie_clean_df["runtime_minutes"].mean()
# Out:
# 102.05923507462687

# %%
#find mean number of runtime_minutes for all profitable movies in dataset
#create data frame of profitable movies
profitable_movie_df = movie_clean_df[movie_clean_df["Estimated Profit"] > 0]

# %%
profitable_movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1342 entries, 0 to 8971
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                1342 non-null   int64
#  1   release_date      1342 non-null   object
#  2   movie             1342 non-null   object
#  3   budgets(USD)      1342 non-null   int64
#  4   dom_gross(USD)    1342 non-null   int64
#  5   world_gross(USD)  1342 non-null   int64
#  6   movie_id          1342 non-null   object
#  7   genres            1339 non-null   object
#  8   runtime_minutes   1342 non-null   float64
#  9   Estimated Profit  1342 non-null   int64
#  10  director_name     1342 non-null   object
# dtypes: float64(1), int64(5), object(5)
# memory usage: 125.8+ KB

# %%
profitable_movie_df.sort_values(by = "Estimated Profit", ascending = False)
profitable_movie_df.head(20)
# Out:
#      id  release_date                                             movie  \
# 0     1  Dec 18, 2009                                            Avatar
# 2     2  May 20, 2011       Pirates of the Caribbean: On Stranger Tides
# 13    4   May 1, 2015                           Avengers: Age of Ultron
# 18    7  Apr 27, 2018                            Avengers: Infinity War
# 42    9  Nov 17, 2017                                    Justice League
# 52   10   Nov 6, 2015                                           Spectre
# 57   11  Jul 20, 2012                             The Dark Knight Rises
# 61   12  May 25, 2018                           Solo: A Star Wars Story
# 67   14   Mar 9, 2012                                       John Carter
# 71   15  Nov 24, 2010                                           Tangled
# 77   17   May 6, 2016                        Captain America: Civil War
# 89   18  Mar 25, 2016                Batman v Superman: Dawn of Justice
# 96   19  Dec 14, 2012                 The Hobbit: An Unexpected Journey
# 101  21  Dec 13, 2013               The Hobbit: The Desolation of Smaug
# 106  22  Dec 17, 2014         The Hobbit: The Battle of the Five Armies
# 111  23  Apr 14, 2017                           The Fate of the Furious
# 113  25  May 26, 2017  Pirates of the Caribbean: Dead Men Tell No Tales
# 123  27   May 4, 2012                                      The Avengers
# 127  29  Jun 14, 2013                                      Man of Steel
# 131  31   Jul 3, 2012                            The Amazing Spider-Man
#
#      budgets(USD)  dom_gross(USD)  world_gross(USD)   movie_id  \
# 0       425000000       760507625        2776345279  tt1775309
# 2       410600000       241063875        1045663875  tt1298650
# 13      330600000       459005868        1403013963  tt2395427
# 18      300000000       678815482        2048134200  tt4154756
# 42      300000000       229024295         655945209  tt0974015
# 52      300000000       200074175         879620923  tt2379713
# 57      275000000       448139099        1084439099  tt1345836
# 61      275000000       213767512         393151347  tt3778644
# 67      275000000        73058679         282778100  tt0401729
# 71      260000000       200821936         586477240  tt0398286
# 77      250000000       408084349        1140069413  tt3498820
# 89      250000000       330360194         867500281  tt2975590
# 96      250000000       303003568        1017003568  tt0903624
# 101     250000000       258366855         960366855  tt1170358
# 106     250000000       255119788         945577621  tt2310332
# 111     250000000       225764765        1234846267  tt4630562
# 113     230000000       172558876         788241137  tt1790809
# 123     225000000       623279547        1517935897  tt0848228
# 127     225000000       291045518         667999518  tt0770828
# 131     220000000       262030663         757890267  tt0948470
#
#                          genres  runtime_minutes  Estimated Profit  \
# 0                        Horror             93.0        2351345279
# 2      Action,Adventure,Fantasy            136.0         635063875
# 13      Action,Adventure,Sci-Fi            141.0        1072413963
# 18      Action,Adventure,Sci-Fi            149.0        1748134200
# 42     Action,Adventure,Fantasy            120.0         355945209
# 52    Action,Adventure,Thriller            148.0         579620923
# 57              Action,Thriller            164.0         809439099
# 61     Action,Adventure,Fantasy            135.0         118151347
# 67      Action,Adventure,Sci-Fi            132.0           7778100
# 71   Adventure,Animation,Comedy            100.0         326477240
# 77      Action,Adventure,Sci-Fi            147.0         890069413
# 89     Action,Adventure,Fantasy            151.0         617500281
# 96     Adventure,Family,Fantasy            169.0         767003568
# 101           Adventure,Fantasy            161.0         710366855
# 106           Adventure,Fantasy            144.0         695577621
# 111       Action,Crime,Thriller            136.0         984846267
# 113    Action,Adventure,Fantasy            129.0         558241137
# 123     Action,Adventure,Sci-Fi            143.0        1292935897
# 127     Action,Adventure,Sci-Fi            143.0         442999518
# 131     Action,Adventure,Sci-Fi            136.0         537890267
#
#          director_name
# 0         Atsushi Wada
# 2         Rob Marshall
# 13         Joss Whedon
# 18       Anthony Russo
# 42         Zack Snyder
# 52          Sam Mendes
# 57   Christopher Nolan
# 61          Ron Howard
# 67      Andrew Stanton
# 71        Nathan Greno
# 77       Anthony Russo
# 89         Zack Snyder
# 96       Peter Jackson
# 101      Peter Jackson
# 106      Peter Jackson
# 111       F. Gary Gray
# 113    Joachim Rønning
# 123        Joss Whedon
# 127        Zack Snyder
# 131          Marc Webb

# %%
#find the mean and median runtime of the profitable movies
profitable_movie_df["runtime_minutes"].mean()
# Out:
# 104.5387481371088

# %%
profitable_movie_df["runtime_minutes"].median()
# Out:
# 104.0

# %%
# create histogram of runtime_minutes
fig, ax = plt.subplots()

ax.hist(profitable_movie_df["runtime_minutes"])
ax.set_title("Frequency of Runtimes in Minutes for Profitable Movies")
ax.set_xlabel("Minutes")
ax.set_ylabel("Frequency");

# %%
#Create scatter plot to see if there is a correlation between runtime and profitability

fig, ax = plt.subplots()
x = profitable_movie_df["runtime_minutes"]
y = profitable_movie_df["Estimated Profit"]
ax.scatter(x, y)
ax.set(xlim = (0, 180), ylim = (0, 2000000000), 
            title = "Runtime in Minutes versus Estimated Movie Profit",
            xlabel = "Runtime (minutes)",
            ylabel = "Estimated Profits ($)");
plt.savefig("images/Movie_Runtime_vs_Profit_Scatter.png")

# %%
##Create an unprofitable movie data frame and see how it compares

# %%
unprofitable_movies_df = movie_clean_df[movie_clean_df["Estimated Profit"] < 0]
unprofitable_movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 802 entries, 7 to 8980
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                802 non-null    int64
#  1   release_date      802 non-null    object
#  2   movie             802 non-null    object
#  3   budgets(USD)      802 non-null    int64
#  4   dom_gross(USD)    802 non-null    int64
#  5   world_gross(USD)  802 non-null    int64
#  6   movie_id          802 non-null    object
#  7   genres            799 non-null    object
#  8   runtime_minutes   802 non-null    float64
#  9   Estimated Profit  802 non-null    int64
#  10  director_name     802 non-null    object
# dtypes: float64(1), int64(5), object(5)
# memory usage: 75.2+ KB

# %%
least_profitable_movies_df = unprofitable_movies_df.sort_values(by = ["Estimated Profit"])[0:100]
least_profitable_movies_df.head()
# Out:
#       id  release_date                        movie  budgets(USD)  \
# 7      3   Jun 7, 2019                 Dark Phoenix     350000000
# 789   94  Mar 11, 2011              Mars Needs Moms     150000000
# 1312  42  Jun 14, 2019  Men in Black: International     110000000
# 1614  80  Dec 13, 2017                       Bright      90000000
# 1612  79  Nov 24, 2010         The Nutcracker in 3D      90000000
#
#       dom_gross(USD)  world_gross(USD)   movie_id                      genres  \
# 7           42762350         149762350  tt6565702     Action,Adventure,Sci-Fi
# 789         21392758          39549758  tt1305591  Adventure,Animation,Family
# 1312         3100000           3100000  tt2283336     Action,Adventure,Comedy
# 1614               0                 0  tt5519340        Action,Crime,Fantasy
# 1612          195459          20466016  tt1041804       Action,Family,Fantasy
#
#       runtime_minutes  Estimated Profit         director_name
# 7               113.0        -200237650         Simon Kinberg
# 789              88.0        -110450242           Simon Wells
# 1312            115.0        -106900000          F. Gary Gray
# 1614            117.0         -90000000            David Ayer
# 1612            110.0         -69533984  Andrey Konchalovskiy

# %%
least_profitable_runtime_mean = least_profitable_movies_df["runtime_minutes"].mean()
least_profitable_runtime_mean
# Out:
# 102.52

# %%
least_profitable_runtime_median = least_profitable_movies_df["runtime_minutes"].median()
least_profitable_runtime_median
# Out:
# 104.5

# %%
fig, ax = plt.subplots()

ax.hist(unprofitable_movies_df["runtime_minutes"])
ax.set_title("Frequency of Runtimes in Minutes for Unprofitable Movies")
ax.set_xlabel("Minutes")
ax.set_ylabel("Frequency");

# %%
unprofitable_runtime_mean = unprofitable_movies_df["runtime_minutes"].mean()
unprofitable_runtime_mean
# Out:
# 97.91022443890274

# %%
unprofitable_runtime_median = unprofitable_movies_df["runtime_minutes"].median()
unprofitable_runtime_median
# Out:
# 96.0

# %%
##Create 100 most profitable movies
most_profitable_df = profitable_movie_df.sort_values(by = "Estimated Profit", ascending = False)[0:100]
most_profitable_df
# Out:
#       id  release_date                   movie  budgets(USD)  dom_gross(USD)  \
# 0      1  Dec 18, 2009                  Avatar     425000000       760507625
# 18     7  Apr 27, 2018  Avengers: Infinity War     300000000       678815482
# 142   34  Jun 12, 2015          Jurassic World     215000000       652270625
# 272   67   Apr 3, 2015               Furious 7     190000000       353007020
# 123   27   May 4, 2012            The Avengers     225000000       623279547
# ...   ..           ...                     ...           ...             ...
# 866   26  Mar 22, 2013              The Croods     135000000       187168425
# 327   81  May 24, 2019                 Aladdin     182000000       246734314
# 762   78  Mar 29, 2018        Ready Player One     150000000       137690172
# 1045  46  Oct 28, 2011           Puss in Boots     130000000       149260504
# 2936  83  Jul 25, 2014                    Lucy      40000000       126573960
#
#       world_gross(USD)   movie_id                      genres  \
# 0           2776345279  tt1775309                      Horror
# 18          2048134200  tt4154756     Action,Adventure,Sci-Fi
# 142         1648854864  tt0369610     Action,Adventure,Sci-Fi
# 272         1518722794  tt2820852       Action,Crime,Thriller
# 123         1517935897  tt0848228     Action,Adventure,Sci-Fi
# ...                ...        ...                         ...
# 866          573068425  tt0481499  Action,Adventure,Animation
# 327          619234314  tt6139732     Adventure,Comedy,Family
# 762          579290136  tt1677720     Action,Adventure,Sci-Fi
# 1045         554987477  tt0448694  Action,Adventure,Animation
# 2936         457507776  tt2872732      Action,Sci-Fi,Thriller
#
#       runtime_minutes  Estimated Profit     director_name
# 0                93.0        2351345279      Atsushi Wada
# 18              149.0        1748134200     Anthony Russo
# 142             124.0        1433854864   Colin Trevorrow
# 272             137.0        1328722794         James Wan
# 123             143.0        1292935897       Joss Whedon
# ...               ...               ...               ...
# 866              98.0         438068425     Chris Sanders
# 327             128.0         437234314       Guy Ritchie
# 762             140.0         429290136  Steven Spielberg
# 1045             90.0         424987477      Chris Miller
# 2936             89.0         417507776        Luc Besson
#
# [100 rows x 11 columns]

# %%
most_profitable_runtime_mean = most_profitable_df["runtime_minutes"].mean()
most_profitable_runtime_median = most_profitable_df["runtime_minutes"].median()
print(most_profitable_runtime_mean, most_profitable_runtime_median)
# Out:
# 121.06 124.0

# %%
fig, ax = plt.subplots()

ax.hist(most_profitable_df["runtime_minutes"])
ax.set_title("Frequency of Runtimes in Minutes for Most Profitable Movies")
ax.set_xlabel("Minutes")
ax.set_ylabel("Frequency")
plt.savefig("./Movie_runtime_hist_Most_Profit.png");

# %%
fig, ax = plt.subplots()
x = most_profitable_df["runtime_minutes"]
y = most_profitable_df["Estimated Profit"]
ax.scatter(x, y)
ax.set(xlim = (40, 180), ylim = (0, 2000000000), 
            title = "Runtime in Minutes versus Estimated Movie Profit",
            xlabel = "Runtime (minutes)",
            ylabel = "Estimated Profits ($)");

# %%
#plot least profitable movies and the frequency of runtimes versus most profitable movies and frequency of run times

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.figure(figsize=(10,6))

plt.hist(most_profitable_df["runtime_minutes"], alpha = 0.5, color = "#4daf4a", label = "Most Profitable Movies", bins = "fd")
plt.hist(least_profitable_movies_df["runtime_minutes"], alpha = 0.5, color = "#ff7f00", label = "Least Profitable Movies", bins = "fd")
plt.vlines(most_profitable_runtime_mean, ymin = 0, ymax = 24, label = "Most Profitable Mean")
plt.vlines(least_profitable_runtime_mean, ymin = 0, ymax = 24, color = "blue", linestyle = "dashed", label = "Least Profitable Mean")
plt.title("Most Profitable vs Least Profitable Movies", size=18)
plt.suptitle("Frequency of Runtimes", size=20)
plt.xlabel("Movie Runtime (mins)", size=14)
plt.ylabel("Frequency", size=14)
plt.legend(loc="upper left")
plt.savefig("./Movie_Runtime_Hist_Compare.png");

# %%
#plotting with median instead of mean

# %%
plt.figure(figsize=(10,6))

plt.hist(most_profitable_df["runtime_minutes"], alpha = 0.5, color = "#4daf4a", label = "Most Profitable Movies", bins = "fd")
plt.hist(least_profitable_movies_df["runtime_minutes"], alpha = 0.5, color = "#ff7f00", label = "Least Profitable Movies", bins = "fd")
plt.vlines(most_profitable_runtime_median, ymin = 0, ymax = 24, label = "Most Profitable Median")
plt.vlines(least_profitable_runtime_median, ymin = 0, ymax = 24, color = "blue", linestyle = "dashed", label = "Least Profitable Median")
plt.title("Most Profitable vs Least Profitable Movies", size=18)
plt.suptitle("Frequency of Runtimes", size=20)
plt.xlabel("Movie Runtime (mins)", size=14)
plt.ylabel("Frequency", size=14)
plt.legend(loc="upper left")
plt.savefig("./Movie_Runtime_Hist_Compare_Median.png");

# %%
## 200 sample size

# %%
most_profitable200_df = profitable_movie_df.sort_values(by = "Estimated Profit", ascending = False)[0:200]
most_profitable200_df
# Out:
#        id  release_date                             movie  budgets(USD)  \
# 0       1  Dec 18, 2009                            Avatar     425000000
# 18      7  Apr 27, 2018            Avengers: Infinity War     300000000
# 142    34  Jun 12, 2015                    Jurassic World     215000000
# 272    67   Apr 3, 2015                         Furious 7     190000000
# 123    27   May 4, 2012                      The Avengers     225000000
# ...   ...           ...                               ...           ...
# 2140   38  Sep 18, 2015    Maze Runner: The Scorch Trials      61000000
# 1065   52  Dec 21, 2011          The Adventures of Tintin     130000000
# 1799   10  Feb 10, 2012  Journey 2: The Mysterious Island      79000000
# 1936  100   Nov 8, 1996                            Ransom      70000000
# 1300   33  Jul 31, 2013                      The Smurfs 2     110000000
#
#       dom_gross(USD)  world_gross(USD)   movie_id                      genres  \
# 0          760507625        2776345279  tt1775309                      Horror
# 18         678815482        2048134200  tt4154756     Action,Adventure,Sci-Fi
# 142        652270625        1648854864  tt0369610     Action,Adventure,Sci-Fi
# 272        353007020        1518722794  tt2820852       Action,Crime,Thriller
# 123        623279547        1517935897  tt0848228     Action,Adventure,Sci-Fi
# ...              ...               ...        ...                         ...
# 2140        81697192         310566162  tt4046784      Action,Sci-Fi,Thriller
# 1065        77591831         373993951  tt0983193  Action,Adventure,Animation
# 1799       103860290         318146162  tt1397514     Action,Adventure,Comedy
# 1936       136492681         308700000  tt8870574              Drama,Thriller
# 1300        71017784         348547523  tt2017020  Adventure,Animation,Comedy
#
#       runtime_minutes  Estimated Profit     director_name
# 0                93.0        2351345279      Atsushi Wada
# 18              149.0        1748134200     Anthony Russo
# 142             124.0        1433854864   Colin Trevorrow
# 272             137.0        1328722794         James Wan
# 123             143.0        1292935897       Joss Whedon
# ...               ...               ...               ...
# 2140            131.0         249566162          Wes Ball
# 1065            107.0         243993951  Steven Spielberg
# 1799             94.0         239146162       Brad Peyton
# 1936             98.0         238700000    Mickey Fonseca
# 1300            105.0         238547523      Raja Gosnell
#
# [200 rows x 11 columns]

# %%
most_profitable200_runtime_mean = most_profitable200_df["runtime_minutes"].mean()
most_profitable200_runtime_mean
# Out:
# 114.09

# %%
most_profitable200_runtime_median = most_profitable200_df["runtime_minutes"].median()
most_profitable200_runtime_median
# Out:
# 113.0

# %%
least_profitable200_df = unprofitable_movies_df.sort_values(by = ["Estimated Profit"])[0:200]
least_profitable200_df
# Out:
#       id  release_date                        movie  budgets(USD)  \
# 7      3   Jun 7, 2019                 Dark Phoenix     350000000
# 789   94  Mar 11, 2011              Mars Needs Moms     150000000
# 1312  42  Jun 14, 2019  Men in Black: International     110000000
# 1614  80  Dec 13, 2017                       Bright      90000000
# 1612  79  Nov 24, 2010         The Nutcracker in 3D      90000000
# ...   ..           ...                          ...           ...
# 5762  36  Jul 20, 2001                      Brother      12000000
# 5391  30   Sep 9, 2016     The Disappointments Room      15000000
# 4758  48   Mar 4, 2011         Take Me Home Tonight      19000000
# 5648  39   May 4, 2012       A Little Bit of Heaven      12500000
# 3479  79  Mar 14, 2008                     Doomsday      33000000
#
#       dom_gross(USD)  world_gross(USD)   movie_id                      genres  \
# 7           42762350         149762350  tt6565702     Action,Adventure,Sci-Fi
# 789         21392758          39549758  tt1305591  Adventure,Animation,Family
# 1312         3100000           3100000  tt2283336     Action,Adventure,Comedy
# 1614               0                 0  tt5519340        Action,Crime,Fantasy
# 1612          195459          20466016  tt1041804       Action,Family,Fantasy
# ...              ...               ...        ...                         ...
# 5762          450594            450594  tt1588358          Drama,Family,Sport
# 5391         2423467           3503761  tt2364897       Drama,Horror,Thriller
# 4758         6928068           7576604  tt0810922        Comedy,Drama,Romance
# 5648           10011           1100287  tt1440161        Comedy,Drama,Fantasy
# 3479        11008770          21621188  tt2805976               Action,Sci-Fi
#
#       runtime_minutes  Estimated Profit         director_name
# 7               113.0        -200237650         Simon Kinberg
# 789              88.0        -110450242           Simon Wells
# 1312            115.0        -106900000          F. Gary Gray
# 1614            117.0         -90000000            David Ayer
# 1612            110.0         -69533984  Andrey Konchalovskiy
# ...               ...               ...                   ...
# 5762             97.0         -11549406        Marcel Rasquin
# 5391             85.0         -11496239           D.J. Caruso
# 4758             97.0         -11423396         Michael Dowse
# 5648            106.0         -11399713        Nicole Kassell
# 3479             95.0         -11378812          Neil Johnson
#
# [200 rows x 11 columns]

# %%
least_profitable200_runtime_mean = least_profitable200_df["runtime_minutes"].mean()
least_profitable200_runtime_mean
# Out:
# 103.77

# %%
least_profitable200_runtime_median = least_profitable200_df["runtime_minutes"].median()
least_profitable200_runtime_median
# Out:
# 105.0

# %%
#Graph with 200 sample size

# %%
plt.figure(figsize=(10,6))

plt.hist(most_profitable200_df["runtime_minutes"], alpha = 0.5, color = "#4daf4a", label = "Most Profitable Movies", bins = "fd")
plt.hist(least_profitable200_df["runtime_minutes"], alpha = 0.5, color = "#ff7f00", label = "Least Profitable Movies", bins = "fd")
plt.vlines(most_profitable200_runtime_mean, ymin = 0, ymax = 24, label = "Most Profitable Mean")
plt.vlines(least_profitable200_runtime_mean, ymin = 0, ymax = 24, color = "blue", linestyle = "dashed", label = "Least Profitable Mean")
plt.title("Most Profitable vs Least Profitable Movies", size=18)
plt.suptitle("Frequency of Runtimes", size=20)
plt.xlabel("Movie Runtime (mins)", size=14)
plt.ylabel("Frequency", size=14)
plt.legend(loc="upper left");

# %%
plt.figure(figsize=(10,6))

plt.hist(most_profitable_df["runtime_minutes"], alpha = 0.5, color = "blue", label = "Most Profitable Movies", bins = "fd")
plt.hist(least_profitable_movies_df["runtime_minutes"], alpha = 0.5, color = "red", label = "Least Profitable Movies", bins = "fd")
plt.vlines(x=104, ymin = 0, ymax = 24, label = "Overall Movie Mean")
plt.title("Most Profitable vs Least Profitable Movies", size=18)
plt.suptitle("Frequency of Runtimes", size=20)
plt.xlabel("Movie Runtime (mins)", size=14)
plt.ylabel("Frequency", size=14)
plt.legend(loc="upper left")
plt.savefig("./Movie_Runtime_Hist_Compare_Final.png");
