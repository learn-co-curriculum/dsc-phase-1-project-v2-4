# %% [markdown]
# ## Movie Data Analysis
#
# Please fill out:
# * Student name: Yue Yu, Margaret Boland, Peter Burton
# * Student pace: full time
# * Scheduled project review date/time: June 3rd 2022
# * Instructor name:
# * Blog post URL:

# %% [markdown]
# ## Microsoft Movie Studio Analysis

# %% [markdown]
# ## PART I
# ## WHY ENTER THE MOVIE BUSINESS?

# %% [markdown]
# Big companies have increasingly been entering the movie making business in an effort to drive positive consumer sentiment for their company and products, compete on the same playing field as their competitors, and diversify offerings to drive alternative revenue streams.
#
# However, movies are expensive endeavors. Data from marketing research firm emarketer shows that Netflix spent 17.8 billion USD on acquiring and creating content. While Netflix has become one of the premiere movie streaming services in the industry, the high spend on content has not always paid off. Following poor subscriber numbers in its Q1 2022 earnings report, Netflix's stock dropped 30perc. in one day - losing $45bn off its market value.

# %% [markdown]
# ![Screen%20Shot%202022-06-03%20at%209.59.23%20AM.png](attachment:Screen%20Shot%202022-06-03%20at%209.59.23%20AM.png)

# %% [markdown]
# [source](https://www.emarketer.com/chart/226017/netflix-content-spending-worldwide-2016-2020-billions)

# %% [markdown]
# Netflix serves as an example of the major risk that entering the movie business entails and serves as a backdrop of our team's research strategy for Microsoft's new Movie Studio. To mitigate the risk and volatility of the movie business exemplified by Netflix's recent struggles, we focused our research on the qualities of the most profitable movies. To evaluate the movie market and create the best possible recommendations for Microsoft we combined data from the following sources:

# %% [markdown]
# [IMDb](https://www.imdb.com/)

# %% [markdown]
# [The-Numbers](https://www.the-numbers.com/)

# %% [markdown]
# In summary, to create a viable new Movie Studio our team determined it was most important to pursue profitable movies and used the above data sources to find characteristics of the most profitable movies.

# %% [markdown]
# ## PART II
# ## Opening & Cleaning the Data

# %% [markdown]
# ## Import Relevant Packages and Open IMDb File

# %%
import pandas as pd
import numpy as np
import sqlite3
import zipfile
import matplotlib.pyplot as plt

# %%
# upzip im.db.zip file
with zipfile.ZipFile('./zippedData/im.db.zip') as zipObj:
    zipObj.extractall(path='./zippedData/')

# %%
con = sqlite3.connect('zippedData/im.db')
cursor = con.cursor()

# %%
# check table names
schema_df = pd.read_sql("""
                        SELECT 
                            *
                        FROM 
                            sqlite_master """, con)
schema_df
# Out:
#     type           name       tbl_name  rootpage  \
# 0  table   movie_basics   movie_basics         2
# 1  table      directors      directors         3
# 2  table      known_for      known_for         4
# 3  table     movie_akas     movie_akas         5
# 4  table  movie_ratings  movie_ratings         6
# 5  table        persons        persons         7
# 6  table     principals     principals         8
# 7  table        writers        writers         9
#
#                                                  sql
# 0  CREATE TABLE "movie_basics" (\n"movie_id" TEXT...
# 1  CREATE TABLE "directors" (\n"movie_id" TEXT,\n...
# 2  CREATE TABLE "known_for" (\n"person_id" TEXT,\...
# 3  CREATE TABLE "movie_akas" (\n"movie_id" TEXT,\...
# 4  CREATE TABLE "movie_ratings" (\n"movie_id" TEX...
# 5  CREATE TABLE "persons" (\n"person_id" TEXT,\n ...
# 6  CREATE TABLE "principals" (\n"movie_id" TEXT,\...
# 7  CREATE TABLE "writers" (\n"movie_id" TEXT,\n  ...

# %% [markdown]
# We think genres, director and runtime of the movie have large impact on the profitability of a movie. So, we are going to make a table that contains all these information first.

# %% [markdown]
# ## Open & Clean the Budget Table

# %%
df_budgets = pd.read_csv('zippedData/tn.movie_budgets.csv.gz')
df_budgets.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747

# %%
"""All the numbers in this table need to be converted to integers"""

df_budgets['budgets(USD)'] = df_budgets['production_budget'].str.replace('$','').str.replace(',', '').astype(int)
df_budgets['dom_gross(USD)'] = df_budgets['domestic_gross'].str.replace('$','').str.replace(',', '').astype(int)
df_budgets['world_gross(USD)'] = df_budgets['worldwide_gross'].str.replace('$','').str.replace(',', '').astype('int64')

# %%
# keep the int columns only
budget_clean = df_budgets.drop(['production_budget','domestic_gross','worldwide_gross'], axis=1)
budget_clean.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#    budgets(USD)  dom_gross(USD)  world_gross(USD)
# 0     425000000       760507625        2776345279
# 1     410600000       241063875        1045663875
# 2     350000000        42762350         149762350
# 3     330600000       459005868        1403013963
# 4     317000000       620181382        1316721747

# %% [markdown]
# We are going to work with data from the SQL database. The next step is to put together all the data we need from the database with the budget table above.

# %% [markdown]
# ## Join movie_basics and budget_clean Tables to Create Central Working Table

# %%
df_basics = pd.read_sql("""
                        SELECT 
                            movie_id, 
                            primary_title AS movie, 
                            genres, 
                            runtime_minutes
                        FROM 
                            movie_basics """, con)

# %%
# we want all the movies' name and movie id to be shown in the table.
movie_budget = budget_clean.merge(df_basics, on='movie')
df_budget_merged = movie_budget
movie_budget.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   7  Apr 27, 2018                       Avengers: Infinity War
#
#    budgets(USD)  dom_gross(USD)  world_gross(USD)   movie_id  \
# 0     425000000       760507625        2776345279  tt1775309
# 1     410600000       241063875        1045663875  tt1298650
# 2     350000000        42762350         149762350  tt6565702
# 3     330600000       459005868        1403013963  tt2395427
# 4     300000000       678815482        2048134200  tt4154756
#
#                      genres  runtime_minutes
# 0                    Horror             93.0
# 1  Action,Adventure,Fantasy            136.0
# 2   Action,Adventure,Sci-Fi            113.0
# 3   Action,Adventure,Sci-Fi            141.0
# 4   Action,Adventure,Sci-Fi            149.0

# %% [markdown]
# ## Create Estimated Profit Variable

# %% [markdown]
# To make sure that we are only working with profitable movies, we created an Estimated Profit variable, which serves as our proxy for ROI. Note: It is not equivalent to ROI because a simple deduction of budget from worldwide gross does not take into account marketing budgets, payments to theaters and distributors, etc.

# %%
# add a new column that shows the profit of each movie
movie_budget['Estimated Profit'] = movie_budget['world_gross(USD)']-movie_budget['budgets(USD)']
movie_budget.head()
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   7  Apr 27, 2018                       Avengers: Infinity War
#
#    budgets(USD)  dom_gross(USD)  world_gross(USD)   movie_id  \
# 0     425000000       760507625        2776345279  tt1775309
# 1     410600000       241063875        1045663875  tt1298650
# 2     350000000        42762350         149762350  tt6565702
# 3     330600000       459005868        1403013963  tt2395427
# 4     300000000       678815482        2048134200  tt4154756
#
#                      genres  runtime_minutes  Estimated Profit
# 0                    Horror             93.0        2351345279
# 1  Action,Adventure,Fantasy            136.0         635063875
# 2   Action,Adventure,Sci-Fi            113.0        -200237650
# 3   Action,Adventure,Sci-Fi            141.0        1072413963
# 4   Action,Adventure,Sci-Fi            149.0        1748134200

# %% [markdown]
# ## Join Directors and Director's Name to the Central Working Table

# %%
df_directors = pd.read_sql("""
                        SELECT 
                            *
                        FROM 
                            directors """, con)
df_directors.head()
# Out:
#     movie_id  person_id
# 0  tt0285252  nm0899854
# 1  tt0462036  nm1940585
# 2  tt0835418  nm0151540
# 3  tt0835418  nm0151540
# 4  tt0878654  nm0089502

# %%
df_person = pd.read_sql("""
                        SELECT 
                            *
                        FROM 
                            persons """, con)
df_person.head()
# Out:
#    person_id       primary_name  birth_year  death_year  \
# 0  nm0061671  Mary Ellen Bauder         NaN         NaN
# 1  nm0061865       Joseph Bauer         NaN         NaN
# 2  nm0062070         Bruce Baum         NaN         NaN
# 3  nm0062195       Axel Baumann         NaN         NaN
# 4  nm0062798        Pete Baxter         NaN         NaN
#
#                                  primary_profession
# 0         miscellaneous,production_manager,producer
# 1        composer,music_department,sound_department
# 2                        miscellaneous,actor,writer
# 3  camera_department,cinematographer,art_department
# 4  production_designer,art_department,set_decorator

# %%
director_df = pd.read_sql("""
                            SELECT
                                d.movie_id, 
                                p.primary_name AS director_name
                            FROM 
                                directors AS d
                                INNER JOIN persons AS p
                                    ON d.person_id = p.person_id
                                """, con)
director_df.head()
# Out:
#     movie_id      director_name
# 0  tt0285252        Tony Vitale
# 1  tt0462036         Bill Haley
# 2  tt0835418  Jay Chandrasekhar
# 3  tt0835418  Jay Chandrasekhar
# 4  tt0878654        Albert Pyun

# %%
# add director names to the table
movie_df = movie_budget.merge(director_df, on='movie_id', how='inner')
movie_clean_df = movie_df.drop_duplicates(subset='movie',keep='first')
movie_clean_df.head()
# Out:
#     id  release_date                                        movie  \
# 0    1  Dec 18, 2009                                       Avatar
# 2    2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 7    3   Jun 7, 2019                                 Dark Phoenix
# 13   4   May 1, 2015                      Avengers: Age of Ultron
# 18   7  Apr 27, 2018                       Avengers: Infinity War
#
#     budgets(USD)  dom_gross(USD)  world_gross(USD)   movie_id  \
# 0      425000000       760507625        2776345279  tt1775309
# 2      410600000       241063875        1045663875  tt1298650
# 7      350000000        42762350         149762350  tt6565702
# 13     330600000       459005868        1403013963  tt2395427
# 18     300000000       678815482        2048134200  tt4154756
#
#                       genres  runtime_minutes  Estimated Profit  director_name
# 0                     Horror             93.0        2351345279   Atsushi Wada
# 2   Action,Adventure,Fantasy            136.0         635063875   Rob Marshall
# 7    Action,Adventure,Sci-Fi            113.0        -200237650  Simon Kinberg
# 13   Action,Adventure,Sci-Fi            141.0        1072413963    Joss Whedon
# 18   Action,Adventure,Sci-Fi            149.0        1748134200  Anthony Russo

# %% [markdown]
# ## PART III
# ## Analyzing the Most Popular Movie Genres from Profitable Movies

# %%
most_profit_movie = movie_clean_df.sort_values(by=['Estimated Profit'],ascending=False)[:100]
most_profit_movie['genres'].value_counts().head(10)
# Out:
# Action,Adventure,Sci-Fi       25
# Adventure,Animation,Comedy    15
# Action,Adventure,Fantasy       8
# Action,Adventure,Comedy        7
# Action,Adventure,Animation     5
# Adventure,Family,Fantasy       4
# Action,Crime,Thriller          3
# Adventure,Fantasy              2
# Action,Adventure,Thriller      2
# Animation,Comedy,Family        2
# Name: genres, dtype: int64

# %%
most_profit_movie = movie_clean_df.sort_values(by=['Estimated Profit'],ascending=False)[:100]
profit_genres = movie_clean_df.sort_values(by=['Estimated Profit'], ascending=False)['genres'][:100]
pop_gen_ls = ['Act,Adv,Sci','Adv,Anim,Com','Act,Adv,Fan','Act,Adv,Com','Act,Adv,Anim','Adv,Fam,Fan','Act,Crim,Thri','Anim,Com, Fam',
             'Act,Adv,Thri','Adv,Dram,Sci']

# %%
fig, ax = plt.subplots(figsize=(15,8))
ax.bar(x=profit_genres.value_counts()[:10].index, height=profit_genres.value_counts()[:10], zorder=3)
ax.set_xlabel('genres', fontsize=16)
plt.xticks(np.arange(0,10),fontsize=20,rotation=45,labels=pop_gen_ls,ha='right')
ax.set_title('Most Appeared Genres of Top 100 Profitable Movies', fontsize=16)
ax.grid(axis='y', zorder=0)
plt.show();

# %% [markdown]
# ##  Determining Average Budget of Each Genre

# %%
genres = profit_genres.value_counts()[:10].index
top_profit_movie_genres = movie_clean_df.loc[movie_clean_df['genres'].isin(genres)]
profit_genres_ls = top_profit_movie_genres.groupby('genres')
mean_budgets = profit_genres_ls.mean()['budgets(USD)']
mean_budgets
# Out:
# genres
# Action,Adventure,Animation    1.151471e+08
# Action,Adventure,Comedy       8.505000e+07
# Action,Adventure,Fantasy      1.415886e+08
# Action,Adventure,Sci-Fi       1.649164e+08
# Action,Adventure,Thriller     1.168333e+08
# Action,Crime,Thriller         5.904167e+07
# Adventure,Animation,Comedy    9.811029e+07
# Adventure,Family,Fantasy      1.354000e+08
# Adventure,Fantasy             2.316667e+08
# Animation,Comedy,Family       5.521429e+07
# Name: budgets(USD), dtype: float64

# %%
gen_ls = ['Act,Adv,Anim','Act,Adv,Com','Act,Adv,Fan','Act,Adv,Sic','Act,Crim,Thri','Adv,Anim,Com',
         'Adv,Dram,Fan','Adv,Fam,Fan','Aventure Fantasy','Anim,Com,Fam']
fig, ax = plt.subplots(figsize=(15,8))
ax.bar(x=mean_budgets.index, height=mean_budgets, zorder=3)
ax.set_xlabel('genres', fontsize=16)

ax.set_ylabel('hundred million (USD)',fontsize=16)
plt.xticks(np.arange(0,10),fontsize=20,rotation=45,labels=gen_ls,ha='right')

ax.set_title('Average Budget of Each Genre', fontsize=16)
ax.grid(axis='y', zorder=0)
plt.show();

# %% [markdown]
# ## PART IV
# ## Analyzing Directors of Most Profitable Movies

# %% [markdown]
# ## Cleaning New Updated Table

# %%
movie_clean_df = movie_df.drop_duplicates(subset='movie',keep='first')

# %%
movie_clean_df.head()
# Out:
#     id  release_date                                        movie  \
# 0    1  Dec 18, 2009                                       Avatar
# 2    2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 7    3   Jun 7, 2019                                 Dark Phoenix
# 13   4   May 1, 2015                      Avengers: Age of Ultron
# 18   7  Apr 27, 2018                       Avengers: Infinity War
#
#     budgets(USD)  dom_gross(USD)  world_gross(USD)   movie_id  \
# 0      425000000       760507625        2776345279  tt1775309
# 2      410600000       241063875        1045663875  tt1298650
# 7      350000000        42762350         149762350  tt6565702
# 13     330600000       459005868        1403013963  tt2395427
# 18     300000000       678815482        2048134200  tt4154756
#
#                       genres  runtime_minutes  Estimated Profit  director_name
# 0                     Horror             93.0        2351345279   Atsushi Wada
# 2   Action,Adventure,Fantasy            136.0         635063875   Rob Marshall
# 7    Action,Adventure,Sci-Fi            113.0        -200237650  Simon Kinberg
# 13   Action,Adventure,Sci-Fi            141.0        1072413963    Joss Whedon
# 18   Action,Adventure,Sci-Fi            149.0        1748134200  Anthony Russo

# %%
movie_df['estimated_profit'] = movie_df['world_gross(USD)']-movie_df['budgets(USD)']
movie_clean_df['estimated_profit'] = movie_clean_df['world_gross(USD)']-movie_clean_df['budgets(USD)']
# Out:
# <ipython-input-24-9114c18305d4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie_clean_df['estimated_profit'] = movie_clean_df['world_gross(USD)']-movie_clean_df['budgets(USD)']

# %%
movie_clean_df.sort_values("estimated_profit", inplace=True)
# Out:
# <ipython-input-25-a37d04ded4e9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   movie_clean_df.sort_values("estimated_profit", inplace=True)

# %%
Top_500 = movie_clean_df.tail(500)
Top_100 = movie_clean_df.tail(100)
Top_250 = movie_clean_df.tail(250)
Top_50 = movie_clean_df.tail(50)

# %%
movie_clean_df.shape
# Out:
# (2298, 12)

# %%
Directors = (movie_clean_df['director_name'].unique())
Director_list = Directors.tolist()
Director_list
# Out:
# ['Simon Kinberg',
#  'Simon Wells',
#  'F. Gary Gray',
#  'David Ayer',
#  'Chris Sanders',
#  'Edwine Dorival',
#  'Andrey Konchalovskiy',
#  'Xiao Feng',
#  'Chris Wedge',
#  'Landen Wakil',
#  'Richard Gilliam',
#  'Frank Coraci',
#  'Chris Jordan',
#  'Nonzee Nimibutr',
#  'Robert Schwentke',
#  'Michael Mann',
#  'Reed Morano',
#  'James Gray',
#  'Quentin Lee',
#  'Emilio Roso',
#  'Micah Fink',
#  'Zakary Hallett',
#  'Lawrence Kasanoff',
#  'Neil Corbin',
#  'Michael B. Clifford',
#  'Ben Affleck',
#  'Daniel Espinosa',
#  'Nic Good',
#  'Jess Carson',
#  'John Crowley',
#  'Alex Alessi',
#  'Elizabeth Berry',
#  'Emilio Rodriguez',
#  'Mario Van Peebles',
#  'Jimmy Hayward',
#  'Ash Brannon',
#  'Amanda Boyle',
#  'Guy Ritchie',
#  'Roland Joffé',
#  'Mikael Håfström',
#  'Werner Herzog',
#  'Joel Schumacher',
#  'Seok-hoon Lee',
#  'Sngmoo Lee',
#  'Peter Berg',
#  'David Frankel',
#  'Gabriele Muccino',
#  'Robbie Pickering',
#  'Jean-Pierre Jeunet',
#  'Walter Hill',
#  'Robert Zemeckis',
#  'Matt Kendrick',
#  'Joe Cornish',
#  'Guel Arraes',
#  'Andrew Tiernan',
#  'Frédéric Auburtin',
#  'William Winckler',
#  'David Koepp',
#  'Khurram H. Alavi',
#  'Jeff Stenzel',
#  'Willie Ying',
#  'Megan Freels Johnston',
#  'Michael Gieleta',
#  'Brad Furman',
#  'Gary Ross',
#  'Jinglei Xu',
#  'Marcus Nispel',
#  'Darren Lynch',
#  'Brian De Palma',
#  'Marc Forster',
#  'Michael Winterbottom',
#  'David O. Russell',
#  'Simon West',
#  'Musing Derick Tenn',
#  'Sebastián Lelio',
#  'Jonathan Newman',
#  'Eugene Jarecki',
#  'Laya Yourgou',
#  'Jacques Audiard',
#  'Taylor Hackford',
#  'Charles Uwagbai',
#  'Frank Miller',
#  'James Holden',
#  'Doug Liman',
#  'David Gordon Green',
#  'George Nolfi',
#  'June Daguiso',
#  'Robert Luketic',
#  'Juan Solanas',
#  'Rickey Colbert',
#  'Bruce Robinson',
#  'Pierre Coré',
#  'Carl Rinsch',
#  'Tom Tykwer',
#  'Kaya Purohit',
#  'Kim Homer Garcia',
#  'Martin Scorsese',
#  'Sharon Maymon',
#  'Pedro Morelli',
#  'Werner Kriegelstein',
#  'Pierre Morel',
#  'Richard Lanni',
#  'Paco R. Baños',
#  'Seung-wan Hong',
#  "Gavin O'Connor",
#  'Richard J. Lewis',
#  'Dan Gilroy',
#  'Thijs Meuwese',
#  'Anthony Roemermann',
#  'Craig Gillespie',
#  'George Mendeluk',
#  'Kelly Asbury',
#  'Rob Hawk',
#  'Tom Walsh',
#  'Ohad Milstein',
#  'Rachel Lambert',
#  'Bill Condon',
#  'Susanne Bier',
#  'Farhad Safinia',
#  'Julie Taymor',
#  'Jonathan English',
#  'Kimble Rendall',
#  'Radu Mihaileanu',
#  'Matt Marshall',
#  'Brian Robbins',
#  'Andrew Jarecki',
#  'Kumar Saroj',
#  'Puri Jagannadh',
#  'Brook Susan Parker',
#  'Justin Chadwick',
#  'Brian A. Miller',
#  'Jon Cassar',
#  'John Curran',
#  'David Hayter',
#  'Rodney Gray',
#  'Angelo Pizzo',
#  'Chuck Russell',
#  'Denis Villeneuve',
#  'Rob Reiner',
#  'Nick Hamm',
#  'Veena Sud',
#  'Matthew Heineman',
#  'Paul China',
#  'Dan Bradley',
#  'Todd Robinson',
#  'Angelina Jolie',
#  'Rupert Wyatt',
#  'Patrick-Mario Bernard',
#  'Jodie Foster',
#  'Amy Heckerling',
#  'Kai Nagata',
#  'Veronika Kaserer',
#  'Walter Salles',
#  'Matthew Campagna',
#  'J.W. Myers',
#  'Eric Williams',
#  'Ron Shelton',
#  'Tom Vaughan',
#  'Gurinder Chadha',
#  'Gore Verbinski',
#  'Vidhu Vinod Chopra',
#  'Kim Strobl',
#  'Jonathan Jakubowicz',
#  'Darrell Roodt',
#  'James Franco',
#  'Ken Kwapis',
#  'Christian Rivers',
#  'Erik D. Bateman',
#  'Oliver Stone',
#  'Mira Nair',
#  'Stefano Mordini',
#  'Igor Kinko',
#  'Jérôme Salle',
#  'Anand Vrs Tomar',
#  'Kevin Munroe',
#  'Yossi Madmoni',
#  'Tim Kirkby',
#  'Dito Montiel',
#  'Miguel Sapochnik',
#  'Jin-ho Hur',
#  'Rod Lurie',
#  'Stephen Petrillo',
#  'Ki-duk Kim',
#  'Ty Hunter',
#  'Eylem Sen',
#  'Scott Walker',
#  'Alexander Payne',
#  'Peter Chelsom',
#  'Joseph Kosinski',
#  'Kenneth Lonergan',
#  'Tom Shkolnik',
#  'Mark Gustafson',
#  'S.S. Rajamouli',
#  'Daniel Barnz',
#  'Hyung-rae Shim',
#  'Lee Tamahori',
#  'Dylan Chandler',
#  'Moon Si-Hyun',
#  'Andrea Di Stefano',
#  'Benedek Fliegauf',
#  'Olivier Marchal',
#  'Luca Guadagnino',
#  'Marco Carmel',
#  'Vijay Krishna Acharya',
#  'Robert Lorenz',
#  'Brian Trenchard-Smith',
#  'Tristan Patterson',
#  'Timothy Hines',
#  'Felix van Groeningen',
#  'Alex Garland',
#  'Renny Harlin',
#  'Myles Humphus',
#  'Carl Walins',
#  'Michael Apted',
#  'Roland Emmerich',
#  'Moshe Zeevi',
#  'Barry Levinson',
#  'Cameron Crowe',
#  'Ernesto Aguilar',
#  'Marcel Rasquin',
#  'D.J. Caruso',
#  'Michael Dowse',
#  'Nicole Kassell',
#  'Neil Johnson',
#  'Burr Steers',
#  'David Serero',
#  'J.C. Chandor',
#  'Abeer Zeibak Haddad',
#  'Yuvaraj Dhayalan',
#  'Julie Winokur',
#  'Bruce Ramsay',
#  'Jonathan Hensleigh',
#  'Lawrence Kasdan',
#  'Meng Zhang',
#  'Rowan Joffe',
#  'Trae Briers',
#  'Akiva Schaffer',
#  'Matthijs van Heijningen Jr.',
#  'Yuka Matsushima',
#  'Niels Arden Oplev',
#  'Ruairi Robinson',
#  'Jeff Nichols',
#  'Alejandro G. Iñárritu',
#  'Ron Howard',
#  'John Madden',
#  'George Hickenlooper',
#  'Kasi Lemmons',
#  'Dan Cordle',
#  'Tom Donahue',
#  'David Hackl',
#  'Douglas Aarniokoski',
#  'James D.R. Hickox',
#  'Jim Issa',
#  'Kate Kaminski',
#  'Robin Aubert',
#  'Jeb Stuart',
#  'Konrad Lecki',
#  'Justin Tipping',
#  'Kim Farrant',
#  'Rafa Lara',
#  'Michael Radford',
#  'Adam Starks',
#  'Alexis Michalik',
#  'Eric Lavaine',
#  'John Stalberg Jr.',
#  'Michael Grandage',
#  'Glenn Ficarra',
#  'Jake Scott',
#  'Mauricio De la Orta',
#  'Charlotte Sieling',
#  'Valeri Milev',
#  'Cyrus Nowrasteh',
#  'Jean Lee',
#  'William Phillips',
#  'Jose Carlos Gomez',
#  'Joseph P. Stachura',
#  'Ben Younger',
#  'Roqiyeh Tavakoli',
#  'Robert Redford',
#  'Hernan Jimenez',
#  'Rob Cohen',
#  'Shannon Keith',
#  'Adam Shankman',
#  'Patrick Lussier',
#  'Jim Wilson',
#  'Nimród Antal',
#  'Paul McGuigan',
#  'Craig Anderson',
#  'Desiree Lim',
#  'Shintaro Shimosawa',
#  'Lee Daniels',
#  'Peter Landesman',
#  'Jeff Bemiss',
#  'Graeme Higginson',
#  'Babak Najafi',
#  'Wes Craven',
#  'Shyamaprasad',
#  'Line Hatland',
#  'Mikael Kreuzriegler',
#  'Chris Weitz',
#  'Michael Winnick',
#  'Jordan Roberts',
#  'Oleg Sentsov',
#  'Taika Waititi',
#  'Adrienne Nelson',
#  'Keith Parmer',
#  'Ralph Fiennes',
#  'Robert Chapin',
#  'Tommy Lee Jones',
#  'Claudia Llosa',
#  'Sarik Andreasyan',
#  'Anthony Hemingway',
#  'Mathew Cullen',
#  'Tamar Simon Hoffs',
#  'Sacha Bennett',
#  'Tom Brady',
#  'Jeta Amata',
#  'Nadeem Soumah',
#  'Joe Johnston',
#  'Ben Hernandez Bray',
#  'Ross Venokur',
#  'Neil Marshall',
#  'David L. Hunt',
#  'Kim Nguyen',
#  'Jon Stewart',
#  'David Batty',
#  'Jason Zeldes',
#  'Sebastian Klinger',
#  'Adrian Noble',
#  'Spencer Susser',
#  'Jackie Earle Haley',
#  'Scott Cooper',
#  'Valerie Faris',
#  'Shari Springer Berman',
#  'Ian Sharp',
#  'Chris Tyrrell',
#  'Ho-Cheung Pang',
#  'Ariel Vromen',
#  'Todd Lincoln',
#  'Alain Desrochers',
#  'Louis Leterrier',
#  'Alex Gonzales',
#  'Ben Wheatley',
#  'Courtney Solomon',
#  'David R. Ellis',
#  'Scott Mann',
#  'Ed Nouwen',
#  'Jonathan Glazer',
#  'Stanley Kwan',
#  'Christopher Wilkinson',
#  'Charles Matthau',
#  'Bryan Fogel',
#  'William Kaufman',
#  'Mikey Schaefer',
#  'Raj Thiruselvan',
#  'V.K. Prakash',
#  'Julie Anne Robinson',
#  'Christopher M. Bessette',
#  'Francis Ford Coppola',
#  'Tim Dünschede',
#  'Rick Bieber',
#  'Kate Barker-Froyland',
#  'Jeremy Sims',
#  'Andrew Haigh',
#  'Marçal Forés',
#  'Hitoshi Matsumoto',
#  'George Ratliff',
#  'Karen Oganesyan',
#  'Bettie Wilde',
#  'Stewart Hendler',
#  'Taylor Hayden',
#  'Mauricio Hernandez',
#  'William Friedkin',
#  'Mohamed Khan',
#  'David Michôd',
#  'Karyn Kusama',
#  'Frank Wolf',
#  'Mark Duplass',
#  'Andrea Arnold',
#  'Peter Sollett',
#  'Paul Thomas Anderson',
#  'Gus Van Sant',
#  'David Cronenberg',
#  'Richard Shepard',
#  'Jane Alexandra Foster',
#  'Stewart Raffill',
#  'John Stephenson',
#  'Reg Traviss',
#  'Dan Garcia',
#  'Michael Anderson',
#  'Scott Sanders',
#  'Marc Bennett',
#  'Scott Foley',
#  'John Herzfeld',
#  'Vicky Jewson',
#  'Barrett Esposito',
#  'Oren Peli',
#  'Rodger Edralin',
#  'Kevin Smith',
#  'Ryszard Bugajski',
#  'David Lam',
#  'Michael Courtney',
#  'Paul Schrader',
#  'Jon Wright',
#  'Jon Watts',
#  'David Sudmalis',
#  'Olivier Dahan',
#  'Ody C. Harahap',
#  'Ahmet Boyacioglu',
#  'Kade Mendelowitz',
#  'Nick Park',
#  'Gabriela Tagliavini',
#  'Analeine Cal y Mayor',
#  'Mikael Berg',
#  'Matthew A. Brown',
#  'Don Scardino',
#  'Gary McKendry',
#  'Adam Vermillion',
#  'Beth LaMure',
#  'Todd Strauss-Schulson',
#  'Mora Stephens',
#  'Kabir Sadanand',
#  'Duane Journey',
#  'Ernie Barbarash',
#  'Brandon Slagle',
#  'William H. Macy',
#  'Larry Rosen',
#  'Stefan Ruzowitzky',
#  'Floria Sigismondi',
#  'Ernest Holzman',
#  'Alejandro Amenábar',
#  'Noah Scott',
#  'James Manera',
#  'Yann Demange',
#  'Dany Gehshan',
#  'Bruce Macdonald',
#  'Jeffrey Nachmanoff',
#  'Brent Ryan Green',
#  'Kevin Carraway',
#  'Ruba Nadda',
#  'Larisa Sadilova',
#  'Lawrence Sher',
#  'Daniel Stamm',
#  'Nicolas Winding Refn',
#  'Daryush Shokof',
#  'David Lowery',
#  'Kevin Connolly',
#  'Yan Vizinberg',
#  'David Schwimmer',
#  'Edoardo Leo',
#  'Mark Romanek',
#  'Jaan Tootsen',
#  'Jason Reitman',
#  'Nisha Ganatra',
#  'Roberto Santucci',
#  'Julian Gilbey',
#  'Pete Travis',
#  'Kaf',
#  'Daniel Petrie Jr.',
#  'Chris Jaymes',
#  'Muyiwa Aluko',
#  'Henry Hobson',
#  'Zal Batmanglij',
#  'Charles Ferguson',
#  'Prachya Pinkaew',
#  'Antonio Simoncini',
#  'Richard Raymond',
#  'Yash Chopra',
#  'Saad Hendawy',
#  'Eldar Rapaport',
#  'Taylor Grant',
#  'Alex Kurtzman',
#  'James Kent',
#  'Timur Bekmambetov',
#  'Jim Mickle',
#  'Warren P. Sonoda',
#  'Mateo Gil',
#  'Benson Lee',
#  'Jennifer Finnigan',
#  'Craig Johnson',
#  'Rodrigo Cortés',
#  'Jorge Dorado',
#  'Sam Levinson',
#  'Isaac Florentine',
#  'Hank Braxtan',
#  'Martin Rutley',
#  'Fred Cavayé',
#  'Gonzalo Albornoz',
#  'Victor Teran',
#  "Chris D'Arienzo",
#  'Darin Scott',
#  'Christian Sesma',
#  'Yuki Otsuka',
#  'Stuart Smith',
#  'Brandon Cronenberg',
#  'Marcio Garcia',
#  'Michael Worth',
#  'David Wain',
#  'Bryan Buckley',
#  'Leon Ford',
#  'Qi Zhao',
#  'Xavier Gens',
#  'Arie Posin',
#  'DeShawn Hill',
#  'Josh Schwartz',
#  'Drew Goddard',
#  'Eric Wareheim',
#  'Corey Piper',
#  'Heidi Ewing',
#  'Christophe Sahr',
#  'Gabriel Soriano',
#  'Jonathan Lynn',
#  'Fred Andrews',
#  'Michael Mongillo',
#  'John Woo',
#  'Gary Horton',
#  'Jon M. Chu',
#  'Nikita Sharma',
#  'Joe Cross',
#  'Youssef Delara',
#  'Chris Hunter',
#  'Chris Evans',
#  'Rob Thomas',
#  'Nathan Waters',
#  'Zackary Adler',
#  'Jaco Booyens',
#  'Benni Diez',
#  'Dominic Burns',
#  'Jason Stone',
#  'Danny Perez',
#  'John Murlowski',
#  'Paul Greengrass',
#  'Jonathan Teplitzky',
#  'Rita Merson',
#  'Reed Cowan',
#  'Maarten Wijsman',
#  'Shapur Gharib',
#  'Ulla Heikkilä',
#  'Duke Johnson',
#  'Drew Pearce',
#  'Jesse Estrada',
#  'Alejandro Monteverde',
#  'Andrew Mogel',
#  'Dan Rush',
#  'Jason Eisener',
#  'Jason Bateman',
#  'Miguel Arteta',
#  "Anthony O'Brien",
#  'Glenn Ciano',
#  'Dan Perri',
#  'Robert Fontaine',
#  'Gavin Wiesen',
#  'Russell Friedenberg',
#  'Coke Daniels',
#  'James Cox',
#  'Song Wang',
#  'Michael Rochford',
#  'Olga Lopato',
#  'Alex Ranarivelo',
#  'John J. Budion',
#  'Brad Copeland',
#  'Jonas Åkerlund',
#  'Chris Shadley',
#  'Sebastian Doggart',
#  'Derick Martini',
#  'Scott Dow',
#  'Jerry Dugan',
#  'Paul Bunnell',
#  'Michael W. Watkins',
#  'Qi Song',
#  'Jonathan Kasdan',
#  'Dean Wright',
#  'Catherine Hardwicke',
#  'Stephen Milburn Anderson',
#  'Bill Muir',
#  'Trevor Fleming',
#  'Rebecca Harrell Tickell',
#  'James Gunn',
#  'Vijay Chandar',
#  'Reginald Hudlin',
#  'Cory Finley',
#  'Corey Grant',
#  'W.D. Hogan',
#  'Curt Hahn',
#  'Bill Guttentag',
#  'Richard LaGravenese',
#  'Robert Rodriguez',
#  'Tina Gordon',
#  'Whit Stillman',
#  'Frank Pestarino',
#  'Ice Idanan',
#  'Mitzi Peirone',
#  'Sreekanth S. Nair',
#  'Jeffery Hauser',
#  'Dan Fogelman',
#  'S. Craig Zahler',
#  'David Winning',
#  'Tara Subkoff',
#  'David Rodriguez',
#  'Deryck Broom',
#  'Arvin N. Berner',
#  'Nae Caranfil',
#  'Wayne W. Whited',
#  'Patrick Epape',
#  'Jamal Hill',
#  'Ahsan Rahim',
#  'David Worth',
#  'Daryn Tufts',
#  'Boris Rodriguez',
#  'Adam Carolla',
#  'Jorma Taccone',
#  'Ryan Fleck',
#  'Andrew Gurland',
#  'Don Boyd',
#  'William Eubank',
#  'John Sayles',
#  'Christopher Morris',
#  'Giovanni Zelko',
#  'Alexander Holt',
#  'Gerard Johnstone',
#  'Spike Lee',
#  'Brenton Spencer',
#  'Justin Thomas Ostensen',
#  'Jay Alaimo',
#  'Timothy A. Chey',
#  'Dylan Bank',
#  'Jeremy Saulnier',
#  'Marcel Walz',
#  'Lluís Quílez',
#  'Agnès Jaoui',
#  'Léa Pool',
#  'Steve Pink',
#  'Princeton Holt',
#  'Alex Proyas',
#  'Jehane Noujaim',
#  'Diego Iván Andrade',
#  'Marcus Dunstan',
#  'Téo Frank',
#  'Matthew R. Anderson',
#  'Joe Marino',
#  'Mona Fastvold',
#  'Andrew Steggall',
#  'Panos Cosmatos',
#  'Eric Piccoli',
#  'Roberta Grossman',
#  'Mikel Rueda',
#  'Katie Aselton',
#  'Robert Heath',
#  'David DeCoteau',
#  'Richard J. Martinez',
#  'K. King',
#  'Jonathan Meyers',
#  'Stefan C. Schaefer',
#  'Robert Hall',
#  'Jeffrey St. Jules',
#  'Jyri Kähönen',
#  'Tommy Oliver',
#  'Marjorie Conrad',
#  'Luis Enrique Rodríguez',
#  'Nick Love',
#  'Caryn Waechter',
#  'Simeon Rice',
#  'Éric Toledano',
#  'David Cross',
#  'Wajahat Rauf',
#  'Ann P Meredith',
#  'Vera Farmiga',
#  'Fred Carpenter',
#  'Allison Burnett',
#  'Nick Tomnay',
#  'Laurent Bouhnik',
#  'Benjamin Dickinson',
#  'Sanjay Rawal',
#  'Johnny Remo',
#  'Christopher Henze',
#  'Kat Coiro',
#  'Peter Sattler',
#  'Lee Kirk',
#  'Blair Erickson',
#  'Darby Christensen',
#  "Natalie Bible'",
#  'Jason King',
#  'Kristian Day',
#  'Shane Dawson',
#  'H.M. Coakley',
#  'Sardar Shafai',
#  'Mick Jackson',
#  'Max Nichols',
#  'Lee Hirsch',
#  'Anthony Powell',
#  'Michael D. Akers',
#  'Anbarasan',
#  'Tony Goldwyn',
#  'Bill Benenson',
#  'Pieter Gaspersz',
#  'Travis Romero',
#  'Steve Taylor',
#  'Lance McDaniel',
#  'Michael Walker',
#  'Tim Sisarich',
#  'Nick Weiss',
#  'Johanna Schwartz',
#  'Rob Zombie',
#  'Lisa Azuelos',
#  'Richard Montoya',
#  'U. Roberto Romano',
#  'Blaz Zavrsnik',
#  'Matt Walsh',
#  'Pan Nalin',
#  'Gergö Elekes',
#  'Noel J. Rainford',
#  'Allen Hughes',
#  'Tom Silva',
#  'Warren Sheppard',
#  'Eric England',
#  'Alec Asten',
#  'Carman Spoto',
#  'Chris Petropoulos',
#  'William Gazecki',
#  'Michael Hoffman Jr.',
#  'Jack Heller',
#  'Darren Lynn Bousman',
#  'Matt Jackson',
#  'Amber Benson',
#  'Justin Paul Miller',
#  'Joel Paul Reisig',
#  'Allan Katz',
#  'Matthew Charles Santoro',
#  'Alex Craig Mann',
#  'Catherine Gund',
#  'Scott Hercman',
#  'Ramaa Mosley',
#  'Tim Lowry',
#  'Randy Moore',
#  'Steven R. Monroe',
#  'Dylan Baker',
#  'Matthew Watts',
#  'Amat Escalante',
#  'Joshua Overbay',
#  'Oren Kaplan',
#  'Yasu Shibuya',
#  'Jeffrey Blitz',
#  'Maryam Touzani',
#  'Kalyaan',
#  'Chad Kapper',
#  'Molly Bernstein',
#  'Kwiduck Lee',
#  'Dean Duncan',
#  'Jerome Elston Scott',
#  'Donna R. Clark',
#  'Daniel Columbie',
#  'Jack Perez',
#  'Pamela J. Richardson',
#  'Colin Downey',
#  'Bruce Dellis',
#  'Ken Del Conte',
#  'Eric Mendelsohn',
#  'Andrew Hyatt',
#  'Tom Seidman',
#  'Edward E. Romero',
#  'Sam Martin',
#  'Kristin Rizzo',
#  'Adam Rifkin',
#  "James O'Brien",
#  'Corbin Bernsen',
#  'Zoran Lisinac',
#  'Chris Mason Johnson',
#  'Daniel Garcia',
#  'Ken Roht',
#  'Darren Press',
#  'Thomas L. Phillips',
#  'Sharon Greytak',
#  'Gregory W. Friedle',
#  'Marcel Wehn',
#  'Jay Coster',
#  'Marius A. Markevicius',
#  'Michael Polish',
#  'Amir Bar-Lev',
#  'Eric Bugbee',
#  'Noah Buschel',
#  'Cary Bell',
#  'Deborah Anderson',
#  'Mike Cahill',
#  'Sara Newens',
#  'Kelly Reichardt',
#  'Valentine',
#  'Amal Al-Agroobi',
#  'Sai Varadan',
#  'Roze',
#  'Jennifer Blanc-Biehn',
#  'Steve Lickteig',
#  'Marcin Teodoru',
#  'Patrick Ryan Sims',
#  'James Swirsky',
#  'Wade Gasque',
#  'Joe Swanberg',
#  'Jason Miller',
#  'Michael Carney',
#  'Brett Piper',
#  'Etan Cohen',
#  'Andrew Herwitz',
#  'Kirk Loudon',
#  'Mike Flanagan',
#  'Jason Trost',
#  'Terron R. Parsons',
#  'Luciangela Gatto',
#  'Daniel Schechter',
#  'Matt Johnson',
#  'Zak Forsman',
#  'Patrick Meaney',
#  'Collin Joseph Neal',
#  'Dave Carroll',
#  'Malcolm Goodwin',
#  'Chad Hartigan',
#  'Jem Cohen',
#  'E.L. Katz',
#  'Ela Thier',
#  'Mark Jenkin',
#  'Daishi Matsunaga',
#  'Travis Legge',
#  'Madoka Raine',
#  'Damir Catic',
#  'Rick Montano',
#  'Craig Wyting',
#  'Joseph Mazzella',
#  'Timothy McNeil',
#  'Paul Devlin',
#  'Brandon Landers',
#  'Jim Chuchu',
#  'Zarina Tadjibaeva',
#  'Edward Burns',
#  'Benjamin Roberds',
#  'Anna Rose Holmer',
#  'Svetlana Proskurina',
#  'Nicole Mosleh',
#  'Ryan Gosling',
#  'Ray Griggs',
#  'Chan-wook Park',
#  'Ava DuVernay',
#  'Johann Buchholz',
#  'Maryam Keshavarz',
#  'Ulrika Bengts',
#  'Bill Yip',
#  'Andrea Molaioli',
#  'Steven Knight',
#  'Trey Edward Shults',
#  'Graham Wright',
#  'Jamie Bailey',
#  'Colin Minihan',
#  'Gia Coppola',
#  'P.C. Shekar',
#  'Quentin Dupieux',
#  'Robin Bissell',
#  'Christine Cynn',
#  'Leos Carax',
#  'Patrick Doughtie',
#  'Miranda July',
#  'Köken Ergun',
#  'Ti West',
#  'Vincent Lannoo',
#  'Marielle Heller',
#  'Dallas Jenkins',
#  'Rossana Patrizia Siclari',
#  'Koert Davidse',
#  'Gerardo Naranjo',
#  'Lena Dunham',
#  'R. Samala',
#  'Brett Haley',
#  'Sean Spencer',
#  'Warren Badenski',
#  'Geremy Jasper',
#  'Douglas McGrath',
#  'Sofie Stougaard',
#  'Paul Costes',
#  'Christopher Landon',
#  'Craig Zobel',
#  "Cris D'Amato",
#  'Sean Anders',
#  'Zach Braff',
#  'Joseph Dorman',
#  'Ryan McDonough',
#  'Michael Petrone',
#  'Daniel Armstrong',
#  'Brillante Mendoza',
#  'Brad J. Silverman',
#  'Steven Summers',
#  'Tom Putnam',
#  'Hilary Linder',
#  'Jed I. Goodman',
#  'David M. Matthews',
#  'Jayaraaj',
#  'Rodrigo García',
#  'Dror Moreh',
#  'Dawn',
#  'Stephen Armourae',
#  'John Cameron Mitchell',
#  'Alfonso Gomez-Rejon',
#  'Anne Fletcher',
#  'Lapo Melzi',
#  'Farren Blackburn',
#  'Andrew Erwin',
#  'Mario DeAngelis',
#  'Ricardo Martinez',
#  'Joe Wright',
#  'Van M. Pham',
#  'Nicole Holofcener',
#  'Chad Zuver',
#  'Michael Moore',
#  'Michael Cuesta',
#  'Chia-Chien Chen',
#  'Will Canon',
#  'Conor Allyn',
#  'Yolanda Torres',
#  'Lorene Scafaria',
#  'Lea Glob',
#  'Mark Neveldine',
#  'Ron Fricke',
#  'Vince Rotonda',
#  'Stephan Elliott',
#  'David G. Evans',
#  'Derek Cianfrance',
#  'Nima Nourizadeh',
#  'Gillian Robespierre',
#  'Matt Brown',
#  'Jake Schreier',
#  'Matt Piedmont',
#  'Jan Verheyen',
#  'Jokes Yanes',
#  'Hans Petter Moland',
#  'Maggie Carey',
#  'Tony Glazer',
#  'Richard Ayoade',
#  'Bryan Singer',
#  'Isao Yukisada',
#  'Lu Yaeger',
#  'Thomas Balmès',
#  'Joe Nussbaum',
#  'Adam Ethan Crow',
#  'Dan Kwan',
#  'Lynn Shelton',
#  'Lilly Wachowski',
#  'Andrew Adamson',
#  'Nicholas P. Richards',
#  'Mark Vadik',
#  'Hrant Yeritskinyan',
#  'Paul Emami',
#  'Murat Eroglu',
#  'Stuart McDonald',
#  'Stuart Cameron',
#  'Laron Green',
#  'Tate Taylor',
#  'Patricia Riggen',
#  'J.A. Bayona',
#  'Drake Doremus',
#  'Alyssa Baxter-Williams',
#  'Todd Graff',
#  'Colin Trevorrow',
#  'J.D. Dillard',
#  'Jonathan Levine',
#  'Lynne Ramsay',
#  'Wenjian Ding',
#  'Slawomir Fabicki',
#  'Steve Gomer',
#  'Blair Treu',
#  'Richard Linklater',
#  'Deniz Gamze Ergüven',
#  'Justin Simien',
#  'Tonny Trimarsanto',
#  'Corey Harrell',
#  'Peter Swanson',
#  'Jung-bum Park',
#  'Parker Dorris',
#  'Eli Roth',
#  'Roger Kumble',
#  'Jennifer Yuh Nelson',
#  'Brad Peyton',
#  'James Ponsoldt',
#  'Sean Durkin',
#  'Enrique Begné',
#  'James McTeigue',
#  'Nick Moran',
#  'Rogeria Inocencio',
#  'Patrick Hogan',
#  'Ivan Reitman',
#  'Sylvain White',
#  'Andrew Traucki',
#  'Gareth Edwards',
#  'Jennifer Barbaro',
#  'Jakub Paczek',
#  'Ricardo de Montreuil',
#  'Wayne Wang',
#  'Ben Stiller',
#  'Mabrouk El Mechri',
#  'Jennifer Kent',
#  'David Matthew Weese',
#  'Rohit Jugraj',
#  'In-ho Hwang',
#  'Danny Boyle',
#  'Rashard Mendenhall',
#  'Shana Feste',
#  ...]

# %% [markdown]
# ## Creating a Dictionary of Directors with a List of their Profits in Each of their Films

# %%
directors_profits = dict(zip(movie_clean_df.director_name, movie_clean_df.estimated_profit))
directors_profits
# Out:
# {'Simon Kinberg': -200237650,
#  'Simon Wells': -110450242,
#  'F. Gary Gray': 984846267,
#  'David Ayer': 571059887,
#  'Chris Sanders': 438068425,
#  'Edwine Dorival': -79448583,
#  'Andrey Konchalovskiy': -69533984,
#  'Xiao Feng': -64483721,
#  'Chris Wedge': 162794441,
#  'Landen Wakil': -61583254,
#  'Richard Gilliam': -60376918,
#  'Frank Coraci': 90805525,
#  'Chris Jordan': -59500000,
#  'Nonzee Nimibutr': -53296816,
#  'Robert Schwentke': 30891409,
#  'Michael Mann': -50334996,
#  'Reed Morano': -50000000,
#  'James Gray': -8414989,
#  'Quentin Lee': -49318920,
#  'Emilio Roso': -48884073,
#  'Micah Fink': -48572910,
#  'Zakary Hallett': -45183506,
#  'Lawrence Kasanoff': -44926294,
#  'Neil Corbin': -44373310,
#  'Michael B. Clifford': -43467226,
#  'Ben Affleck': 182640757,
#  'Daniel Espinosa': 123542162,
#  'Nic Good': -40515477,
#  'Jess Carson': -40187130,
#  'John Crowley': 51076141,
#  'Alex Alessi': -39920877,
#  'Elizabeth Berry': -39640994,
#  'Emilio Rodriguez': -39536270,
#  'Mario Van Peebles': -2270616,
#  'Jimmy Hayward': 55387072,
#  'Ash Brannon': -35851512,
#  'Amanda Boyle': -35787201,
#  'Guy Ritchie': 437234314,
#  'Roland Joffé': -31979010,
#  'Mikael Håfström': 60143987,
#  'Werner Herzog': -34421457,
#  'Joel Schumacher': -34213468,
#  'Seok-hoon Lee': -33658175,
#  'Sngmoo Lee': -33485675,
#  'Peter Berg': 109804632,
#  'David Frankel': 103085295,
#  'Gabriele Muccino': -33000000,
#  'Robbie Pickering': -32929042,
#  'Jean-Pierre Jeunet': -32642313,
#  'Walter Hill': -32402031,
#  'Robert Zemeckis': 129558438,
#  'Matt Kendrick': -31657368,
#  'Joe Cornish': -6540817,
#  'Guel Arraes': -30147513,
#  'Andrew Tiernan': -29936195,
#  'Frédéric Auburtin': -29831168,
#  'William Winckler': -29689015,
#  'David Koepp': -3606799,
#  'Khurram H. Alavi': -29351401,
#  'Jeff Stenzel': -29000000,
#  'Willie Ying': -27686691,
#  'Megan Freels Johnston': -27507986,
#  'Michael Gieleta': -27000000,
#  'Brad Furman': 47145086,
#  'Gary Ross': 597923379,
#  'Jinglei Xu': -26746567,
#  'Marcus Nispel': 464792,
#  'Darren Lynch': -26491142,
#  'Brian De Palma': -26425943,
#  'Marc Forster': 341514650,
#  'Michael Winterbottom': -9382723,
#  'David O. Russell': 217878294,
#  'Simon West': 211979256,
#  'Musing Derick Tenn': -25057578,
#  'Sebastián Lelio': -25032507,
#  'Jonathan Newman': -25000000,
#  'Eugene Jarecki': -25000000,
#  'Laya Yourgou': -24908884,
#  'Jacques Audiard': -1295643,
#  'Taylor Hackford': 13543388,
#  'Charles Uwagbai': -24587877,
#  'Frank Miller': -24349158,
#  'James Holden': -24219674,
#  'Doug Liman': 192541256,
#  'David Gordon Green': 62514401,
#  'George Nolfi': 76731325,
#  'June Daguiso': -23733302,
#  'Robert Luketic': 20572749,
#  'Juan Solanas': -23612961,
#  'Rickey Colbert': -23584344,
#  'Bruce Robinson': -23455268,
#  'Pierre Coré': -23328075,
#  'Carl Rinsch': -23283185,
#  'Tom Tykwer': 28673154,
#  'Kaya Purohit': -23083131,
#  'Kim Homer Garcia': -23076041,
#  'Martin Scorsese': 289870414,
#  'Sharon Maymon': -22514515,
#  'Pedro Morelli': -22493812,
#  'Werner Kriegelstein': -21785949,
#  'Pierre Morel': 26800758,
#  'Richard Lanni': -21354043,
#  'Paco R. Baños': -21316034,
#  'Seung-wan Hong': -21269076,
#  "Gavin O'Connor": 112962083,
#  'Richard J. Lewis': -21154425,
#  'Dan Gilroy': 41834418,
#  'Thijs Meuwese': -20982604,
#  'Anthony Roemermann': -20894793,
#  'Craig Gillespie': 42797409,
#  'George Mendeluk': -20393838,
#  'Kelly Asbury': 137578586,
#  'Rob Hawk': -20000000,
#  'Tom Walsh': -20000000,
#  'Ohad Milstein': -19915768,
#  'Rachel Lambert': -19903179,
#  'Bill Condon': -19845828,
#  'Susanne Bier': -19800000,
#  'Farhad Safinia': -19772767,
#  'Julie Taymor': -19722057,
#  'Jonathan English': -19702589,
#  'Kimble Rendall': -19528031,
#  'Radu Mihaileanu': -19523376,
#  'Matt Marshall': -19245699,
#  'Brian Robbins': -19209514,
#  'Andrew Jarecki': -19126383,
#  'Kumar Saroj': -18682235,
#  'Puri Jagannadh': -18326623,
#  'Brook Susan Parker': -18296719,
#  'Justin Chadwick': -5109598,
#  'Brian A. Miller': 10883171,
#  'Jon Cassar': 20768449,
#  'John Curran': -17934980,
#  'David Hayter': -17905047,
#  'Rodney Gray': -17835005,
#  'Angelo Pizzo': -17754000,
#  'Chuck Russell': -17690392,
#  'Denis Villeneuve': 156127894,
#  'Rob Reiner': -79987,
#  'Nick Hamm': -17383131,
#  'Veena Sud': -17323302,
#  'Matthew Heineman': -17174509,
#  'Paul China': -17000000,
#  'Dan Bradley': -16835850,
#  'Todd Robinson': -16800490,
#  'Angelina Jolie': -16272254,
#  'Rupert Wyatt': 377986200,
#  'Patrick-Mario Bernard': -15968369,
#  'Jodie Foster': 66466095,
#  'Amy Heckerling': -15905188,
#  'Kai Nagata': -15827101,
#  'Veronika Kaserer': -15707086,
#  'Walter Salles': -15686698,
#  'Matthew Campagna': -15598587,
#  'J.W. Myers': -15593868,
#  'Eric Williams': -15516210,
#  'Ron Shelton': -15243588,
#  'Tom Vaughan': -15173016,
#  'Gurinder Chadha': -8357061,
#  'Gore Verbinski': 110724600,
#  'Vidhu Vinod Chopra': -14996529,
#  'Kim Strobl': -14982738,
#  'Jonathan Jakubowicz': -14968025,
#  'Darrell Roodt': -14938153,
#  'James Franco': 18717667,
#  'Ken Kwapis': 29119358,
#  'Christian Rivers': -14712583,
#  'Erik D. Bateman': -14654131,
#  'Oliver Stone': 37513490,
#  'Mira Nair': -4944519,
#  'Stefano Mordini': -14313571,
#  'Igor Kinko': -14278659,
#  'Jérôme Salle': -14155772,
#  'Anand Vrs Tomar': -14081258,
#  'Kevin Munroe': -13906275,
#  'Yossi Madmoni': -13900000,
#  'Tim Kirkby': -13896325,
#  'Dito Montiel': -13851422,
#  'Miguel Sapochnik': -13804762,
#  'Jin-ho Hur': -13752421,
#  'Rod Lurie': -13746179,
#  'Stephen Petrillo': -13733033,
#  'Ki-duk Kim': 88521733,
#  'Ty Hunter': -13627243,
#  'Eylem Sen': -13594968,
#  'Scott Walker': -13582540,
#  'Alexander Payne': 155507800,
#  'Peter Chelsom': -13518595,
#  'Joseph Kosinski': 167916633,
#  'Kenneth Lonergan': 69233867,
#  'Tom Shkolnik': -13341294,
#  'Mark Gustafson': -13318189,
#  'S.S. Rajamouli': 233502914,
#  'Daniel Barnz': 21028230,
#  'Hyung-rae Shim': -13235753,
#  'Lee Tamahori': -13134354,
#  'Dylan Chandler': -13117304,
#  'Moon Si-Hyun': -13089292,
#  'Andrea Di Stefano': -13082321,
#  'Benedek Fliegauf': -13000000,
#  'Olivier Marchal': -13000000,
#  'Luca Guadagnino': -12965385,
#  'Marco Carmel': -12628809,
#  'Vijay Krishna Acharya': -12276380,
#  'Robert Lorenz': -12181087,
#  'Brian Trenchard-Smith': -12000000,
#  'Tristan Patterson': -12000000,
#  'Timothy Hines': -11985384,
#  'Felix van Groeningen': -11968576,
#  'Alex Garland': 25358392,
#  'Renny Harlin': -11046681,
#  'Myles Humphus': -11803143,
#  'Carl Walins': -11715669,
#  'Michael Apted': 263186950,
#  'Roland Emmerich': 219169424,
#  'Moshe Zeevi': -11624365,
#  'Barry Levinson': -11613847,
#  'Cameron Crowe': 68729073,
#  'Ernesto Aguilar': -11563237,
#  'Marcel Rasquin': -11549406,
#  'D.J. Caruso': 260033359,
#  'Michael Dowse': -11423396,
#  'Nicole Kassell': -11399713,
#  'Neil Johnson': -11378812,
#  'Burr Steers': 4478084,
#  'David Serero': -11234415,
#  'J.C. Chandor': 17033227,
#  'Abeer Zeibak Haddad': -11005210,
#  'Yuvaraj Dhayalan': -11000000,
#  'Julie Winokur': -10876140,
#  'Bruce Ramsay': -10870330,
#  'Jonathan Hensleigh': -10811806,
#  'Lawrence Kasdan': -10799654,
#  'Meng Zhang': -10791124,
#  'Rowan Joffe': -2436421,
#  'Trae Briers': -10486612,
#  'Akiva Schaffer': 12130045,
#  'Matthijs van Heijningen Jr.': -10426922,
#  'Yuka Matsushima': -10405045,
#  'Niels Arden Oplev': 35308153,
#  'Ruairi Robinson': -10338636,
#  'Jeff Nichols': 21556959,
#  'Alejandro G. Iñárritu': 397938302,
#  'Ron Howard': 118151347,
#  'John Madden': 124639780,
#  'George Hickenlooper': -10227814,
#  'Kasi Lemmons': -10214865,
#  'Dan Cordle': -10194188,
#  'Tom Donahue': -10014684,
#  'David Hackl': -10000000,
#  'Douglas Aarniokoski': -10000000,
#  'James D.R. Hickox': -10000000,
#  'Jim Issa': -10000000,
#  'Kate Kaminski': -9980747,
#  'Robin Aubert': -9937594,
#  'Jeb Stuart': -9890617,
#  'Konrad Lecki': -9885099,
#  'Justin Tipping': -9849809,
#  'Kim Farrant': -9838903,
#  'Rafa Lara': -9826528,
#  'Michael Radford': -9802099,
#  'Adam Starks': -9800895,
#  'Alexis Michalik': -9758281,
#  'Eric Lavaine': -9752435,
#  'John Stalberg Jr.': -9751867,
#  'Michael Grandage': -9734717,
#  'Glenn Ficarra': -9649253,
#  'Jake Scott': -9644081,
#  'Mauricio De la Orta': -9639102,
#  'Charlotte Sieling': -9606304,
#  'Valeri Milev': -9500000,
#  'Cyrus Nowrasteh': -9486303,
#  'Jean Lee': -9478590,
#  'William Phillips': -9441946,
#  'Jose Carlos Gomez': -9424629,
#  'Joseph P. Stachura': -9406527,
#  'Ben Younger': -9396074,
#  'Roqiyeh Tavakoli': -9276612,
#  'Robert Redford': -9092589,
#  'Hernan Jimenez': -9046114,
#  'Rob Cohen': 49401938,
#  'Shannon Keith': -8998758,
#  'Adam Shankman': 49911903,
#  'Patrick Lussier': -8957417,
#  'Jim Wilson': -8930546,
#  'Nimród Antal': 87234389,
#  'Paul McGuigan': -8875633,
#  'Craig Anderson': -8815745,
#  'Desiree Lim': -8807575,
#  'Shintaro Shimosawa': -8647489,
#  'Lee Daniels': 147025498,
#  'Peter Landesman': -8383647,
#  'Jeff Bemiss': -8357834,
#  'Graeme Higginson': -8340066,
#  'Babak Najafi': 135194085,
#  'Wes Craven': 55989590,
#  'Shyamaprasad': -8175367,
#  'Line Hatland': -8164400,
#  'Mikael Kreuzriegler': -8155621,
#  'Chris Weitz': -8115749,
#  'Michael Winnick': -8000000,
#  'Jordan Roberts': -8000000,
#  'Oleg Sentsov': -7997971,
#  'Taika Waititi': 666980024,
#  'Adrienne Nelson': -7969390,
#  'Keith Parmer': -7955803,
#  'Ralph Fiennes': -7820377,
#  'Robert Chapin': -7786905,
#  'Tommy Lee Jones': -7782429,
#  'Claudia Llosa': -7762312,
#  'Sarik Andreasyan': -7658782,
#  'Anthony Hemingway': -7634502,
#  'Mathew Cullen': -7566268,
#  'Tamar Simon Hoffs': -7500000,
#  'Sacha Bennett': -7486476,
#  'Tom Brady': -7470605,
#  'Jeta Amata': -7467428,
#  'Nadeem Soumah': -7447745,
#  'Joe Johnston': 230569776,
#  'Ben Hernandez Bray': -7299739,
#  'Ross Venokur': -7146713,
#  'Neil Marshall': 39823958,
#  'David L. Hunt': -1750000,
#  'Kim Nguyen': -6817727,
#  'Jon Stewart': -6814283,
#  'David Batty': -6765645,
#  'Jason Zeldes': -6724415,
#  'Sebastian Klinger': -6642676,
#  'Adrian Noble': -6621859,
#  'Spencer Susser': -6617054,
#  'Jackie Earle Haley': -6613256,
#  'Scott Cooper': 45837872,
#  'Valerie Faris': -6554621,
#  'Shari Springer Berman': -6507892,
#  'Ian Sharp': -6496851,
#  'Chris Tyrrell': -6458435,
#  'Ho-Cheung Pang': -6435852,
#  'Ariel Vromen': -6376391,
#  'Todd Lincoln': -6362719,
#  'Alain Desrochers': -6280301,
#  'Louis Leterrier': 368214888,
#  'Alex Gonzales': -6264471,
#  'Ben Wheatley': -337794,
#  'Courtney Solomon': -6186011,
#  'David R. Ellis': -6122847,
#  'Scott Mann': -6093183,
#  'Ed Nouwen': -6078950,
#  'Jonathan Glazer': -6070067,
#  'Stanley Kwan': -6051235,
#  'Christopher Wilkinson': -6001774,
#  'Charles Matthau': -6000000,
#  'Bryan Fogel': -6000000,
#  'William Kaufman': -6000000,
#  'Mikey Schaefer': -5989020,
#  'Raj Thiruselvan': -5973993,
#  'V.K. Prakash': -5865491,
#  'Julie Anne Robinson': 72678948,
#  'Christopher M. Bessette': -5784909,
#  'Francis Ford Coppola': -5731654,
#  'Tim Dünschede': -5701776,
#  'Rick Bieber': -5591841,
#  'Kate Barker-Froyland': -5562911,
#  'Jeremy Sims': -5559061,
#  'Andrew Haigh': 1387585,
#  'Marçal Forés': -5500000,
#  'Hitoshi Matsumoto': -5475044,
#  'George Ratliff': -5471532,
#  'Karen Oganesyan': -5454879,
#  'Bettie Wilde': -5446814,
#  'Stewart Hendler': -5436920,
#  'Taylor Hayden': -5433754,
#  'Mauricio Hernandez': -5396999,
#  'William Friedkin': -5340890,
#  'Mohamed Khan': -5338536,
#  'David Michôd': 3878683,
#  'Karyn Kusama': -645164,
#  'Frank Wolf': -5309198,
#  'Mark Duplass': -5291873,
#  'Andrea Arnold': -888250,
#  'Peter Sollett': -5267772,
#  'Paul Thomas Anderson': 13147416,
#  'Gus Van Sant': -2605438,
#  'David Cronenberg': -5192469,
#  'Richard Shepard': -5142542,
#  'Jane Alexandra Foster': -5077957,
#  'Stewart Raffill': -5068194,
#  'John Stephenson': -5066171,
#  'Reg Traviss': -5017320,
#  'Dan Garcia': -5000000,
#  'Michael Anderson': -5000000,
#  'Scott Sanders': -5000000,
#  'Marc Bennett': -5000000,
#  'Scott Foley': -5000000,
#  'John Herzfeld': -5000000,
#  'Vicky Jewson': -5000000,
#  'Barrett Esposito': -5000000,
#  'Oren Peli': -4992444,
#  'Rodger Edralin': -4991703,
#  'Kevin Smith': 18909910,
#  'Ryszard Bugajski': -4947042,
#  'David Lam': -4946670,
#  'Michael Courtney': -4932495,
#  'Paul Schrader': 374772,
#  'Jon Wright': -4859179,
#  'Jon Watts': 705166350,
#  'David Sudmalis': -4850869,
#  'Olivier Dahan': -4800109,
#  'Ody C. Harahap': -4783045,
#  'Ahmet Boyacioglu': -4758685,
#  'Kade Mendelowitz': -4755048,
#  'Nick Park': -4714110,
#  'Gabriela Tagliavini': -4700000,
#  'Analeine Cal y Mayor': -4700000,
#  'Mikael Berg': -4636105,
#  'Matthew A. Brown': -4634892,
#  'Don Scardino': -4607391,
#  'Gary McKendry': -4590954,
#  'Adam Vermillion': -4572344,
#  'Beth LaMure': -4500000,
#  'Todd Strauss-Schulson': 16265745,
#  'Mora Stephens': -4500000,
#  'Kabir Sadanand': -4500000,
#  'Duane Journey': -4500000,
#  'Ernie Barbarash': -4488226,
#  'Brandon Slagle': -4439488,
#  'William H. Macy': -4432781,
#  'Larry Rosen': -4346385,
#  'Stefan Ruzowitzky': -4326365,
#  'Floria Sigismondi': -4221368,
#  'Ernest Holzman': -4218553,
#  'Alejandro Amenábar': -4175626,
#  'Noah Scott': -4168107,
#  'James Manera': -4148310,
#  'Yann Demange': -4052017,
#  'Dany Gehshan': -4049998,
#  'Bruce Macdonald': -4000000,
#  'Jeffrey Nachmanoff': -4000000,
#  'Brent Ryan Green': -4000000,
#  'Kevin Carraway': -4000000,
#  'Ruba Nadda': -3995673,
#  'Larisa Sadilova': -3982361,
#  'Lawrence Sher': -3961559,
#  'Daniel Stamm': 68365900,
#  'Nicolas Winding Refn': 66357930,
#  'Daryush Shokof': -3936820,
#  'David Lowery': 2669782,
#  'Kevin Connolly': -3910900,
#  'Yan Vizinberg': -3886770,
#  'David Schwimmer': -3879984,
#  'Edoardo Leo': -3868233,
#  'Mark Romanek': -3826282,
#  'Jaan Tootsen': -3815600,
#  'Jason Reitman': 10750356,
#  'Nisha Ganatra': -3753695,
#  'Roberto Santucci': -3602635,
#  'Julian Gilbey': -3557450,
#  'Pete Travis': -3532394,
#  'Kaf': -3500000,
#  'Daniel Petrie Jr.': -3500000,
#  'Chris Jaymes': -3495040,
#  'Muyiwa Aluko': -3476729,
#  'Henry Hobson': -3472240,
#  'Zal Batmanglij': 294448,
#  'Charles Ferguson': 5799257,
#  'Prachya Pinkaew': -3459378,
#  'Antonio Simoncini': -3440000,
#  'Richard Raymond': -3403665,
#  'Yash Chopra': -3393334,
#  'Saad Hendawy': -3387928,
#  'Eldar Rapaport': -3387364,
#  'Taylor Grant': -3385046,
#  'Alex Kurtzman': 214953905,
#  'James Kent': -3353331,
#  'Timur Bekmambetov': 69989730,
#  'Jim Mickle': 175587,
#  'Warren P. Sonoda': -3317305,
#  'Mateo Gil': -3282693,
#  'Benson Lee': -3276623,
#  'Jennifer Finnigan': -3249794,
#  'Craig Johnson': 4797192,
#  'Rodrigo Cortés': 19282640,
#  'Jorge Dorado': -3157373,
#  'Sam Levinson': -3021473,
#  'Isaac Florentine': -3000000,
#  'Hank Braxtan': -3000000,
#  'Martin Rutley': -3000000,
#  'Fred Cavayé': -3000000,
#  'Gonzalo Albornoz': -3000000,
#  'Victor Teran': -3000000,
#  "Chris D'Arienzo": -3000000,
#  'Darin Scott': -3000000,
#  'Christian Sesma': -3000000,
#  'Yuki Otsuka': -2994861,
#  'Stuart Smith': -2979919,
#  'Brandon Cronenberg': -2976593,
#  'Marcio Garcia': -2952531,
#  'Michael Worth': -2921052,
#  'David Wain': -2917220,
#  'Bryan Buckley': -2884184,
#  'Leon Ford': -2874065,
#  'Qi Zhao': -2852009,
#  'Xavier Gens': -2843638,
#  'Arie Posin': -2841123,
#  'DeShawn Hill': -2836931,
#  'Josh Schwartz': -2833385,
#  'Drew Goddard': 40689968,
#  'Eric Wareheim': -2776348,
#  'Corey Piper': -2737935,
#  'Heidi Ewing': -2727133,
#  'Christophe Sahr': -2704507,
#  'Gabriel Soriano': -2693352,
#  'Jonathan Lynn': -2685806,
#  'Fred Andrews': -2669000,
#  'Michael Mongillo': -2660000,
#  'John Woo': -2645770,
#  'Gary Horton': -2633444,
#  'Jon M. Chu': 238325007,
#  'Nikita Sharma': -2609697,
#  'Joe Cross': -2600000,
#  'Youssef Delara': 1690411,
#  'Chris Hunter': -2543398,
#  'Chris Evans': -2516062,
#  'Rob Thomas': -2514617,
#  'Nathan Waters': -2509128,
#  'Zackary Adler': -2500000,
#  'Jaco Booyens': -2500000,
#  'Benni Diez': -2500000,
#  'Dominic Burns': -1200000,
#  'Jason Stone': -2500000,
#  'Danny Perez': -2500000,
#  'John Murlowski': -2500000,
#  'Paul Greengrass': 296168316,
#  'Jonathan Teplitzky': 5910210,
#  'Rita Merson': -2400000,
#  'Reed Cowan': -2399720,
#  'Maarten Wijsman': -2325745,
#  'Shapur Gharib': -2303854,
#  'Ulla Heikkilä': -2300000,
#  'Duke Johnson': -2293832,
#  'Drew Pearce': -2241201,
#  'Jesse Estrada': -2240304,
#  'Alejandro Monteverde': -2230701,
#  'Andrew Mogel': -2227634,
#  'Dan Rush': -2178990,
#  'Jason Eisener': -2165047,
#  'Jason Bateman': -2156855,
#  'Miguel Arteta': 73379287,
#  "Anthony O'Brien": -2100000,
#  'Glenn Ciano': -2100000,
#  'Dan Perri': -2100000,
#  'Robert Fontaine': -2096670,
#  'Gavin Wiesen': -2010965,
#  'Russell Friedenberg': -2000000,
#  'Coke Daniels': -2000000,
#  'James Cox': -2000000,
#  'Song Wang': -2000000,
#  'Michael Rochford': -2000000,
#  'Olga Lopato': -2000000,
#  'Alex Ranarivelo': -2000000,
#  'John J. Budion': -2000000,
#  'Brad Copeland': -2000000,
#  'Jonas Åkerlund': -2000000,
#  'Chris Shadley': -2000000,
#  'Sebastian Doggart': -2000000,
#  'Derick Martini': -2000000,
#  'Scott Dow': -2000000,
#  'Jerry Dugan': -2000000,
#  'Paul Bunnell': -1997564,
#  'Michael W. Watkins': -1989976,
#  'Qi Song': -1985007,
#  'Jonathan Kasdan': -1982939,
#  'Dean Wright': -1973745,
#  'Catherine Hardwicke': 49678442,
#  'Stephen Milburn Anderson': -1961744,
#  'Bill Muir': -1950368,
#  'Trevor Fleming': -1936445,
#  'Rebecca Harrell Tickell': -1927723,
#  'James Gunn': 600867516,
#  'Vijay Chandar': -1887556,
#  'Reginald Hudlin': -1883184,
#  'Cory Finley': -1812698,
#  'Corey Grant': -1800000,
#  'W.D. Hogan': -1800000,
#  'Curt Hahn': -1800000,
#  'Bill Guttentag': -1800000,
#  'Richard LaGravenese': 10282876,
#  'Robert Rodriguez': 232976036,
#  'Tina Gordon': -1692834,
#  'Whit Stillman': -1675701,
#  'Frank Pestarino': -1621147,
#  'Ice Idanan': -1614407,
#  'Mitzi Peirone': -1579255,
#  'Sreekanth S. Nair': -1577515,
#  'Jeffery Hauser': -1569178,
#  'Dan Fogelman': -1534155,
#  'S. Craig Zahler': -1524154,
#  'David Winning': -1500000,
#  'Tara Subkoff': -1500000,
#  'David Rodriguez': -1500000,
#  'Deryck Broom': -1500000,
#  'Arvin N. Berner': -1500000,
#  'Nae Caranfil': -1494604,
#  'Wayne W. Whited': -1493763,
#  'Patrick Epape': -1478413,
#  'Jamal Hill': -1421405,
#  'Ahsan Rahim': -1401194,
#  'David Worth': -1400000,
#  'Daryn Tufts': -1400000,
#  'Boris Rodriguez': -1398368,
#  'Adam Carolla': -1386831,
#  'Jorma Taccone': -1370105,
#  'Ryan Fleck': 948061550,
#  'Andrew Gurland': -1363294,
#  'Don Boyd': -1360916,
#  'William Eubank': -1334678,
#  'John Sayles': -1315295,
#  'Christopher Morris': -1313889,
#  'Giovanni Zelko': -1300000,
#  'Alexander Holt': -1286535,
#  'Gerard Johnstone': -1263137,
#  'Spike Lee': 78017335,
#  'Brenton Spencer': -1200000,
#  'Justin Thomas Ostensen': -1200000,
#  'Jay Alaimo': -1200000,
#  'Timothy A. Chey': -1200000,
#  'Dylan Bank': -1200000,
#  'Jeremy Saulnier': 17002,
#  'Marcel Walz': -1191292,
#  'Lluís Quílez': -1180572,
#  'Agnès Jaoui': -1173510,
#  'Léa Pool': -1173392,
#  'Steve Pink': 37445860,
#  'Princeton Holt': -1168869,
#  'Alex Proyas': -1163244,
#  'Jehane Noujaim': -1159068,
#  'Diego Iván Andrade': -1115197,
#  'Marcus Dunstan': -1109906,
#  'Téo Frank': -1107351,
#  'Matthew R. Anderson': -1100000,
#  'Joe Marino': -1100000,
#  'Mona Fastvold': -1097364,
#  'Andrew Steggall': -1072439,
#  'Panos Cosmatos': -1043509,
#  'Eric Piccoli': -1038779,
#  'Roberta Grossman': -1011249,
#  'Mikel Rueda': -1000000,
#  'Katie Aselton': -1000000,
#  'Robert Heath': -1000000,
#  'David DeCoteau': -1000000,
#  'Richard J. Martinez': -1000000,
#  'K. King': -1000000,
#  'Jonathan Meyers': -1000000,
#  'Stefan C. Schaefer': -1000000,
#  'Robert Hall': -1000000,
#  'Jeffrey St. Jules': -1000000,
#  'Jyri Kähönen': -1000000,
#  'Tommy Oliver': -1000000,
#  'Marjorie Conrad': -1000000,
#  'Luis Enrique Rodríguez': -1000000,
#  'Nick Love': 3500366,
#  'Caryn Waechter': -993130,
#  'Simeon Rice': -989043,
#  'Éric Toledano': -987004,
#  'David Cross': -984844,
#  'Wajahat Rauf': -982279,
#  'Ann P Meredith': -973178,
#  'Vera Farmiga': -957307,
#  'Fred Carpenter': -950000,
#  'Allison Burnett': -950000,
#  'Nick Tomnay': -948413,
#  'Laurent Bouhnik': -945000,
#  'Benjamin Dickinson': -936986,
#  'Sanjay Rawal': -912824,
#  'Johnny Remo': -903266,
#  'Christopher Henze': -900000,
#  'Kat Coiro': -899095,
#  'Peter Sattler': -898947,
#  'Lee Kirk': -892604,
#  'Blair Erickson': -871878,
#  'Darby Christensen': -847589,
#  "Natalie Bible'": -846744,
#  'Jason King': -842984,
#  'Kristian Day': -800000,
#  'Shane Dawson': -764312,
#  'H.M. Coakley': -750000,
#  'Sardar Shafai': -749550,
#  'Mick Jackson': -736060,
#  'Max Nichols': -731919,
#  'Lee Hirsch': -718176,
#  'Anthony Powell': -711243,
#  'Michael D. Akers': -701214,
#  'Anbarasan': -700000,
#  'Tony Goldwyn': -673020,
#  'Bill Benenson': -650000,
#  'Pieter Gaspersz': -650000,
#  'Travis Romero': -625000,
#  'Steve Taylor': -604982,
#  'Lance McDaniel': -600000,
#  'Michael Walker': -600000,
#  'Tim Sisarich': -600000,
#  'Nick Weiss': -596699,
#  'Johanna Schwartz': -592057,
#  'Rob Zombie': 41131,
#  'Lisa Azuelos': -568494,
#  'Richard Montoya': -557443,
#  'U. Roberto Romano': -556291,
#  'Blaz Zavrsnik': -551538,
#  'Matt Walsh': -546173,
#  'Pan Nalin': -540889,
#  'Gergö Elekes': -523540,
#  'Noel J. Rainford': -520750,
#  'Allen Hughes': -519955,
#  'Tom Silva': -518580,
#  'Warren Sheppard': -500000,
#  'Eric England': -500000,
#  'Alec Asten': -500000,
#  'Carman Spoto': -500000,
#  'Chris Petropoulos': -500000,
#  'William Gazecki': -500000,
#  'Michael Hoffman Jr.': -500000,
#  'Jack Heller': -500000,
#  'Darren Lynn Bousman': -500000,
#  'Matt Jackson': -500000,
#  'Amber Benson': -500000,
#  'Justin Paul Miller': -500000,
#  'Joel Paul Reisig': -250000,
#  'Allan Katz': -500000,
#  'Matthew Charles Santoro': -499472,
#  'Alex Craig Mann': -498222,
#  'Catherine Gund': -498178,
#  'Scott Hercman': -489029,
#  'Ramaa Mosley': -486267,
#  'Tim Lowry': -480200,
#  'Randy Moore': -478038,
#  'Steven R. Monroe': -471529,
#  'Dylan Baker': -450815,
#  'Matthew Watts': -450000,
#  'Amat Escalante': -447386,
#  'Joshua Overbay': -436514,
#  'Oren Kaplan': -407362,
#  'Yasu Shibuya': -400000,
#  'Jeffrey Blitz': -379601,
#  'Maryam Touzani': -365515,
#  'Kalyaan': -355548,
#  'Chad Kapper': -350000,
#  'Molly Bernstein': -347551,
#  'Kwiduck Lee': -313000,
#  'Dean Duncan': -310866,
#  'Jerome Elston Scott': -300000,
#  'Donna R. Clark': -300000,
#  'Daniel Columbie': -300000,
#  'Jack Perez': -300000,
#  'Pamela J. Richardson': -300000,
#  'Colin Downey': -298289,
#  'Bruce Dellis': -296504,
#  'Ken Del Conte': -290000,
#  'Eric Mendelsohn': -260525,
#  'Andrew Hyatt': 20529498,
#  'Tom Seidman': -250000,
#  'Edward E. Romero': -250000,
#  'Sam Martin': -250000,
#  'Kristin Rizzo': -250000,
#  'Adam Rifkin': -250000,
#  "James O'Brien": -250000,
#  'Corbin Bernsen': -250000,
#  'Zoran Lisinac': -246766,
#  'Chris Mason Johnson': -231177,
#  'Daniel Garcia': -200000,
#  'Ken Roht': -200000,
#  'Darren Press': -200000,
#  'Thomas L. Phillips': -200000,
#  'Sharon Greytak': -200000,
#  'Gregory W. Friedle': -196352,
#  'Marcel Wehn': -193740,
#  'Jay Coster': -191207,
#  'Marius A. Markevicius': -185556,
#  'Michael Polish': -183858,
#  'Amir Bar-Lev': -182335,
#  'Eric Bugbee': -175000,
#  'Noah Buschel': -172398,
#  'Cary Bell': -162497,
#  'Deborah Anderson': -150000,
#  'Mike Cahill': 1927779,
#  'Sara Newens': -144142,
#  'Kelly Reichardt': -130072,
#  'Valentine': -125000,
#  'Amal Al-Agroobi': -125000,
#  'Sai Varadan': -125000,
#  'Roze': -117073,
#  'Jennifer Blanc-Biehn': -100000,
#  'Steve Lickteig': -100000,
#  'Marcin Teodoru': -100000,
#  'Patrick Ryan Sims': -100000,
#  'James Swirsky': -100000,
#  'Wade Gasque': -100000,
#  'Joe Swanberg': -92900,
#  'Jason Miller': -79944,
#  'Michael Carney': -76395,
#  'Brett Piper': -75000,
#  'Etan Cohen': 66511453,
#  'Andrew Herwitz': -71905,
#  'Kirk Loudon': -66201,
#  'Mike Flanagan': 72831866,
#  'Jason Trost': -20000,
#  'Terron R. Parsons': -60000,
#  'Luciangela Gatto': -58138,
#  'Daniel Schechter': -55083,
#  'Matt Johnson': -55000,
#  'Zak Forsman': -50000,
#  'Patrick Meaney': -50000,
#  'Collin Joseph Neal': -50000,
#  'Dave Carroll': -50000,
#  'Malcolm Goodwin': -45000,
#  'Chad Hartigan': -42000,
#  'Jem Cohen': -41626,
#  'E.L. Katz': -40576,
#  'Ela Thier': -40000,
#  'Mark Jenkin': -39688,
#  'Daishi Matsunaga': -37395,
#  'Travis Legge': -22000,
#  'Madoka Raine': -35000,
#  'Damir Catic': -35000,
#  'Rick Montano': -30000,
#  'Craig Wyting': -25000,
#  'Joseph Mazzella': -25000,
#  'Timothy McNeil': -23453,
#  'Paul Devlin': -20000,
#  'Brandon Landers': -17300,
#  'Jim Chuchu': -15000,
#  'Zarina Tadjibaeva': -9473,
#  'Edward Burns': -4416,
#  'Benjamin Roberds': -1400,
#  'Anna Rose Holmer': -758,
#  'Svetlana Proskurina': 349,
#  'Nicole Mosleh': 1124,
#  'Ryan Gosling': 9644,
#  'Ray Griggs': 33588,
#  'Chan-wook Park': 34913,
#  'Ava DuVernay': 46776576,
#  'Johann Buchholz': 43618,
#  'Maryam Keshavarz': 58978,
#  'Ulrika Bengts': 80479,
#  'Bill Yip': 84596,
#  'Andrea Molaioli': 87521,
#  'Steven Knight': 88390,
#  'Trey Edward Shults': 14720203,
#  'Graham Wright': 128711,
#  'Jamie Bailey': 136870,
#  'Colin Minihan': 151887,
#  'Gia Coppola': 156309,
#  'P.C. Shekar': 170043,
#  'Quentin Dupieux': 180914,
#  'Robin Bissell': 205616,
#  'Christine Cynn': 227316,
#  'Leos Carax': 230426,
#  'Patrick Doughtie': 237452,
#  'Miranda July': 239174,
#  'Köken Ergun': 255538,
#  'Ti West': 261535,
#  'Vincent Lannoo': 268825,
#  'Marielle Heller': 1752387,
#  'Dallas Jenkins': 303792,
#  'Rossana Patrizia Siclari': 342000,
#  'Koert Davidse': 350641,
#  'Gerardo Naranjo': 362298,
#  'Lena Dunham': 374149,
#  'R. Samala': 410511,
#  'Brett Haley': 420962,
#  'Sean Spencer': 425707,
#  'Warren Badenski': 438663,
#  'Geremy Jasper': 471090,
#  'Douglas McGrath': 474463,
#  'Sofie Stougaard': 493216,
#  'Paul Costes': 545420,
#  'Christopher Landon': 120010260,
#  'Craig Zobel': 560700,
#  "Cris D'Amato": 571408,
#  'Sean Anders': 71736188,
#  'Zach Braff': 54672579,
#  'Joseph Dorman': 631261,
#  'Ryan McDonough': 667524,
#  'Michael Petrone': 724277,
#  'Daniel Armstrong': 762014,
#  'Brillante Mendoza': 791973,
#  'Brad J. Silverman': 807159,
#  'Steven Summers': 861785,
#  'Tom Putnam': 884276,
#  'Hilary Linder': 888305,
#  'Jed I. Goodman': 965996,
#  'David M. Matthews': 995644,
#  'Jayaraaj': 1000000,
#  'Rodrigo García': 1039003,
#  'Dror Moreh': 1092308,
#  'Dawn': 1109095,
#  'Stephen Armourae': 1176701,
#  'John Cameron Mitchell': 1205034,
#  'Alfonso Gomez-Rejon': 1266180,
#  'Anne Fletcher': 10671512,
#  'Lapo Melzi': 1319440,
#  'Farren Blackburn': 1360665,
#  'Andrew Erwin': 4391992,
#  'Mario DeAngelis': 1410835,
#  'Ricardo Martinez': 1495262,
#  'Joe Wright': 120807172,
#  'Van M. Pham': 1547570,
#  'Nicole Holofcener': 17621449,
#  'Chad Zuver': 1635247,
#  'Michael Moore': 1653715,
#  'Michael Cuesta': 5310140,
#  'Chia-Chien Chen': 1659955,
#  'Will Canon': 1668109,
#  'Conor Allyn': 1684207,
#  'Yolanda Torres': 1755271,
#  'Lorene Scafaria': 2326942,
#  'Lea Glob': 1818479,
#  'Mark Neveldine': 1929184,
#  'Ron Fricke': 1966671,
#  'Vince Rotonda': 2024321,
#  'Stephan Elliott': 2224539,
#  'David G. Evans': 2230735,
#  'Derek Cianfrance': 32011449,
#  'Nima Nourizadeh': 91028188,
#  'Gillian Robespierre': 2324070,
#  'Matt Brown': 2382122,
#  'Jake Schreier': 73450484,
#  'Matt Piedmont': 2446952,
#  'Jan Verheyen': 2502141,
#  'Jokes Yanes': 2511317,
#  'Hans Petter Moland': 2599159,
#  'Maggie Carey': 2628828,
#  'Tony Glazer': 2636443,
#  'Richard Ayoade': 2681937,
#  'Bryan Singer': 839985342,
#  'Isao Yukisada': 2700000,
#  'Lu Yaeger': 2733256,
#  'Thomas Balmès': 2746453,
#  'Joe Nussbaum': 2763183,
#  'Adam Ethan Crow': 2820000,
#  'Dan Kwan': 2837111,
#  'Lynn Shelton': 2970593,
#  'Lilly Wachowski': 2982519,
#  'Andrew Adamson': 3012862,
#  'Nicholas P. Richards': 3039258,
#  'Mark Vadik': 3062896,
#  'Hrant Yeritskinyan': 3083765,
#  'Paul Emami': 3187506,
#  'Murat Eroglu': 3190220,
#  'Stuart McDonald': 3237229,
#  'Stuart Cameron': 3265259,
#  'Laron Green': 3320293,
#  'Tate Taylor': 188120004,
#  'Patricia Riggen': 60798736,
#  'J.A. Bayona': 1135772799,
#  'Drake Doremus': 3478400,
#  'Alyssa Baxter-Williams': 3591500,
#  'Todd Graff': 3657914,
#  'Colin Trevorrow': 1433854864,
#  'J.D. Dillard': 3684450,
#  'Jonathan Levine': 85121608,
#  'Lynne Ramsay': 3765283,
#  'Wenjian Ding': 3793996,
#  'Slawomir Fabicki': 3898064,
#  'Steve Gomer': 3941994,
#  'Blair Treu': 4049171,
#  'Richard Linklater': 53273049,
#  'Deniz Gamze Ergüven': 4152584,
#  'Justin Simien': 4153771,
#  'Tonny Trimarsanto': 4206732,
#  'Corey Harrell': 4231215,
#  'Peter Swanson': 4241309,
#  'Jung-bum Park': 4299670,
#  'Parker Dorris': 4302995,
#  'Eli Roth': 18575965,
#  'Roger Kumble': 4340177,
#  'Jennifer Yuh Nelson': 514837547,
#  'Brad Peyton': 346258539,
#  'James Ponsoldt': 4416951,
#  'Sean Durkin': 4438911,
#  'Enrique Begné': 4445044,
#  'James McTeigue': 45411620,
#  'Nick Moran': 4688384,
#  'Rogeria Inocencio': 4714370,
#  'Patrick Hogan': 4719990,
#  'Ivan Reitman': 124228078,
#  'Sylvain White': 41723644,
#  'Andrew Traucki': 5037867,
#  'Gareth Edwards': 849102856,
#  'Jennifer Barbaro': 5182050,
#  'Jakub Paczek': 5209334,
#  'Ricardo de Montreuil': 5272421,
#  'Wayne Wang': 5348205,
#  'Ben Stiller': 96861183,
#  'Mabrouk El Mechri': 5361206,
#  'Jennifer Kent': 5482387,
#  'David Matthew Weese': 5489826,
#  'Rohit Jugraj': 5500000,
#  'In-ho Hwang': 5500000,
#  'Danny Boyle': 67006296,
#  'Rashard Mendenhall': 5600000,
#  'Shana Feste': 14718173,
#  ...}

# %%
sorted(directors_profits, key=directors_profits.get, reverse=True)
# Out:
# ['Atsushi Wada',
#  'Pete Meads',
#  'Anthony Russo',
#  'Colin Trevorrow',
#  'James Wan',
#  'Joss Whedon',
#  'Ryan Coogler',
#  'J.A. Bayona',
#  'Adam Green',
#  'Christophe Gans',
#  'Pierre Coffin',
#  'Brad Bird',
#  'Shane Black',
#  'F. Gary Gray',
#  'Kyle Balda',
#  'Ryan Fleck',
#  'Michael Bay',
#  'Sam Mendes',
#  'Jon Favreau',
#  'Jake Kasdan',
#  'Jared Bush',
#  'Lee Unkrich',
#  'Gareth Edwards',
#  'Bryan Singer',
#  'Tim Burton',
#  'Andrew Stanton',
#  'Chris Renaud',
#  'Christopher Nolan',
#  'Jun Falkenstein',
#  'Mike Thurmeier',
#  'Peter Jackson',
#  'Tim Miller',
#  'Ruben Fleischer',
#  'Francis Lawrence',
#  'Jon Watts',
#  'Artie Mandelberg',
#  'David Leitch',
#  'Patty Jenkins',
#  'Taika Waititi',
#  'Andy Muschietti',
#  'David Slade',
#  'Rob Marshall',
#  'David Yates',
#  'Zack Snyder',
#  'Tom McGrath',
#  'James Gunn',
#  'Gary Ross',
#  'Mike Mitchell',
#  'Alfonso Cuarón',
#  'Robert Stromberg',
#  'David Ayer',
#  'Christophe Lourdelet',
#  'Joachim Rønning',
#  'Ridley Scott',
#  'Dan Scanlon',
#  'Matt Reeves',
#  'Marc Webb',
#  'Sam Taylor-Johnson',
#  'Jennifer Yuh Nelson',
#  'Scott Derrickson',
#  'Todd Phillips',
#  'Seth MacFarlane',
#  'Justin Lin',
#  'Ang Lee',
#  'Tarô Ohtani',
#  'Alan Taylor',
#  'Peyton Reed',
#  'Clint Eastwood',
#  'Kyle Lawrence',
#  'Ron Clements',
#  'Don Hall',
#  'Christopher H. Baum',
#  'Dean DeBlois',
#  'Genndy Tartakovsky',
#  'Raja Gosnell',
#  'Brad Dalton',
#  'Barry Sonnenfeld',
#  'Chris Sanders',
#  'Guy Ritchie',
#  'Steven Spielberg',
#  'Chris Miller',
#  'Luc Besson',
#  'George Anton',
#  'Damien Chazelle',
#  'Rahim Behboodi Far',
#  'Alejandro G. Iñárritu',
#  'Phil Lord',
#  'Carlos Saldanha',
#  'Vanja Kovacevic',
#  'Chris Eneaji Eneng',
#  'Rupert Wyatt',
#  'Alessandro Carloni',
#  'Jordan Vogt-Roberts',
#  'Brenda Chapman',
#  'Louis Leterrier',
#  'Reza Golchin',
#  'Travis Knight',
#  'Bradford Lewis',
#  'Jonathan Liebesman',
#  'Laura Clarke',
#  'Jon Turteltaub',
#  'Quentin Tarantino',
#  'Brad Peyton',
#  'Thiago J. Silva',
#  'Vitaliy Versace',
#  'Marc Forster',
#  'Adam Sputh',
#  'Olivier Megaton',
#  'Rich Moore',
#  'Nathan Greno',
#  'James Foley',
#  'Mostafa Kiayee',
#  'Darren Aronofsky',
#  'Sjoerd Oostrik',
#  'Wes Ball',
#  'Sébastien Grall',
#  'Harald Zwart',
#  'Matthew Vaughn',
#  'Daming Chen',
#  'David Fincher',
#  'Reinhard Klooss',
#  'Michael Gracey',
#  'James Mangold',
#  'Kenneth Branagh',
#  'Peter Farrelly',
#  'Will Gluck',
#  'Paul Greengrass',
#  'Josh Boone',
#  'David F. Sandberg',
#  'Sam Raimi',
#  'Martin Scorsese',
#  'Nitesh Tiwari',
#  'Stephen Chbosky',
#  'Christopher Miller',
#  'Clay Kaytis',
#  'J.J. Abrams',
#  'Sarah Morris',
#  'Jill Magid',
#  'Paul W.S. Anderson',
#  'Jamie Buckner',
#  'Rabi Kinagi',
#  'Sébastien Lifshitz',
#  'Duncan Jones',
#  'Michael Apted',
#  'Pia Justine Cruz',
#  'D.J. Caruso',
#  'Elizabeth Banks',
#  'Paul Feig',
#  'Muzaffer Özdemir',
#  'Sang-woo Lee',
#  'Nicholas Stoller',
#  'Feihong Chen',
#  'Jordan Peele',
#  'John R. Leonetti',
#  'Mickey Fonseca',
#  'Jon M. Chu',
#  'Simon J. Smith',
#  'Mani Maserrat Agah',
#  'S.S. Rajamouli',
#  'Robert Rodriguez',
#  'Rupert Sanders',
#  'Rawson Marshall Thurber',
#  'Chris McKay',
#  'Joe Johnston',
#  'Jason Stamp',
#  'Shawn Levy',
#  'Carlos Borges',
#  'Sujit Mondal',
#  'Bill Boyce',
#  'Guillermo del Toro',
#  'Noam Murro',
#  'George Miller',
#  'Roland Emmerich',
#  'David O. Russell',
#  'Ethan Coen',
#  'Alex Kurtzman',
#  'Niki Caro',
#  'Morten Tyldum',
#  'John Moore',
#  'Simon West',
#  'Paul Weitz',
#  'Luciana Kaplan',
#  'Brian Fee',
#  'Theodore Melfi',
#  'Paul King',
#  'Ariel Schulman',
#  'Gudmund Sand',
#  'Michael Patrick King',
#  'Johnny M. Sizemore',
#  'Imran Sheikh',
#  'Dennis Dugan',
#  'Cody Cameron',
#  'Edgar Wright',
#  'Doug Liman',
#  'Neil Burger',
#  'Thea Sharrock',
#  'Tate Taylor',
#  'Jon Hurwitz',
#  'Sylvester Stallone',
#  'Yimou Zhang',
#  'Roar Uthaug',
#  'Karthik Chandan',
#  'Ben Affleck',
#  'Florian Henckel von Donnersmarck',
#  'Seth Gordon',
#  'Ross Whitaker',
#  'Tod Williams',
#  'Jaume Collet-Serra',
#  'M. Night Shyamalan',
#  'Joseph Kosinski',
#  'Michael Sucsy',
#  'Tony Leondis',
#  'Hangyu Kim',
#  'Neill Blomkamp',
#  'Garry Marshall',
#  'Tommy Wirkola',
#  'Steven Caple Jr.',
#  'Steven Soderbergh',
#  'Chris Wedge',
#  'Peter Ramsey',
#  'Conrad Vernon',
#  'Baz Luhrmann',
#  'Steve McQueen',
#  'Scott Moore',
#  'Phillip Noyce',
#  'Rajesh Pillai',
#  'Walt Becker',
#  'Adam Robitel',
#  'Christopher McQuarrie',
#  'Clara Picasso',
#  'Baltasar Kormákur',
#  'Denis Villeneuve',
#  'Alexander Payne',
#  'Tony Gilroy',
#  'Sangeeth Sivan',
#  'Nick Cassavetes',
#  'McCaslin Miles',
#  'Jacek Lusinski',
#  'David Soren',
#  'Jeff Tremaine',
#  'Steve Martino',
#  'Gary Shore',
#  'G.M. Whiting',
#  'Martin McDonagh',
#  'Lee Daniels',
#  'Ryan Murphy',
#  'Peter Sohn',
#  'Lan An',
#  'Sang-il Lee',
#  'Patrick Fileti',
#  'Gregori J. Martin',
#  'Anthony Jones',
#  'Brett Ratner',
#  'Trish Sie',
#  'Rian Johnson',
#  'Phil Giordano',
#  'Jared Chandler',
#  'Antoine Fuqua',
#  'Henry Joost',
#  'Kelly Asbury',
#  'Troy Murray',
#  'Stan Harrington',
#  'Tarsem Singh',
#  'Danielle Colman',
#  'Steven S. DeKnight',
#  'Babak Najafi',
#  'Karey Kirkpatrick',
#  'Sean Sevestre',
#  'Sanne Vogel',
#  'Wes Anderson',
#  'Scott Speer',
#  'James Blagden',
#  'Andrew Niccol',
#  'Riley Rutter',
#  'Robert Zemeckis',
#  'Larry Brand',
#  'Michael Dougherty',
#  'Mel Gibson',
#  'Tim Story',
#  'Scott Waugh',
#  'Chris Columbus',
#  'Roschdy Zem',
#  'Shigeyuki Tanaka',
#  'Tim Hill',
#  'Jaishankar Chigurula',
#  'Rob Minkoff',
#  'Eric Brevig',
#  'John Madden',
#  'Ivan Reitman',
#  'Gerard McMurray',
#  'Daniel Espinosa',
#  'José Padilha',
#  'Adam McKay',
#  'Sebastien Grousset',
#  'Joe Wright',
#  'Dean Devlin',
#  'Jin-moo Kim',
#  'Ali Ahmadzade',
#  'Rob Letterman',
#  'Christopher Landon',
#  'Oliver Parker',
#  'Michel Gondry',
#  'Ron Howard',
#  'Lasse Hallström',
#  'James Bobin',
#  'Larry Charles',
#  'Steven Quale',
#  'Tatsuya Nagamine',
#  'James Watkins',
#  'Mohammad Ali Bashe Ahangar',
#  'Doug Sweetland',
#  "Gavin O'Connor",
#  'Malcolm D. Lee',
#  'Michel Hazanavicius',
#  'Christoffer Dreyer',
#  'John Batemen',
#  'Josh Trank',
#  'Jennifer Baichwal',
#  'Thor Freudenthal',
#  'Gore Verbinski',
#  'Dave Green',
#  'Peter Berg',
#  'Patrick Hughes',
#  'Gregory Jacobs',
#  'Kabir Khan',
#  'James DeMonaco',
#  'James Marsh',
#  'Judd Apatow',
#  'Martin Campbell',
#  'Daniel Sivan',
#  'Stephen Daldry',
#  'The Lowpriest',
#  'Dan Trachtenberg',
#  'David Frankel',
#  'John Requa',
#  'Simon McQuoid',
#  'Tony Clomax',
#  'Phyllida Lloyd',
#  'William Brent Bell',
#  'Carol Fauls',
#  'Edward Zwick',
#  'Jon Lucas',
#  'David Esbjornson',
#  'Jason Moore',
#  'Noube Rateau',
#  'Jung Huh',
#  'Tayo Osasona',
#  'Stiles White',
#  'Ben Stiller',
#  'Andy Fickman',
#  'Richard Dailey',
#  'Dan Mazer',
#  'Peter Lepeniotis',
#  'Peter Spierig',
#  'Janks Morton',
#  'Brian Taylor',
#  'McG',
#  'Tom Boyle',
#  'Nima Nourizadeh',
#  'Andy Tennant',
#  'Frank Coraci',
#  'François Favrat',
#  'Ricardas Marcinkus',
#  'George Clooney',
#  'Ki-duk Kim',
#  'Kevin Kölsch',
#  'Nimród Antal',
#  'Stephen Frears',
#  'Len Wiseman',
#  'Blake Harris',
#  'János Szász',
#  'Tony Chan',
#  'Jonathan Levine',
#  'Woody Allen',
#  'Riingo Banerjee',
#  'Madhur Bhandarkar',
#  'Samuel Bayer',
#  'Gustavo Goulart',
#  'Kathryn Bigelow',
#  'Mostafa Ahmadi',
#  'Jeff Newitt',
#  'Hope Hartman',
#  'Chao Wang',
#  'Fede Alvarez',
#  'John Francis Daley',
#  'John Lee Hancock',
#  'John Hamburg',
#  'Andrius Blazevicius',
#  'Yorgos Lanthimos',
#  'Alister Grierson',
#  'David Barker',
#  'Albert Hughes',
#  'Jon Erwin',
#  'Ebrahim Hatamikia',
#  'Spike Lee',
#  'Manish Gupta',
#  'Richard Curtis',
#  'George Nolfi',
#  'Ben Falcone',
#  'Bentley Dean',
#  'Jacalyn Evone',
#  'Cesar Montano',
#  'Kirk Jones',
#  'Lawrence Fajardo',
#  'Andrew Cohn',
#  'Justin Baldoni',
#  'Jake Schreier',
#  'Miguel Arteta',
#  'Rob Greenberg',
#  'J Blakeson',
#  'Kay Cannon',
#  'Mike Flanagan',
#  'Martin Sulík',
#  'Julie Anne Robinson',
#  'Young-Sung Sohn',
#  'Tom McCarthy',
#  'Sean Anders',
#  'Scott Hicks',
#  'Alex Kendrick',
#  'Tony Scott',
#  'Tristan Clay',
#  'Mike McCoy',
#  'Timur Bekmambetov',
#  'Richard Reade',
#  'Dennis Gansel',
#  'Kenneth Lonergan',
#  'Ole Bornedal',
#  'Cameron Crowe',
#  'Greta Gerwig',
#  'Daniel Stamm',
#  'Gregory Plotkin',
#  'Greg Berlanti',
#  'She Wei Chou',
#  'Dexter Fletcher',
#  'Milena Partheniou',
#  'R.J. Cutler',
#  'Sylvain Chomet',
#  'Joe Carnahan',
#  'Oliver Frampton',
#  'Danny Boyle',
#  'Maja Friis',
#  'Etan Cohen',
#  'Salome Oggenfuss',
#  'Brian Helgeland',
#  'Jodie Foster',
#  'Nicolas Winding Refn',
#  'Sarah Smith',
#  'Tarun Sudhir',
#  'Michael Lembeck',
#  'Barry Jenkins',
#  'Levan Gabriadze',
#  'Jake Myers',
#  'David Gordon Green',
#  'Giacomo Abbruzzese',
#  'Tal Lazar',
#  'Yildiz Hülya Bilban',
#  'Jason Friedberg',
#  'Bennett Miller',
#  'Greg Mottola',
#  'Stef Desmyter',
#  'Joshua Samson',
#  'Patricia Riggen',
#  'Gil Kenan',
#  'Tomas Alfredson',
#  'Mikael Håfström',
#  'Ari Aster',
#  'D. Tattersall',
#  'Alexandre Aja',
#  'Marc Silverstein',
#  'Robert Aldrich',
#  'Charles Martin Smith',
#  'Arnaud des Pallières',
#  'Alix Lindbergh',
#  'Pete Polyakov',
#  'Ari Sandel',
#  'Greg Strause',
#  'Craig William Macneill',
#  'F. Javier Gutiérrez',
#  'Dean Parisot',
#  'Michael Tiddes',
#  'Jeremy Garelick',
#  'Eui Yong Zong',
#  'Brian Percival',
#  'Brad Anderson',
#  'David Twohy',
#  'Wes Craven',
#  'David Bowers',
#  'Jean-Marc Vallée',
#  'Jimmy Hayward',
#  'Razvan Dinca',
#  'Zach Braff',
#  'Behrouz Sebt Rasoul',
#  'Dae-woo Kim',
#  'Banzragch Batbold',
#  'Zehao Gao',
#  'Nikolaj Arcel',
#  'John Erick Dowdle',
#  'Richard Linklater',
#  'Charlie Bean',
#  'Ken Marino',
#  'Kimberly Peirce',
#  'Gary Winick',
#  'Graham Annable',
#  'John Singleton',
#  'Kana Yamada',
#  'Stella Meghie',
#  'Dominic Sena',
#  'John Crowley',
#  'Breck Eisner',
#  'J.R. Sawyers',
#  'John Whitesell',
#  'Christian Gudegast',
#  'Adam Shankman',
#  'Catherine Hardwicke',
#  'Indra Gunawan',
#  'Erica Milsom',
#  'Rob Cohen',
#  'Danny Roth',
#  'Michael Showalter',
#  'Khavn',
#  'Joan Cutrina',
#  'Ken Scott',
#  'Chris Butler',
#  'Macaela Vandermost',
#  'Joon-ho Bong',
#  'Anton Corbijn',
#  'Camille Delamarre',
#  'Jorge R. Gutiérrez',
#  'Peter Segal',
#  'Simon Curtis',
#  'Aleksander Bach',
#  'Brad Furman',
#  'Pattie Collins',
#  'Ava DuVernay',
#  'Miguel Salazar',
#  'Josh Gordon',
#  'Eduardo W. Roy Jr.',
#  'Anna Foerster',
#  'Scott Cooper',
#  'James McTeigue',
#  'Dustin Hoffman',
#  'Chase Pottinger',
#  'Tom Gormican',
#  'Masatoshi Kurakata',
#  'Semih Kaplanoglu',
#  'Soo-in Bang',
#  'Lone Scherfig',
#  'Ciarán Foy',
#  'Kamen Kalev',
#  'Ric Roman Waugh',
#  'Jake Szymanski',
#  'Craig Gillespie',
#  'Timothy Reckart',
#  'Ayan Mukherjee',
#  'David M. Rosenthal',
#  'Yael Arava Shuldman',
#  'Dan Gilroy',
#  'Sylvain White',
#  'Scott Stewart',
#  'Travis Cluff',
#  'Dean Bivins',
#  'Bradley Parker',
#  'Renata Heinen',
#  'Mijke de Jong',
#  'Sam Miller',
#  'Stefano Sollima',
#  'Tyler Perry',
#  'Drew Goddard',
#  'Allen Coulter',
#  'Denzel Washington',
#  'Alan Poul',
#  'Alan Ferrier Graham Jonston',
#  'Tom Dey',
#  'Neil Marshall',
#  'Joy Mathew',
#  'Nicole Alibayof',
#  'Craig Brewer',
#  'Lee Toland Krieger',
#  'John Luessenhop',
#  'Oliver Stone',
#  'Steve Pink',
#  'Noemi Weis',
#  'Paul Haggis',
#  'Mark Tonderai',
#  'Mengyuan Wang',
#  'Jeff Prince',
#  'Robert Eggers',
#  'Sarah Christman',
#  'Diederik Van Rooijen',
#  'Wash Westmoreland',
#  'Christian E. Christiansen',
#  'Rudrapatla Venugopal',
#  'Nicholas Hytner',
#  'Nicolai Fuglsig',
#  'Joseph Gordon-Levitt',
#  'Michael Budd',
#  'Daniel Hinerfeld',
#  'Steve Antin',
#  'Vishram Sawant',
#  'Seong-Tae Lee',
#  'Niels Arden Oplev',
#  'Lars Klevberg',
#  'Jeff Wadlow',
#  'David Tietmeyer',
#  'Lukás Kokes',
#  'J. Jesses Smith',
#  'Sterling Johnston',
#  'Scott Frank',
#  'Marcos Carnevale',
#  'David Gelb',
#  'Jonathan del Val',
#  'Michael Bonomo',
#  'Lisa Cholodenko',
#  'Shekar',
#  'Derek Cianfrance',
#  'Vladimir V. Feyer',
#  'Tom Hanks',
#  'Anthony Nardolillo',
#  'Salim Akil',
#  'Brandon Camp',
#  'Todd Haynes',
#  'Robert Schwentke',
#  'Shan Serafin',
#  'Rogger Vergara Adrianzén',
#  'Dane Kissel',
#  'Rúnar Rúnarsson',
#  'Luke Greenfield',
#  'Johnathan McFarlane',
#  'Leslie Small',
#  'George Tillman Jr.',
#  'Gary Fleder',
#  'Michael Garcia',
#  'Neil Hart',
#  'Sean McNamara',
#  'Matt Bettinelli-Olpin',
#  'Ken Kwapis',
#  'Rocky Soraya',
#  'Adam Wingard',
#  'Travis Zariwny',
#  'Steven Dhoedt',
#  'Jim Field Smith',
#  'Tom Tykwer',
#  'Mimi Maynard',
#  'John Stevenson',
#  'Charles Stone III',
#  'John Hillcoat',
#  'Chris Gorak',
#  'Thanadol Nualsuth',
#  'Neil LaBute',
#  'Pablo Larraín',
#  'Michael Haneke',
#  'Lucia Aniello',
#  'Pierre Morel',
#  'Terrence Malick',
#  'Ericson Core',
#  'Timothy Fielding',
#  'Neil Jones',
#  'Harmony Korine',
#  'David Dobkin',
#  'Rohan Sabharwal',
#  'John Wells',
#  'David Mackenzie',
#  'David E. Talbert',
#  'Joshua Michael Stern',
#  'Randall Wallace',
#  'Alex Garland',
#  'Spike Jonze',
#  'Dilip Ghosh',
#  'Mark Tuff',
#  'Johannes Roberts',
#  'Anand Annamalai',
#  'Zhang Lei',
#  'Catherine Meyburgh',
#  'Lijin Jose',
#  'Matthew Colston',
#  'Andrew Dominik',
#  'Jessie Nelson',
#  'Agasthya Manju',
#  'Nicholas Jarecki',
#  'Jug Radivojevic',
#  'Stacy Title',
#  'Chris Pickle',
#  'Sarah Martin',
#  'Luca Scivoletto',
#  'Chris Stokes',
#  'Lenny Abrahamson',
#  'Jonathan Demme',
#  'Jay Conning',
#  'Barbara Sundstrom',
#  'Rhonda Parker',
#  'Levan Akin',
#  'Dean Israelite',
#  'Gavin Hood',
#  'Sudz Sutherland',
#  'Roberto Santiago',
#  'Dmitriy Dyachenko',
#  'Joel Coen',
#  'Ke Wang',
#  'Nat Faxon',
#  'Eduart Makri',
#  'Thomas Imbach',
#  'Jeff Nichols',
#  'Gonzalo López-Gallego',
#  'Mihalis Georgiou',
#  'Benh Zeitlin',
#  'Ed Gass-Donnelly',
#  'David Robert Mitchell',
#  'James Duffy',
#  'Charles Swain',
#  'Wolfgang Meyer',
#  'Daniel Barnz',
#  'Guillaume Bouiges',
#  'Jesse Peretz',
#  'Jon Cassar',
#  'Alexandre Espigares',
#  'Steve Whelan',
#  'Jane Lipsitz',
#  'Jonathan Church',
#  'Robert Luketic',
#  'Roman Polanski',
#  'Andrew Hyatt',
#  'Stephen J. Anderson',
#  'Sarah Gavron',
#  'Saptaswa Basu',
#  'Roger Donaldson',
#  'Roger Michell',
#  'Thomas Bezucha',
#  'Marco Berger',
#  'Rodrigo Cortés',
#  'Bobby Farrelly',
#  'Michael Norton',
#  'Mark Titus',
#  'Kevin Smith',
#  'Brian Levant',
#  'Katherine Cecil',
#  'James Franco',
#  'Roel Reiné',
#  'Eli Roth',
#  'Jean-Philippe Duval',
#  'Daniel Zirilli',
#  'Lucile Hadzihalilovic',
#  'Jee-woon Kim',
#  'Umer Mohammed',
#  'Elizabeth Muren',
#  'Aj Cross',
#  'Mimi Leder',
#  'Jay Roach',
#  'Hank Levine',
#  'Nicole Holofcener',
#  'Hermine Huntgeburth',
#  'Cal Brunker',
#  'Kishore Bhargav',
#  'J.C. Chandor',
#  'Steven M. Smith',
#  'Xavier Giannoli',
#  'Doug Ellin',
#  'Rick DeYoung',
#  'Dru Brown',
#  'Fernando Cortizo',
#  'Todd Strauss-Schulson',
#  'Bobby Mills-Thomas',
#  'Justin Zackham',
#  'Antonis Sotiropoulos',
#  'Kevin Crouch',
#  'Mark Steven Grove',
#  'Chloe Mann',
#  'Madhav Mathur',
#  'Simon Jaquemet',
#  'Stephen Susco',
#  'Stacie Passon',
#  'Richie Keen',
#  'Peter Hedges',
#  'John Michael McDonagh',
#  'Ilya Naishuller',
#  'Tor Iben',
#  'Dylan Brown',
#  'Thomas Carter',
#  'Boots Riley',
#  'Michael Hoffman',
#  'Simon Tyszko',
#  'Steve Carr',
#  'Trey Edward Shults',
#  'Shana Feste',
#  'Laura Lau',
#  'Art Messenger',
#  'Jason L. Mitchell',
#  'Wayne Thornley',
#  'Nate Bernard',
#  'Jonnie Malachi',
#  'Debra Granik',
#  'Troy Nixey',
#  'Chris Rock',
#  'Kevin Macdonald',
#  'Ry Russo-Young',
#  'James Mather',
#  'Sergei Bodrov',
#  'Maïwenn',
#  'Raja Chanda',
#  'Nicholas McCarthy',
#  'Szabolcs Hajdu',
#  'Anand Tucker',
#  'Ainun Ridho',
#  'Leigh Whannell',
#  'Taylor Hackford',
#  'Prabhu Deva',
#  'Paul Thomas Anderson',
#  'Mike Binder',
#  'Ockert Potgieter',
#  'James Demo',
#  'Jesse Baget',
#  'Bethany Ashton Wolf',
#  'Tissy Nnachi',
#  'Pawel Pawlikowski',
#  'Xavier Dolan',
#  'Billy Ray',
#  'Trevor Wall',
#  'Bille Woodruff',
#  'Elizabeth Allen Rosenbaum',
#  'Lars von Trier',
#  'Bo Burnham',
#  'Jocelyn Moorhouse',
#  'Akiva Schaffer',
#  'Chuck Konzelman',
#  'Kevin Cook',
#  'Mike Leigh',
#  'Jon Gunn',
#  'Kriv Stenders',
#  'Byung-Jo Son',
#  'Tery Wilson',
#  'Nanette Burstein',
#  'Ronan Chapalain',
#  'Mehdi Mazloumi',
#  'Wayne Blair',
#  'Rick Famuyiwa',
#  'Mike Mills',
#  'Justine Malle',
#  'Brian A. Miller',
#  'Jos de Putter',
#  'Jason Reitman',
#  'Yoshihiro Nakamura',
#  'Anne Fletcher',
#  'Ritesh Batra',
#  'Ben Lewin',
#  'Agus Pestol',
#  'Brian Klugman',
#  'Mae Czarina Cruz',
#  'Richard LaGravenese',
#  'Huaqing Jiang',
#  'Mark Mylod',
#  'Bill Hass',
#  'Kelly Fremon Craig',
#  'Sofia Coppola',
#  'Emily Fraser',
#  'Tom Ford',
#  'Benny Boom',
#  'Rohit Pandey',
#  'Sanaa Hamri',
#  'Stevie Cruz-Martin',
#  'Albin Joseph',
#  'Leslye Headland',
#  'Stuart Beattie',
#  'Paul D. Hannah',
#  'Eric Dean Hordes',
#  'Roger Spottiswoode',
#  'Andrijana Stojkovic',
#  'Sean Baker',
#  'Aash Aaron',
#  'Ashish R. Mohan',
#  'Angel Manuel Soto',
#  'Seung-Yub Lee',
#  'Joshua Clay Baldwin',
#  'Chris Kaye',
#  'Sajid Khan',
#  'Raoul Peck',
#  'Daniel J. Norman',
#  'Russell Crowe',
#  'Boaz Yakin',
#  'Jennifer Arnold',
#  'Jeff Scott Taylor',
#  'Noah Baumbach',
#  'Oleg Stepchenko',
#  "Remo D'Souza",
#  'Deon Taylor',
#  'Max Joseph',
#  'Aki Kaurismäki',
#  'Anurag Basu',
#  'Ira Farmer',
#  'Jason Winer',
#  'Erik White',
#  'Kim Longinotto',
#  'Nigel Cole',
#  'Asger Leth',
#  'Gina Prince-Bythewood',
#  'Mika Ninagawa',
#  'Houman Seyyedi',
#  'James Lee',
#  'Dilip Panda',
#  'RZA',
#  'Greg McLean',
#  'Nate Parker',
#  'Paco Plaza',
#  'Ron Scalpello',
#  'Hans Rodionoff',
#  'Michaël R. Roskam',
#  'Rohan Sippy',
#  'Andrejs Ekis',
#  'Seth Harden',
#  'Jacob Ennis',
#  'Jonathan Teplitzky',
#  'In-je Park',
#  'Anthony Silverston',
#  'Janchivdorj Sengedorj',
#  'Charles Ferguson',
#  'Luis Sampieri',
#  'Jim Jarmusch',
#  'Peter Atencio',
#  'Rashard Mendenhall',
#  'Rohit Jugraj',
#  'In-ho Hwang',
#  'David Matthew Weese',
#  'Jennifer Kent',
#  'Mabrouk El Mechri',
#  'Wayne Wang',
#  'Michael Cuesta',
#  'Ricardo de Montreuil',
#  'Jakub Paczek',
#  'Jennifer Barbaro',
#  'Andrew Traucki',
#  'Craig Johnson',
#  'Patrick Hogan',
#  'Rogeria Inocencio',
#  'Nick Moran',
#  'Burr Steers',
#  'Enrique Begné',
#  'Sean Durkin',
#  'James Ponsoldt',
#  'Andrew Erwin',
#  'Roger Kumble',
#  'Parker Dorris',
#  'Jung-bum Park',
#  'Peter Swanson',
#  'Corey Harrell',
#  'Tonny Trimarsanto',
#  'Justin Simien',
#  'Deniz Gamze Ergüven',
#  'Blair Treu',
#  'Steve Gomer',
#  'Slawomir Fabicki',
#  'David Michôd',
#  'Wenjian Ding',
#  'Lynne Ramsay',
#  'J.D. Dillard',
#  'Todd Graff',
#  'Alyssa Baxter-Williams',
#  'Nick Love',
#  'Drake Doremus',
#  'Laron Green',
#  'Stuart Cameron',
#  'Stuart McDonald',
#  'Murat Eroglu',
#  'Paul Emami',
#  'Hrant Yeritskinyan',
#  'Mark Vadik',
#  'Nicholas P. Richards',
#  'Andrew Adamson',
#  'Lilly Wachowski',
#  'Lynn Shelton',
#  'Dan Kwan',
#  'Adam Ethan Crow',
#  'Joe Nussbaum',
#  'Thomas Balmès',
#  'Lu Yaeger',
#  'Isao Yukisada',
#  'Richard Ayoade',
#  'David Lowery',
#  'Tony Glazer',
#  'Maggie Carey',
#  'Hans Petter Moland',
#  'Jokes Yanes',
#  'Jan Verheyen',
#  'Matt Piedmont',
#  'Matt Brown',
#  'Lorene Scafaria',
#  'Gillian Robespierre',
#  'David G. Evans',
#  'Stephan Elliott',
#  'Vince Rotonda',
#  'Ron Fricke',
#  'Mark Neveldine',
#  'Mike Cahill',
#  'Lea Glob',
#  'Yolanda Torres',
#  'Marielle Heller',
#  'Youssef Delara',
#  'Conor Allyn',
#  'Will Canon',
#  'Chia-Chien Chen',
#  'Michael Moore',
#  'Chad Zuver',
#  'Van M. Pham',
#  ...]

# %%
from operator import itemgetter
top_profits5 = dict(sorted(directors_profits.items(), key = itemgetter(1), reverse = True)[:5])
top_profits10 = dict(sorted(directors_profits.items(), key = itemgetter(1), reverse = True)[:10])

# %%
top_profits10
# Out:
# {'Atsushi Wada': 2351345279,
#  'Pete Meads': 2008208395,
#  'Anthony Russo': 1748134200,
#  'Colin Trevorrow': 1433854864,
#  'James Wan': 1328722794,
#  'Joss Whedon': 1292935897,
#  'Ryan Coogler': 1148258224,
#  'J.A. Bayona': 1135772799,
#  'Adam Green': 1122469910,
#  'Christophe Gans': 1099199706}

# %% [markdown]
# ## Graphing Top Directors by Individual Movie Profit

# %%
from matplotlib.pyplot import figure
keys = top_profits5.keys()
values = top_profits5.values()
figure(figsize=(8, 6), dpi=80)
plt.rcParams.update({'font.size': 12})
plt.bar(keys, values)
plt.xlabel('Top Five Directors', fontsize=20)
plt.ylabel('Total Gross Profit($B)', fontsize=20)
plt.show()

# %%
from matplotlib.pyplot import figure
keys = top_profits10.keys()
values = top_profits10.values()
figure(figsize=(18, 6), dpi=80)
plt.rcParams.update({'font.size': 12})
plt.bar(keys, values)
plt.xlabel('Top Ten Directors', fontsize=20)
plt.ylabel('Total Gross Profit($B)', fontsize=20)
plt.show()

# %% [markdown]
# ## Looking at the Number of Blockbuster Profitable Hits in the Top 500 by Director

# %%
top_500_appearances = Top_500.director_name.value_counts().head(10).tolist()

# %%
Top_500.director_name.value_counts().head(10)
# Out:
# Steven Spielberg      6
# Jon M. Chu            5
# Ridley Scott          5
# Christopher Nolan     4
# Mike Mitchell         4
# James Wan             4
# Michael Bay           3
# Tom McGrath           3
# Francis Lawrence      3
# Jaume Collet-Serra    3
# Name: director_name, dtype: int64

# %%
numb_movies = figure(figsize=(8, 6))
Top_500['director_name'].value_counts().head(10).plot(kind='bar');
plt.ylabel('Number of Top 500 Movies', fontsize=16) 
plt.title("Top Blockbuster Hits By Director ", fontsize=24)
plt.xticks(rotation = 60)
plt.xticks(ha='right')
plt.show()
numb_movies.savefig('Top500perdirector', bbox_inches='tight')

# %%
Top_100['director_name'].value_counts().head(10).plot(kind='bar');
plt.ylabel('Number of Top 100 Movies', fontsize=16)
plt.show()

# %%
top_directors_list = {'Steven Spielberg', 'Jon M. Chu', 'Ridley Scott', 'James Wan', 'Mike Mitchell', 'Christopher Nolan', 'James DeMonaco', 'Tom McGrath', 'Shawn Levy', 'Tim Burton'}

# %% [markdown]
# ## Looking at the Consistently Top Directors and Graphing Scatter Plots of their Relative Success

# %%
top_directors_500_df = (Top_500[Top_500.director_name.isin(top_directors_list)])
top_directors_500_df.rename(columns = {'budgets(USD)':'budgets_USD', 'world_gross(USD)':'world_gross_USD'}, inplace = True)
top_directors_500_df.head()
# Out:
# /Users/margaretboland/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#       id  release_date                           movie  budgets_USD  \
# 5557  48  Feb 11, 2011  Justin Bieber: Never Say Never     13000000
# 1939  12  Dec 25, 2011                       War Horse     70000000
# 773   89  May 11, 2012                    Dark Shadows    150000000
# 7541  67   Jun 7, 2013                       The Purge      3000000
# 2391  99   Apr 9, 2010                      Date Night     55000000
#
#       dom_gross(USD)  world_gross_USD   movie_id                 genres  \
# 5557        73013910         99034125  tt1702443      Documentary,Music
# 1939        79883359        156815529  tt1568911      Drama,History,War
# 773         79727149        238202668  tt1077368  Comedy,Fantasy,Horror
# 7541        64473115         91266581  tt2184339        Horror,Thriller
# 2391        98711404        152269033  tt1279935   Comedy,Crime,Romance
#
#       runtime_minutes  Estimated Profit     director_name  estimated_profit
# 5557            105.0          86034125        Jon M. Chu          86034125
# 1939            146.0          86815529  Steven Spielberg          86815529
# 773             113.0          88202668        Tim Burton          88202668
# 7541             85.0          88266581    James DeMonaco          88266581
# 2391             88.0          97269033        Shawn Levy          97269033

# %%
fig, ax = plt.subplots()
ax.scatter(x=top_directors_500_df['budgets_USD'], y=top_directors_500_df['world_gross_USD'])
ax.set(xlim = (0, 2.750000e+08), ylim = (3.126658e+07, 1.518723e+09), 
            title = "Movie Budget versus Estimated Movie Profit",
            xlabel = "Budget",
            ylabel = 'Gross Profit');

ax.set_xlim = (1.500000e+06, 2.750000e+08)
ax.set_ylim =(9.126658e+07, 1.518723e+09)
plt.show()

# %%
groups = top_directors_500_df.groupby('director_name')

from matplotlib.pyplot import figure

directorcolorcode = figure(figsize=(18, 12), dpi=80)

for name, group in groups:
    
 
    plt.plot(group.budgets_USD, group.world_gross_USD, marker='o', linestyle='', markersize=14, label=name)
    plt.ticklabel_format(style='plain', useOffset=False)
    plt.xlabel('Budget', fontsize=24)
    plt.ylabel('Gross Profit', fontsize=24)
    
  
    plt.title("Movie Budget versus Estimated Movie Profit Color Coded By Director", fontsize=24)

    
   
plt.legend()
directorcolorcode.savefig('Movie_Budget_Director.png')

# %% [markdown]
# ## PART IV
# ## Movie Profitablity and Runtime Analysis

# %% [markdown]
# The final variable we examined to make a recommendation to Microsoft Movie Studio was a movie's runtime and whether or not that runtime correlated with higher estimated profitability.
#
# Using the movie_clean_df dataframe, we cleaned the dataframe to only include data that had values for the runtime_minutes variable.

# %% [markdown]
# ## Analyzing the runtime data for overall dataset, profitable dataset, and unprofitable movies

# %%
#Drop rows that are missing runtime_minutes values
movie_clean_df = movie_clean_df.dropna(subset=["runtime_minutes"])
#Check that the runtime_minutes has no missing values
movie_clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2144 entries, 7 to 0
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                2144 non-null   int64
#  1   release_date      2144 non-null   object
#  2   movie             2144 non-null   object
#  3   budgets(USD)      2144 non-null   int64
#  4   dom_gross(USD)    2144 non-null   int64
#  5   world_gross(USD)  2144 non-null   int64
#  6   movie_id          2144 non-null   object
#  7   genres            2138 non-null   object
#  8   runtime_minutes   2144 non-null   float64
#  9   Estimated Profit  2144 non-null   int64
#  10  director_name     2144 non-null   object
#  11  estimated_profit  2144 non-null   int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 217.8+ KB

# %%
#Create a new variable with  mean number of runtime_minutes for all movies in 
#dataset to get a better understanding of centrality.
runtime_minutes_mean = movie_clean_df["runtime_minutes"].mean()

# %%
#Create a new variable with the median number of runtime_minutes for all movies in 
#dataset to get a better understanding of centrality. 
runtime_minutes_median = movie_clean_df["runtime_minutes"].median()

# %%
#find mean number of runtime_minutes for all profitable movies in dataset
#create data frame of profitable movies
profitable_movie_df = movie_clean_df[movie_clean_df["Estimated Profit"] > 0]
#find the mean and median runtime of the profitable movies
profitable_movie_df["runtime_minutes"].mean()
profitable_movie_df["runtime_minutes"].median()
# Out:
# 104.0

# %%
# We can visualize this centrality by creating a histogram of runtime_minutes to see centrality. 
fig, ax = plt.subplots()

ax.hist(profitable_movie_df["runtime_minutes"])
ax.set_title("Frequency of Runtimes in Minutes for Profitable Movies")
ax.set_xlabel("Minutes")
ax.set_ylabel("Frequency");

# %%
#Create scatter plot to see if there is a correlation between runtime and profitability

fig, ax = plt.subplots()
x = profitable_movie_df["runtime_minutes"]
y = profitable_movie_df["Estimated Profit"]
ax.scatter(x, y)
ax.set(xlim = (0, 180), ylim = (0, 2000000000), 
            title = "Runtime in Minutes versus Estimated Movie Profit",
            xlabel = "Runtime (minutes)",
            ylabel = "Estimated Profits ($)");

# %% [markdown]
# There appears to be a slight positive correlation between runtime and profitablity in the profitable movie dataframe.
# We then looked to see if this holds true for the most profitable movies that we examined with the genre variable. To do this we stored away those most profitable movies as its own data frame most_profitable_df .

# %%
##Create 100 most profitable movies dataframe 
most_profitable_df = profitable_movie_df.sort_values(by = "Estimated Profit", ascending = False)[0:100]
most_profitable_df
# Out:
#       id  release_date                   movie  budgets(USD)  dom_gross(USD)  \
# 0      1  Dec 18, 2009                  Avatar     425000000       760507625
# 18     7  Apr 27, 2018  Avengers: Infinity War     300000000       678815482
# 142   34  Jun 12, 2015          Jurassic World     215000000       652270625
# 272   67   Apr 3, 2015               Furious 7     190000000       353007020
# 123   27   May 4, 2012            The Avengers     225000000       623279547
# ...   ..           ...                     ...           ...             ...
# 866   26  Mar 22, 2013              The Croods     135000000       187168425
# 327   81  May 24, 2019                 Aladdin     182000000       246734314
# 762   78  Mar 29, 2018        Ready Player One     150000000       137690172
# 1045  46  Oct 28, 2011           Puss in Boots     130000000       149260504
# 2936  83  Jul 25, 2014                    Lucy      40000000       126573960
#
#       world_gross(USD)   movie_id                      genres  \
# 0           2776345279  tt1775309                      Horror
# 18          2048134200  tt4154756     Action,Adventure,Sci-Fi
# 142         1648854864  tt0369610     Action,Adventure,Sci-Fi
# 272         1518722794  tt2820852       Action,Crime,Thriller
# 123         1517935897  tt0848228     Action,Adventure,Sci-Fi
# ...                ...        ...                         ...
# 866          573068425  tt0481499  Action,Adventure,Animation
# 327          619234314  tt6139732     Adventure,Comedy,Family
# 762          579290136  tt1677720     Action,Adventure,Sci-Fi
# 1045         554987477  tt0448694  Action,Adventure,Animation
# 2936         457507776  tt2872732      Action,Sci-Fi,Thriller
#
#       runtime_minutes  Estimated Profit     director_name  estimated_profit
# 0                93.0        2351345279      Atsushi Wada        2351345279
# 18              149.0        1748134200     Anthony Russo        1748134200
# 142             124.0        1433854864   Colin Trevorrow        1433854864
# 272             137.0        1328722794         James Wan        1328722794
# 123             143.0        1292935897       Joss Whedon        1292935897
# ...               ...               ...               ...               ...
# 866              98.0         438068425     Chris Sanders         438068425
# 327             128.0         437234314       Guy Ritchie         437234314
# 762             140.0         429290136  Steven Spielberg         429290136
# 1045             90.0         424987477      Chris Miller         424987477
# 2936             89.0         417507776        Luc Besson         417507776
#
# [100 rows x 12 columns]

# %%
#Finding the mean and median for the top 100 most profitable movies from our most_profitable_df and save away as their own variables. 
most_profitable_runtime_mean = most_profitable_df["runtime_minutes"].mean()
most_profitable_runtime_median = most_profitable_df["runtime_minutes"].median()
print(most_profitable_runtime_mean, most_profitable_runtime_median)
# Out:
# 121.06 124.0

# %% [markdown]
# We see that the 100 most profitable movies have substantially higher runtime mean and median than those from the movie_clean_df (our overall dataset with profitable and unprofitable movies) and the profitable_df dataframe.
#
# We then created a histogram to see the frequency of runtimes in the 100 most profitable movies.

# %%
#creating a histogram of the frequency of runtimes for movies in the top 100 most profitable dataframe. 

fig, ax = plt.subplots()
x = most_profitable_df["runtime_minutes"]
y = most_profitable_df["Estimated Profit"]
ax.scatter(x, y)
ax.set(xlim = (40, 180), ylim = (0, 2000000000), 
            title = "Runtime in Minutes versus Estimated Movie Profit",
            xlabel = "Runtime (minutes)",
            ylabel = "Estimated Profits ($)");

# %% [markdown]
# Its an odd shape, not the most normal curve, but we see that there are more movies with longer runtimes than in the overall profitable movies dataframe. We also knew this by looking at the mean and median, but it is good to visualize.

# %% [markdown]
# Next we created a least profitable dataframe from our main_clean_df to see if there was a big difference between the 100 most profitable movies and the 100 least profitable (in this case unprofitable) movies.

# %%
#To do this we created a dataframe of unprofitable movies (in case we wanted to dig deeper into this dataset 
# and then sort_values() of the unprofitable_movie_df by our "Estimated Profit" variable in descending order.
unprofitable_movies_df = movie_clean_df[movie_clean_df["Estimated Profit"] < 0]
least_profitable_movies_df = unprofitable_movies_df.sort_values(by = ["Estimated Profit"])[0:100]

# %%
#We double checked that the least profitable movie is at the top of our new 100 least profitable (most unprofitable) 
# dataframe. 
least_profitable_movies_df.head()
# Out:
#       id  release_date                        movie  budgets(USD)  \
# 7      3   Jun 7, 2019                 Dark Phoenix     350000000
# 789   94  Mar 11, 2011              Mars Needs Moms     150000000
# 1312  42  Jun 14, 2019  Men in Black: International     110000000
# 1614  80  Dec 13, 2017                       Bright      90000000
# 1612  79  Nov 24, 2010         The Nutcracker in 3D      90000000
#
#       dom_gross(USD)  world_gross(USD)   movie_id                      genres  \
# 7           42762350         149762350  tt6565702     Action,Adventure,Sci-Fi
# 789         21392758          39549758  tt1305591  Adventure,Animation,Family
# 1312         3100000           3100000  tt2283336     Action,Adventure,Comedy
# 1614               0                 0  tt5519340        Action,Crime,Fantasy
# 1612          195459          20466016  tt1041804       Action,Family,Fantasy
#
#       runtime_minutes  Estimated Profit         director_name  \
# 7               113.0        -200237650         Simon Kinberg
# 789              88.0        -110450242           Simon Wells
# 1312            115.0        -106900000          F. Gary Gray
# 1614            117.0         -90000000            David Ayer
# 1612            110.0         -69533984  Andrey Konchalovskiy
#
#       estimated_profit
# 7           -200237650
# 789         -110450242
# 1312        -106900000
# 1614         -90000000
# 1612         -69533984

# %%
#We looked at the mean and median of this new dataframe to see if it was different from our most profitable movies
least_profitable_runtime_mean = least_profitable_movies_df["runtime_minutes"].mean()
least_profitable_runtime_mean
# Out:
# 102.52

# %%
least_profitable_runtime_median = least_profitable_movies_df["runtime_minutes"].median()
least_profitable_runtime_median
# Out:
# 104.5

# %% [markdown]
# We saw that the mean and median of runtimes are similar to the overall data frame and also very different to our most profitable movie list.
#
# To visualize the distinction of the runtimes of the 100 most profitable movies and the 100 least profitable movies we created an overlapping histogram. We also included the dataset mean to both show that the mean of the overall dataset and the mean runtime of the 100 least profitable movies are not significantly different, but is significantly different than the mean runtime of the 100 most profitable movies.

# %%
plt.figure(figsize=(10,6))

plt.hist(most_profitable_df["runtime_minutes"], alpha = 0.5, color = "blue", label = "Most Profitable Movies", bins = "fd")
plt.hist(least_profitable_movies_df["runtime_minutes"], alpha = 0.5, color = "red", label = "Least Profitable Movies", bins = "fd")
plt.vlines(x=104, ymin = 0, ymax = 24, label = "Overall Movie Mean")
plt.title("Most Profitable vs Least Profitable Movies", size=18)
plt.suptitle("Frequency of Runtimes", size=20)
plt.xlabel("Movie Runtime (mins)", size=14)
plt.ylabel("Frequency", size=14)
plt.legend(loc="upper left")
plt.savefig("./Movie_Runtime_Hist_Compare_SampMean.png");

# %% [markdown]
# Overall, from our analysis of movie runtimes we see that the 100 most profitable movies had on average distinctly longer runtimes than the movies in our cleaned data set. We also saw that this distinction held true when comparing the 100 most profitable movies from the 100 least profitable (most unprofitable) movies.
#
# From this analysis we drew the recommendation that Microsoft Movie Studios should make movies that are on average 121 minutes (the average of the most profitable movies), which is nearly 15% longer than the average of the least profitable movies.

# %% [markdown]
# ## PART V
# ## Recommendations & Next Steps

# %% [markdown]
# From our analysis, we recommend that Microsoft put itself in the best position to create profitable movies by making movies that have the following characteristics:
#     1. Movies of the adventure/action genre
#     2. Movies directed by one of the top Directors that outperform their peers particularly James Wan.
#     3. Finally, these movies should have a runtime close to 120 minutes.
#
# In order to ensure Microsoft can pursue this strategy we suggest that in the coming weeks the Movie Studio team:
#     1. Determine budget constraints for genre and director selection.
#     2. Reach out to teams of top directors for the genre and runtime of their upcoming unsold movies.
