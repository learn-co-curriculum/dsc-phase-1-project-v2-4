# %%
import pandas as pd
import matplotlib.pyplot as plt
pd.options.display.float_format = '{:.2f}'.format

# %%
df = pd.read_csv('../data/zippedData/rt.movie_info.tsv.gz' , delimiter='\t')
df.head()
# Out:
#    id                                           synopsis rating  \
# 0   1  This gritty, fast-paced, and innovative police...      R
# 1   3  New York City, not-too-distant-future: Eric Pa...      R
# 2   5  Illeana Douglas delivers a superb performance ...      R
# 3   6  Michael Douglas runs afoul of a treacherous su...      R
# 4   7                                                NaN     NR
#
#                                  genre          director  \
# 0  Action and Adventure|Classics|Drama  William Friedkin
# 1    Drama|Science Fiction and Fantasy  David Cronenberg
# 2    Drama|Musical and Performing Arts    Allison Anders
# 3           Drama|Mystery and Suspense    Barry Levinson
# 4                        Drama|Romance    Rodney Bennett
#
#                             writer  theater_date      dvd_date currency  \
# 0                   Ernest Tidyman   Oct 9, 1971  Sep 25, 2001      NaN
# 1     David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
# 2                   Allison Anders  Sep 13, 1996  Apr 18, 2000      NaN
# 3  Paul Attanasio|Michael Crichton   Dec 9, 1994  Aug 27, 1997      NaN
# 4                     Giles Cooper           NaN           NaN      NaN
#
#   box_office      runtime             studio
# 0        NaN  104 minutes                NaN
# 1    600,000  108 minutes  Entertainment One
# 2        NaN  116 minutes                NaN
# 3        NaN  128 minutes                NaN
# 4        NaN  200 minutes                NaN

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1560 entries, 0 to 1559
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            1560 non-null   int64
#  1   synopsis      1498 non-null   object
#  2   rating        1557 non-null   object
#  3   genre         1552 non-null   object
#  4   director      1361 non-null   object
#  5   writer        1111 non-null   object
#  6   theater_date  1201 non-null   object
#  7   dvd_date      1201 non-null   object
#  8   currency      340 non-null    object
#  9   box_office    340 non-null    object
#  10  runtime       1530 non-null   object
#  11  studio        494 non-null    object
# dtypes: int64(1), object(11)
# memory usage: 146.4+ KB

# %%
df['box_office'].describe()
# Out:
# count         340
# unique        336
# top       200,000
# freq            2
# Name: box_office, dtype: object

# %%
box_office_with_non_value = df.loc[df['box_office'].notnull()] 
box_office_with_non_value
# Out:
#         id                                           synopsis rating  \
# 1        3  New York City, not-too-distant-future: Eric Pa...      R
# 6       10  Some cast and crew from NBC's highly acclaimed...  PG-13
# 7       13  Stewart Kane, an Irishman living in the Austra...      R
# 8       14  "Love Ranch" is a bittersweet love story that ...      R
# 15      22  Two-time Academy Award Winner Kevin Spacey giv...      R
# ...    ...                                                ...    ...
# 1541  1980  A band of renegades on the run in outer space ...  PG-13
# 1542  1981  Money, Fame and the Knowledge of English. In I...     NR
# 1545  1985  A woman who joins the undead against her will ...      R
# 1546  1986  Aki Kaurismaki's The Man Without a Past opens ...     PG
# 1555  1996  Forget terrorists or hijackers -- there's a ha...      R
#
#                                                  genre             director  \
# 1                    Drama|Science Fiction and Fantasy     David Cronenberg
# 6                                               Comedy          Jake Kasdan
# 7                                                Drama         Ray Lawrence
# 8                                                Drama      Taylor Hackford
# 15                   Comedy|Drama|Mystery and Suspense  George Hickenlooper
# ...                                                ...                  ...
# 1541  Action and Adventure|Science Fiction and Fantasy          Joss Whedon
# 1542                                      Comedy|Drama         Gauri Shinde
# 1545                       Horror|Mystery and Suspense  Sebastian Gutierrez
# 1546          Art House and International|Comedy|Drama                  NaN
# 1555  Action and Adventure|Horror|Mystery and Suspense                  NaN
#
#                                 writer  theater_date      dvd_date currency  \
# 1         David Cronenberg|Don DeLillo  Aug 17, 2012   Jan 1, 2013        $
# 6                           Mike White  Jan 11, 2002  Jun 18, 2002        $
# 7     Raymond Carver|Beatrix Christian  Apr 27, 2006   Oct 2, 2007        $
# 8                        Mark Jacobson  Jun 30, 2010   Nov 9, 2010        $
# 15                       Norman Snider  Dec 17, 2010   Apr 5, 2011        $
# ...                                ...           ...           ...      ...
# 1541                       Joss Whedon  Sep 30, 2005  Dec 20, 2005        $
# 1542                      Gauri Shinde   Oct 5, 2012  Nov 20, 2012        $
# 1545               Sebastian Gutierrez   Jun 1, 2007   Oct 9, 2007        $
# 1546                               NaN  Aug 30, 2002   Oct 7, 2003        $
# 1555                               NaN  Aug 18, 2006   Jan 2, 2007        $
#
#       box_office      runtime                  studio
# 1        600,000  108 minutes       Entertainment One
# 6     41,032,915   82 minutes      Paramount Pictures
# 7        224,114  123 minutes  Sony Pictures Classics
# 8        134,904  117 minutes                     NaN
# 15     1,039,869  108 minutes            ATO Pictures
# ...          ...          ...                     ...
# 1541  25,335,935  119 minutes      Universal Pictures
# 1542   1,416,189  129 minutes      Eros Entertainment
# 1545      59,371   98 minutes        IDP Distribution
# 1546     794,306   97 minutes                     NaN
# 1555  33,886,034  106 minutes         New Line Cinema
#
# [340 rows x 12 columns]

# %%
bownv = box_office_with_non_value.sort_values( by=['box_office'],ascending=False)
bownv
# Out:
#         id                                           synopsis rating  \
# 16      23  A fictional film set in the alluring world of ...      R
# 1510  1944  In the 3D action-comedy The Green Hornet, Brit...  PG-13
# 207    274  Natalie Portman stars in this western concerni...      R
# 1469  1890  A misplaced sausage and his savory friends emb...      R
# 1323  1711  Directed by Garry Marshall, The Princess Diari...      G
# ...    ...                                                ...    ...
# 1213  1564  Real-life sweethearts Michael Cera and Charlyn...  PG-13
# 1087  1398  A heartfelt tale of inspiration, hope and rede...     PG
# 809   1046  Writer/director Rodrigo Garca (Nine Lives) tea...      R
# 15      22  Two-time Academy Award Winner Kevin Spacey giv...      R
# 86     108  A picture-perfect family moves into an upscale...      R
#
#                                                   genre  \
# 16                                                Drama
# 1510  Action and Adventure|Comedy|Science Fiction an...
# 207                  Action and Adventure|Drama|Western
# 1469                                   Animation|Comedy
# 1323                             Comedy|Kids and Family
# ...                                                 ...
# 1213                                             Comedy
# 1087       Drama|Kids and Family|Faith and Spirituality
# 809                                               Drama
# 15                    Comedy|Drama|Mystery and Suspense
# 86                         Comedy|Drama|Kids and Family
#
#                           director  \
# 16                             NaN
# 1510                 Michel Gondry
# 207                            NaN
# 1469    Conrad Vernon|Greg Tiernan
# 1323                Garry Marshall
# ...                            ...
# 1213            Nicholas Jasenovec
# 1087  David Nixon|Patrick Doughtie
# 809                            NaN
# 15             George Hickenlooper
# 86                   Derrick Borte
#
#                                                  writer  theater_date  \
# 16                                                  NaN  Dec 20, 2013
# 1510                           Evan Goldberg|Seth Rogen  Jan 14, 2011
# 207                                                 NaN  Jan 29, 2016
# 1469  Kyle Hunter|Ariel Shaffir|Seth Rogen|Evan Gold...  Aug 12, 2016
# 1323                                      Shonda Rhimes  Aug 11, 2004
# ...                                                 ...           ...
# 1213                     Nicholas Jasenovec|Charlyne Yi  Aug 14, 2009
# 1087                                                NaN   Apr 9, 2010
# 809                                                 NaN   May 7, 2010
# 15                                        Norman Snider  Dec 17, 2010
# 86                                        Derrick Borte  Apr 16, 2010
#
#           dvd_date currency  box_office      runtime                  studio
# 16    Mar 18, 2014        $  99,165,609  129 minutes           Sony Pictures
# 1510   May 3, 2011        $  98,000,000  119 minutes           Sony Pictures
# 207   Apr 26, 2016        $     976,847   97 minutes                     NaN
# 1469   Nov 8, 2016        $  97,661,826   89 minutes           Sony Pictures
# 1323  Dec 14, 2004        $  95,111,012  113 minutes                     NaN
# ...            ...      ...         ...          ...                     ...
# 1213   Dec 1, 2009        $   1,149,350   89 minutes          Overture Films
# 1087  Aug 10, 2010        $   1,121,000  110 minutes   Vivendi Entertainment
# 809   Dec 14, 2010        $   1,110,286  126 minutes  Sony Pictures Classics
# 15     Apr 5, 2011        $   1,039,869  108 minutes            ATO Pictures
# 86    Aug 10, 2010        $   1,000,000   93 minutes    Roadside Attractions
#
# [340 rows x 12 columns]

# %%
bownv['box_office'] = bownv['box_office'].str.replace(',','')

# %%
bownv['box_office'] = bownv['box_office'].astype(int) 
bownv['box_office']
# Out:
# 16      99165609
# 1510    98000000
# 207       976847
# 1469    97661826
# 1323    95111012
#           ...
# 1213     1149350
# 1087     1121000
# 809      1110286
# 15       1039869
# 86       1000000
# Name: box_office, Length: 340, dtype: int64

# %%
bownv.sort_values('box_office',ascending=False, inplace= True)
bownv
# Out:
#         id                                           synopsis rating  \
# 827   1071  This depiction of the last 12 hours in the lif...      R
# 877   1136  The Hobbit: An Unexpected Journey follows titl...  PG-13
# 1188  1525  In Skyfall, Bond's loyalty to M is tested as h...  PG-13
# 690    883  Now that Greg Focker is "in" with his soon-to-...  PG-13
# 1117  1442  Youthful wizard Harry Potter returns to the sc...     PG
# ...    ...                                                ...    ...
# 1269  1639  In this darkly erotic drama from cult filmmake...     NR
# 691    884  Freebie (James Caan) and the Bean (Alan Arkin)...      R
# 697    895  After a sexual assault by a random stranger, S...     NR
# 359    469  Jacqueline Kennedy Onassis sued him, Marlon Br...  PG-13
# 970   1260  With the recent assault on Berlusconi in Milan...     NR
#
#                                                   genre        director  \
# 827                                               Drama      Mel Gibson
# 877    Action and Adventure|Science Fiction and Fantasy   Peter Jackson
# 1188          Action and Adventure|Mystery and Suspense      Sam Mendes
# 690                                              Comedy       Jay Roach
# 1117        Kids and Family|Science Fiction and Fantasy  Chris Columbus
# ...                                                 ...             ...
# 1269                  Art House and International|Drama  Jeanne Labrune
# 691                   Action and Adventure|Comedy|Drama    Richard Rush
# 697                   Drama|Horror|Mystery and Suspense    Eric England
# 359   Documentary|Musical and Performing Arts|Specia...       Leon Gast
# 970             Documentary|Special Interest|Television    Erik Gandini
#
#                                                  writer  theater_date  \
# 827                      Mel Gibson|Benedict Fitzgerald  Feb 25, 2004
# 877   Peter Jackson|Philippa Boyens|Guillermo del To...  Dec 14, 2012
# 1188                 John Logan|Robert Wade|Neal Purvis   Nov 9, 2012
# 690                           Jim Herzfeld|John Hamburg  Dec 22, 2004
# 1117                                       Steve Kloves  Nov 15, 2002
# ...                                                 ...           ...
# 1269                    Jeanne Labrune|Richard Debuisne  Aug 26, 2011
# 691                                      Robert Kaufman  Dec 25, 1974
# 697                                        Eric England  Nov 22, 2013
# 359                                                 NaN  Jul 30, 2010
# 970                                        Erik Gandini  Aug 28, 2009
#
#           dvd_date currency  box_office      runtime                 studio
# 827   Aug 31, 2004        $   368000000  127 minutes   Newmarket Film Group
# 877   Mar 19, 2013        $   303001229  170 minutes           Warner Bros.
# 1188  Mar 11, 2013        $   299300000  145 minutes                    MGM
# 690   Apr 26, 2005        $   279167575  118 minutes     Universal Pictures
# 1117  Apr 11, 2003        $   261835892  161 minutes  Warner Bros. Pictures
# ...            ...      ...         ...          ...                    ...
# 1269  Jan 17, 2012        $        8856   95 minutes     First Run Features
# 691   Jan 11, 2011        $        8300  114 minutes  Warner Bros. Pictures
# 697   Mar 18, 2014        $        3328   84 minutes              IFC Films
# 359   Oct 19, 2010        $        2367   88 minutes      Magnolia Pictures
# 970    Sep 7, 2010        $         363   84 minutes           Lorber Films
#
# [340 rows x 12 columns]

# %%
bownv_top_100bo = bownv['rating'].head(100)
bownv_top_100bo.value_counts() # For the top 100 movies that have non-null box_office value, 
                               # looks like PG-13 appears the most.
# Out:
# PG-13    50
# R        24
# PG       24
# G         2
# Name: rating, dtype: int64

# %%
bownv_top_100bo.value_counts().keys()
# Out:
# Index(['PG-13', 'R', 'PG', 'G'], dtype='object')

# %%
fig,ax = plt.subplots()
x = bownv_top_100bo.value_counts().keys()
height = bownv_top_100bo.value_counts().values

ax.bar( x = x , height = height);
ax.set_xlabel('Rating')
ax.set_ylabel('# of Movies')
ax.set_title('Top 100 movies with highest box_office value(non-null)');

# %%
df_rating_avg_bf=bownv.groupby(by='rating').mean().reset_index()[['rating','box_office']]
df_rating_avg_bf.sort_values(by='box_office', ascending = True , inplace = True)

# %%
df_rating_avg_bf.box_office
# Out:
# 1    1260219.00
# 2    2486248.68
# 5   23231760.90
# 0   30447955.56
# 3   51033556.73
# 4   56520154.89
# Name: box_office, dtype: float64

# %%
fig, ax = plt.subplots()
ax.ticklabel_format(style='plain')
x = df_rating_avg_bf.rating
height = df_rating_avg_bf.box_office

ax.barh( y = x , width = height);
ax.set_xlabel('Average box_office')
ax.set_ylabel('Rating ')
ax.set_title('Average box_office for each rating');

# %%
df_rating_median_bf=bownv.groupby(by='rating').median().reset_index()[['rating','box_office']]

# %%
df_rating_median_bf.sort_values(by='box_office', ascending = True , inplace = True)

# %%
fig, ax = plt.subplots()
ax.ticklabel_format(style='plain')
plt.xticks(rotation=330, ha="right")
x = df_rating_median_bf.rating
height = df_rating_median_bf.box_office

ax.barh( y = x , width = height);
ax.set_xlabel('Median box_office')
ax.set_ylabel('Rating ')
ax.set_title('Median box_office for each rating');

# %%
# From the information given above, movies that rated PG-13 and PG have better results than others .
