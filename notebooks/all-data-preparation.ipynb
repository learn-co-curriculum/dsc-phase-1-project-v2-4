# %%
# !pwd
# Out:
# /g/My Drive/Flatiron/Phase-1/project/phase-1-project/dsc-phase-1-project/notebooks

# %%
# !cd ..

# %%
# !pwd
# Out:
# /g/My Drive/Flatiron/Phase-1/project/phase-1-project/dsc-phase-1-project/notebooks

# %%
import pandas as pd

# %%
df_movie_genre_long = pd.read_csv('../data/movie_genre_long.csv', index_col=0)

# %%
df_tmdb = pd.read_csv('../data/tmdb_filtered.csv', index_col=0)

# %%
df_tmdb.head()
# Out:
#         budget                                             genres       id  \
# 0  250000000.0  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...  12444.0
# 1  165000000.0  [{'id': 14, 'name': 'Fantasy'}, {'id': 12, 'na...  10191.0
# 2  200000000.0  [{'id': 12, 'name': 'Adventure'}, {'id': 28, '...  10138.0
# 3   30000000.0  [{'id': 16, 'name': 'Animation'}, {'id': 12, '...    862.0
# 4  160000000.0  [{'id': 28, 'name': 'Action'}, {'id': 878, 'na...  27205.0
#
#      imdb_id                                original_title release_date  \
# 0  tt0926084  Harry Potter and the Deathly Hallows: Part 1   2010-10-17
# 1  tt0892769                      How to Train Your Dragon   2010-03-18
# 2  tt1228705                                    Iron Man 2   2010-04-28
# 3  tt0114709                                     Toy Story   1995-10-30
# 4  tt1375666                                     Inception   2010-07-15
#
#        revenue  vote_average  vote_count
# 0  954305868.0           7.8     16170.0
# 1  494878759.0           7.8     11036.0
# 2  623933331.0           6.8     18118.0
# 3  373554033.0           8.0     15570.0
# 4  825532764.0           8.4     31837.0

# %%
df_tmdb_filtered = df_tmdb[['budget', 'revenue', 'imdb_id','vote_average','vote_count']]

# %%
df_tmdb_filtered.head()
# Out:
#     budget_api  revenue_api    imdb_id  vote_average  vote_count
# 0  250000000.0  954305868.0  tt0926084           7.8     16170.0
# 1  165000000.0  494878759.0  tt0892769           7.8     11036.0
# 2  200000000.0  623933331.0  tt1228705           6.8     18118.0
# 3   30000000.0  373554033.0  tt0114709           8.0     15570.0
# 4  160000000.0  825532764.0  tt1375666           8.4     31837.0

# %%
df_tmdb_filtered.rename(columns={'budget':'budget_api', 'revenue':'revenue_api'}, inplace=True)
# Out:
# C:\Users\ghall\anaconda3\envs\learn-env\lib\site-packages\pandas\core\frame.py:4296: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
df_tmdb_filtered.head()
# Out:
#     budget_api  revenue_api    imdb_id  vote_average  vote_count
# 0  250000000.0  954305868.0  tt0926084           7.8     16170.0
# 1  165000000.0  494878759.0  tt0892769           7.8     11036.0
# 2  200000000.0  623933331.0  tt1228705           6.8     18118.0
# 3   30000000.0  373554033.0  tt0114709           8.0     15570.0
# 4  160000000.0  825532764.0  tt1375666           8.4     31837.0

# %%
df_movie_genre_long
# Out:
#         movie_id        primary_title       original_title  start_year  \
# 0      tt1014759  Alice in Wonderland  Alice in Wonderland        2010
# 1      tt1014759  Alice in Wonderland  Alice in Wonderland        2010
# 2      tt1014759  Alice in Wonderland  Alice in Wonderland        2010
# 3      tt1014759  Alice in Wonderland  Alice in Wonderland        2010
# 4      tt1014759  Alice in Wonderland  Alice in Wonderland        2010
# ...          ...                  ...                  ...         ...
# 32773  tt6139732              Aladdin              Aladdin        2019
# 32774  tt6139732              Aladdin              Aladdin        2019
# 32775  tt6139732              Aladdin              Aladdin        2019
# 32776  tt6139732              Aladdin              Aladdin        2019
# 32777  tt6139732              Aladdin              Aladdin        2019
#
#                          genres  average_rating  num_votes  \
# 0      Adventure,Family,Fantasy             6.5     358813
# 1      Adventure,Family,Fantasy             6.5     358813
# 2      Adventure,Family,Fantasy             6.5     358813
# 3      Adventure,Family,Fantasy             6.5     358813
# 4      Adventure,Family,Fantasy             6.5     358813
# ...                         ...             ...        ...
# 32773   Adventure,Comedy,Family             7.4      57549
# 32774   Adventure,Comedy,Family             7.4      57549
# 32775   Adventure,Comedy,Family             7.4      57549
# 32776   Adventure,Comedy,Family             7.4      57549
# 32777   Adventure,Comedy,Family             7.4      57549
#
#                persons_name persons_job     title_norm_movie_info  id  \
# 0               Johnny Depp       actor  alice in wonderland 2010  51
# 1               Johnny Depp       actor  alice in wonderland 2010  51
# 2               Johnny Depp       actor  alice in wonderland 2010  51
# 3      Helena Bonham Carter     actress  alice in wonderland 2010  51
# 4      Helena Bonham Carter     actress  alice in wonderland 2010  51
# ...                     ...         ...                       ...  ..
# 32773           Naomi Scott     actress              aladdin 2019  81
# 32774           Naomi Scott     actress              aladdin 2019  81
# 32775          Mena Massoud       actor              aladdin 2019  81
# 32776          Mena Massoud       actor              aladdin 2019  81
# 32777          Mena Massoud       actor              aladdin 2019  81
#
#        release_date                movie  production_budget  domestic_gross  \
# 0       Mar 5, 2010  Alice in Wonderland          200000000       334191110
# 1       Mar 5, 2010  Alice in Wonderland          200000000       334191110
# 2       Mar 5, 2010  Alice in Wonderland          200000000       334191110
# 3       Mar 5, 2010  Alice in Wonderland          200000000       334191110
# 4       Mar 5, 2010  Alice in Wonderland          200000000       334191110
# ...             ...                  ...                ...             ...
# 32773  May 24, 2019              Aladdin          182000000       246734314
# 32774  May 24, 2019              Aladdin          182000000       246734314
# 32775  May 24, 2019              Aladdin          182000000       246734314
# 32776  May 24, 2019              Aladdin          182000000       246734314
# 32777  May 24, 2019              Aladdin          182000000       246734314
#
#        worldwide_gross     title_norm_genre_long      genre
# 0           1025491110  alice in wonderland 2010    Fantasy
# 1           1025491110  alice in wonderland 2010     Family
# 2           1025491110  alice in wonderland 2010  Adventure
# 3           1025491110  alice in wonderland 2010    Fantasy
# 4           1025491110  alice in wonderland 2010     Family
# ...                ...                       ...        ...
# 32773        619234314              aladdin 2019     Comedy
# 32774        619234314              aladdin 2019     Family
# 32775        619234314              aladdin 2019  Adventure
# 32776        619234314              aladdin 2019     Comedy
# 32777        619234314              aladdin 2019     Family
#
# [32778 rows x 18 columns]

# %%
len(df_movie_genre_long['movie_id'].unique())
# Out:
# 1357

# %%
df_movie_genre_long.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32778 entries, 0 to 32777
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   movie_id               32778 non-null  object
#  1   primary_title          32778 non-null  object
#  2   original_title         32778 non-null  object
#  3   start_year             32778 non-null  int64
#  4   genres                 32778 non-null  object
#  5   average_rating         32778 non-null  float64
#  6   num_votes              32778 non-null  int64
#  7   persons_name           32778 non-null  object
#  8   persons_job            32778 non-null  object
#  9   title_norm_movie_info  32778 non-null  object
#  10  id                     32778 non-null  int64
#  11  release_date           32778 non-null  object
#  12  movie                  32778 non-null  object
#  13  production_budget      32778 non-null  int64
#  14  domestic_gross         32778 non-null  int64
#  15  worldwide_gross        32778 non-null  int64
#  16  title_norm_genre_long  32778 non-null  object
#  17  genre                  32778 non-null  object
# dtypes: float64(1), int64(6), object(11)
# memory usage: 4.8+ MB

# %%
df_all_data = df_movie_genre_long.merge(df_tmdb_filtered,
                         how='inner',
                         left_on='movie_id',
                         right_on='imdb_id')

# %%
df_all_data
# Out:
#         movie_id        primary_title       original_title  start_year  \
# 0      tt1014759  Alice in Wonderland  Alice in Wonderland        2010
# 1      tt1014759  Alice in Wonderland  Alice in Wonderland        2010
# 2      tt1014759  Alice in Wonderland  Alice in Wonderland        2010
# 3      tt1014759  Alice in Wonderland  Alice in Wonderland        2010
# 4      tt1014759  Alice in Wonderland  Alice in Wonderland        2010
# ...          ...                  ...                  ...         ...
# 34028  tt3829266         The Predator         The Predator        2018
# 34029  tt3829266         The Predator         The Predator        2018
# 34030  tt3829266         The Predator         The Predator        2018
# 34031  tt3829266         The Predator         The Predator        2018
# 34032  tt3829266         The Predator         The Predator        2018
#
#                          genres  average_rating  num_votes  \
# 0      Adventure,Family,Fantasy             6.5     358813
# 1      Adventure,Family,Fantasy             6.5     358813
# 2      Adventure,Family,Fantasy             6.5     358813
# 3      Adventure,Family,Fantasy             6.5     358813
# 4      Adventure,Family,Fantasy             6.5     358813
# ...                         ...             ...        ...
# 34028   Action,Adventure,Sci-Fi             5.4      94888
# 34029   Action,Adventure,Sci-Fi             5.4      94888
# 34030   Action,Adventure,Sci-Fi             5.4      94888
# 34031   Action,Adventure,Sci-Fi             5.4      94888
# 34032   Action,Adventure,Sci-Fi             5.4      94888
#
#                persons_name persons_job     title_norm_movie_info  ...  \
# 0               Johnny Depp       actor  alice in wonderland 2010  ...
# 1               Johnny Depp       actor  alice in wonderland 2010  ...
# 2               Johnny Depp       actor  alice in wonderland 2010  ...
# 3      Helena Bonham Carter     actress  alice in wonderland 2010  ...
# 4      Helena Bonham Carter     actress  alice in wonderland 2010  ...
# ...                     ...         ...                       ...  ...
# 34028        Jacob Tremblay       actor         the predator 2018  ...
# 34029        Jacob Tremblay       actor         the predator 2018  ...
# 34030       Trevante Rhodes       actor         the predator 2018  ...
# 34031       Trevante Rhodes       actor         the predator 2018  ...
# 34032       Trevante Rhodes       actor         the predator 2018  ...
#
#        release_date                movie production_budget  domestic_gross  \
# 0       Mar 5, 2010  Alice in Wonderland         200000000       334191110
# 1       Mar 5, 2010  Alice in Wonderland         200000000       334191110
# 2       Mar 5, 2010  Alice in Wonderland         200000000       334191110
# 3       Mar 5, 2010  Alice in Wonderland         200000000       334191110
# 4       Mar 5, 2010  Alice in Wonderland         200000000       334191110
# ...             ...                  ...               ...             ...
# 34028  Sep 14, 2018         The Predator          88000000        51024708
# 34029  Sep 14, 2018         The Predator          88000000        51024708
# 34030  Sep 14, 2018         The Predator          88000000        51024708
# 34031  Sep 14, 2018         The Predator          88000000        51024708
# 34032  Sep 14, 2018         The Predator          88000000        51024708
#
#        worldwide_gross     title_norm_genre_long      genre    imdb_id  \
# 0           1025491110  alice in wonderland 2010    Fantasy  tt1014759
# 1           1025491110  alice in wonderland 2010     Family  tt1014759
# 2           1025491110  alice in wonderland 2010  Adventure  tt1014759
# 3           1025491110  alice in wonderland 2010    Fantasy  tt1014759
# 4           1025491110  alice in wonderland 2010     Family  tt1014759
# ...                ...                       ...        ...        ...
# 34028        159487563         the predator 2018     Sci-Fi  tt3829266
# 34029        159487563         the predator 2018  Adventure  tt3829266
# 34030        159487563         the predator 2018     Action  tt3829266
# 34031        159487563         the predator 2018     Sci-Fi  tt3829266
# 34032        159487563         the predator 2018  Adventure  tt3829266
#
#       vote_average  vote_count
# 0              6.6     12255.0
# 1              6.6     12255.0
# 2              6.6     12255.0
# 3              6.6     12255.0
# 4              6.6     12255.0
# ...            ...         ...
# 34028          5.6      3786.0
# 34029          5.6      3786.0
# 34030          5.6      3786.0
# 34031          5.6      3786.0
# 34032          5.6      3786.0
#
# [34033 rows x 21 columns]

# %%
# save this dataframe as a csv
df_all_data.to_csv('all_data.csv')
